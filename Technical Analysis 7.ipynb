# %% [markdown]
# ## Downloads all Stock Data from a Given Index for 5 Years

# %%
# Provides ways to work with large multidimensional arrays
import numpy as np 
# Allows for further data manipulation and analysis
import pandas as pd 
import matplotlib.pyplot as plt # Plotting
import matplotlib.dates as mdates # Styling dates
# %matplotlib inline

# pip install numpy
# conda install -c anaconda pandas
# conda install -c conda-forge matplotlib

import datetime as dt # For defining dates

import time

# In Powershell Prompt : conda install -c conda-forge multitasking
# pip install -i https://pypi.anaconda.org/ranaroussi/simple yfinance

import yfinance as yf

# To show all your output File -> Preferences -> Settings Search for Notebook
# Notebook Output Text Line Limit and set to 100

# Used for file handling like deleting files
import os

# conda install -c conda-forge cufflinks-py
# conda install -c plotly plotly
import cufflinks as cf
import plotly.express as px
import plotly.graph_objects as go

# Make Plotly work in your Jupyter Notebook
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Use Plotly locally
cf.go_offline()

from plotly.subplots import make_subplots

# New Imports
# Used to get data from a directory
import os
from os import listdir
from os.path import isfile, join

import warnings
warnings.simplefilter("ignore")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Constants

# %%
PATH = "D:/Python for Finance/Wilshire_Stocks/"

# Start end date defaults
S_DATE = "2016-12-12"
E_DATE = "2021-12-10"
S_DATE_DT = pd.to_datetime(S_DATE)
E_DATE_DT = pd.to_datetime(E_DATE)

# %% [markdown]
# ## Holds Stocks Not Downloaded

# %%
stocks_not_downloaded = []
missing_stocks = []

# %% [markdown]
# ## Function that Returns a Stock Dataframe from a CSV

# %%
# Reads a dataframe from the CSV file, changes index to date and returns it
def get_stock_df_from_csv(ticker):
    
    # Try to get the file and if it doesn't exist issue a warning
    try:
        df = pd.read_csv(PATH + ticker + '.csv', index_col=0)
    except FileNotFoundError:
        print("File Doesn't Exist")
    else:
        return df

# %% [markdown]
# ## Returns a Named Columns Data from a CSV

# %%
def get_column_from_csv(file, col_name):
    # Try to get the file and if it doesn't exist issue a warning
    try:
        df = pd.read_csv(file)
    except FileNotFoundError:
        print("File Doesn't Exist")
    else:
        return df[col_name]

# %% [markdown]
# ## Get Stock Tickers

# %%
# Total of 3482 tickers
tickers = get_column_from_csv("D:/Python for Finance/Wilshire-5000-Stocks.csv", "Ticker")
tickers

# for x in tickers:
#     print(x, end=", ")

print(len(tickers))
# Out:
# 3481

# %% [markdown]
# ## Function that Saves Stock Data to CSV

# %%
# Function that gets a dataframe by providing a ticker and starting date
def save_to_csv_from_yahoo(folder, ticker):
    
    stock = yf.Ticker(ticker)
    
    try:
        print("Get Data for : ", ticker)
        # Get historical closing price data
        df = stock.history(period="5y")
    
        # Wait 2 seconds
        time.sleep(2)
        
        if df.empty:
            stocks_not_downloaded.append(ticker)
        
        # Remove the period for saving the file name
        # Save data to a CSV file
        # File to save to 
        the_file = folder + ticker.replace(".", "_") + '.csv'
        print(the_file, " Saved")
        df.to_csv(the_file)
    except Exception as ex:
        stocks_not_downloaded.append(ticker)
        print("Couldn't Get Data for :", ticker)

# %% [markdown]
# ## Get 5 Years of Data for the 1st 20 Stocks

# %%
# # Folder used to store stock data
# folder = "D:/Python for Finance/Wilshire_Stocks/"

# for x in range(20):
#   save_to_csv_from_yahoo(folder, tickers[x])
# print("Finished")

# %% [markdown]
# ## Stocks Not Downloaded

# %%
# stocks_not_downloaded

# %% [markdown]
# ## Get Next 80 Stocks

# %%
# for x in range(20, 100):
#   save_to_csv_from_yahoo(folder, tickers[x])
# print("Finished")
# stocks_not_downloaded

# %% [markdown]
# ## Get Rest of Stocks

# %%
# for x in range(3001, 3481):
#   save_to_csv_from_yahoo(folder, tickers[x])
# print("Finished")
# stocks_not_downloaded

# %% [markdown]
# ## Delete Empty Files

# %%
try:
  for x in missing_stocks:
    os.remove("D:/Python for Finance/Wilshire_Stocks/" + x + ".csv")
except FileNotFoundError:
  print("Couldn't Find " + x)

print("Finished")
# Out:
# Finished

# %% [markdown]
# ## Are FAANG Stocks Worth Investing in?

# %%
# Download just those stocks were are working with to make them up to date
# Facebook, Amazon, Apple, Netflix, Google
tickers = ["FB", "AMZN", "AAPL", "NFLX", "GOOG"]

for i in tickers:
    save_to_csv_from_yahoo("D:/Python for Finance/Wilshire_Stocks/", i)
    print("Finished " + i)
# Out:
# Get Data for :  FB
# D:/Python for Finance/Wilshire_Stocks/FB.csv  Saved
# Finished FB
# Get Data for :  AMZN
# D:/Python for Finance/Wilshire_Stocks/AMZN.csv  Saved
# Finished AMZN
# Get Data for :  AAPL
# D:/Python for Finance/Wilshire_Stocks/AAPL.csv  Saved
# Finished AAPL
# Get Data for :  NFLX
# D:/Python for Finance/Wilshire_Stocks/NFLX.csv  Saved
# Finished NFLX
# Get Data for :  GOOG
# D:/Python for Finance/Wilshire_Stocks/GOOG.csv  Saved
# Finished GOOG

# %%
fig = go.Figure()

# Get the dataframe with all FB's data
fb_df = get_stock_df_from_csv("FB")

# fb_df.head()

# Get closing price for the rest
amzn_df = get_stock_df_from_csv("AMZN")
aapl_df = get_stock_df_from_csv("AAPL")
nflx_df = get_stock_df_from_csv("NFLX")
goog_df = get_stock_df_from_csv("GOOG")

amzn_df

fb_plot = go.Scatter(x=fb_df.index, y=fb_df['Close'], name="Facebook")
amzn_plot = go.Scatter(x=amzn_df.index, y=amzn_df['Close'], name="Amazon")
aapl_plot = go.Scatter(x=aapl_df.index, y=aapl_df['Close'], name="Apple")
nflx_plot = go.Scatter(x=nflx_df.index, y=nflx_df['Close'], name="Netflix")
goog_plot = go.Scatter(x=goog_df.index, y=goog_df['Close'], name="Google")

# Plot price changes
fig.add_trace(fb_plot)
fig.add_trace(amzn_plot)
fig.add_trace(aapl_plot)
fig.add_trace(nflx_plot)
fig.add_trace(goog_plot)

fig.update_xaxes(title="Date", rangeslider_visible=True)
fig.update_yaxes(title="Price")
fig.update_layout(height=1200, width=1800, 
                  showlegend=True)
fig.show()

# This data isn't useful for our purposes because the scales are different
# We must calculate the daily returns for these stocks to get data we can
# work with
# Out:
# <div>                            <div id="7fa47dda-6bc2-4b55-9b51-19260a81b563" class="plotly-graph-div" style="height:1200px; width:1800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7fa47dda-6bc2-4b55-9b51-19260a81b563")) {                    Plotly.newPlot(                        "7fa47dda-6bc2-4b55-9b51-19260a81b563",                        [{"name":"Facebook","type":"scatter","x":["2016-12-29","2016-12-30","2017-01-03","2017-01-04","2017-01-05","2017-01-06","2017-01-09","2017-01-10","2017-01-11","2017-01-12","2017-01-13","2017-01-17","2017-01-18","2017-01-19","2017-01-20","2017-01-23","2017-01-24","2017-01-25","2017-01-26","2017-01-27","2017-01-30","2017-01-31","2017-02-01","2017-02-02","2017-02-03","2017-02-06","2017-02-07","2017-02-08","2017-02-09","2017-02-10","2017-02-13","2017-02-14","2017-02-15","2017-02-16","2017-02-17","2017-02-21","2017-02-22","2017-02-23","2017-02-24","2017-02-27","2017-02-28","2017-03-01","2017-03-02","2017-03-03","2017-03-06","2017-03-07","2017-03-08","2017-03-09","2017-03-10","2017-03-13","2017-03-14","2017-03-15","2017-03-16","2017-03-17","2017-03-20","2017-03-21","2017-03-22","2017-03-23","2017-03-24","2017-03-27","2017-03-28","2017-03-29","2017-03-30","2017-03-31","2017-04-03","2017-04-04","2017-04-05","2017-04-06","2017-04-07","2017-04-10","2017-04-11","2017-04-12","2017-04-13","2017-04-17","2017-04-18","2017-04-19","2017-04-20","2017-04-21","2017-04-24","2017-04-25","2017-04-26","2017-04-27","2017-04-28","2017-05-01","2017-05-02","2017-05-03","2017-05-04","2017-05-05","2017-05-08","2017-05-09","2017-05-10","2017-05-11","2017-05-12","2017-05-15","2017-05-16","2017-05-17","2017-05-18","2017-05-19","2017-05-22","2017-05-23","2017-05-24","2017-05-25","2017-05-26","2017-05-30","2017-05-31","2017-06-01","2017-06-02","2017-06-05","2017-06-06","2017-06-07","2017-06-08","2017-06-09","2017-06-12","2017-06-13","2017-06-14","2017-06-15","2017-06-16","2017-06-19","2017-06-20","2017-06-21","2017-06-22","2017-06-23","2017-06-26","2017-06-27","2017-06-28","2017-06-29","2017-06-30","2017-07-03","2017-07-05","2017-07-06","2017-07-07","2017-07-10","2017-07-11","2017-07-12","2017-07-13","2017-07-14","2017-07-17","2017-07-18","2017-07-19","2017-07-20","2017-07-21","2017-07-24","2017-07-25","2017-07-26","2017-07-27","2017-07-28","2017-07-31","2017-08-01","2017-08-02","2017-08-03","2017-08-04","2017-08-07","2017-08-08","2017-08-09","2017-08-10","2017-08-11","2017-08-14","2017-08-15","2017-08-16","2017-08-17","2017-08-18","2017-08-21","2017-08-22","2017-08-23","2017-08-24","2017-08-25","2017-08-28","2017-08-29","2017-08-30","2017-08-31","2017-09-01","2017-09-05","2017-09-06","2017-09-07","2017-09-08","2017-09-11","2017-09-12","2017-09-13","2017-09-14","2017-09-15","2017-09-18","2017-09-19","2017-09-20","2017-09-21","2017-09-22","2017-09-25","2017-09-26","2017-09-27","2017-09-28","2017-09-29","2017-10-02","2017-10-03","2017-10-04","2017-10-05","2017-10-06","2017-10-09","2017-10-10","2017-10-11","2017-10-12","2017-10-13","2017-10-16","2017-10-17","2017-10-18","2017-10-19","2017-10-20","2017-10-23","2017-10-24","2017-10-25","2017-10-26","2017-10-27","2017-10-30","2017-10-31","2017-11-01","2017-11-02","2017-11-03","2017-11-06","2017-11-07","2017-11-08","2017-11-09","2017-11-10","2017-11-13","2017-11-14","2017-11-15","2017-11-16","2017-11-17","2017-11-20","2017-11-21","2017-11-22","2017-11-24","2017-11-27","2017-11-28","2017-11-29","2017-11-30","2017-12-01","2017-12-04","2017-12-05","2017-12-06","2017-12-07","2017-12-08","2017-12-11","2017-12-12","2017-12-13","2017-12-14","2017-12-15","2017-12-18","2017-12-19","2017-12-20","2017-12-21","2017-12-22","2017-12-26","2017-12-27","2017-12-28","2017-12-29","2018-01-02","2018-01-03","2018-01-04","2018-01-05","2018-01-08","2018-01-09","2018-01-10","2018-01-11","2018-01-12","2018-01-16","2018- ...

# %% [markdown]
# ## Daily Returns

# %% [markdown]
# For single stocks to find the daily return we subtract opening price from the closing price. Then you could multiply by the number of shares owned.
#
# We calculate a percentage rate of return for each day to compare investments.
# Simple Rate of Return = (End Price - Beginning Price) / Beginning Price OR (EP / BP) - 1

# %%
# Shift provides the value from the previous day
# NaN is displayed because there was no previous day price for the 1st calculation
def add_daily_return_to_df(df, ticker):
    df['daily_return'] = (df['Close'] / df['Close'].shift(1)) - 1
    # Save data to a CSV file
    df.to_csv(PATH + ticker + '.csv')
    return df

# %%
add_daily_return_to_df(fb_df, "FB")
add_daily_return_to_df(amzn_df, "AMZN")
add_daily_return_to_df(aapl_df, "AAPL")
add_daily_return_to_df(nflx_df, "NFLX")
add_daily_return_to_df(goog_df, "GOOG")
goog_df.head()
# Out:
#                   Open        High         Low       Close   Volume  \
# Date
# 2016-12-29  783.330017  785.929993  778.919983  782.789978   744300
# 2016-12-30  782.750000  782.780029  770.409973  771.820007  1770000
# 2017-01-03  778.809998  789.630005  775.799988  786.140015  1657300
# 2017-01-04  788.359985  791.340027  783.159973  786.900024  1073000
# 2017-01-05  786.080017  794.479980  785.020020  794.020020  1335200
#
#             Dividends  Stock Splits  daily_return
# Date
# 2016-12-29          0             0           NaN
# 2016-12-30          0             0     -0.014014
# 2017-01-03          0             0      0.018554
# 2017-01-04          0             0      0.000967
# 2017-01-05          0             0      0.009048

# %% [markdown]
# ## Get Cumulative Return

# %%
def add_cum_return_to_df(df, ticker):
    df['cum_return'] = (1 + df['daily_return']).cumprod()
    df.to_csv(PATH + ticker + '.csv')
    return df

# %%
add_cum_return_to_df(fb_df, "FB")
add_cum_return_to_df(amzn_df, "AMZN")
add_cum_return_to_df(aapl_df, "AAPL")
add_cum_return_to_df(nflx_df, "NFLX")
add_cum_return_to_df(goog_df, "GOOG")
# Out:
#                    Open         High          Low        Close   Volume  \
# Date
# 2016-12-29   783.330017   785.929993   778.919983   782.789978   744300
# 2016-12-30   782.750000   782.780029   770.409973   771.820007  1770000
# 2017-01-03   778.809998   789.630005   775.799988   786.140015  1657300
# 2017-01-04   788.359985   791.340027   783.159973   786.900024  1073000
# 2017-01-05   786.080017   794.479980   785.020020   794.020020  1335200
# ...                 ...          ...          ...          ...      ...
# 2021-12-22  2882.000000  2946.060059  2879.260010  2938.979980   921900
# 2021-12-23  2941.790039  2971.451904  2939.017090  2942.850098   690300
# 2021-12-27  2949.270020  2968.530029  2945.000000  2961.280029   662800
# 2021-12-28  2967.489990  2967.489990  2918.709961  2928.959961   931200
# 2021-12-29  2928.590088  2943.675049  2910.090088  2914.530029   467227
#
#             Dividends  Stock Splits  daily_return  cum_return
# Date
# 2016-12-29          0             0           NaN         NaN
# 2016-12-30          0             0     -0.014014    0.985986
# 2017-01-03          0             0      0.018554    1.004280
# 2017-01-04          0             0      0.000967    1.005251
# 2017-01-05          0             0      0.009048    1.014346
# ...               ...           ...           ...         ...
# 2021-12-22          0             0      0.018919    3.754494
# 2021-12-23          0             0      0.001317    3.759438
# 2021-12-27          0             0      0.006263    3.782982
# 2021-12-28          0             0     -0.010914    3.741693
# 2021-12-29          0             0     -0.004927    3.723259
#
# [1259 rows x 9 columns]

# %% [markdown]
# ## Merge Multiple Stocks in One Dataframe by Column Name

# %%
def merge_df_by_column_name(col_name, sdate, edate, *tickers):
    # Will hold data for all dataframes with the same column name
    mult_df = pd.DataFrame()
    
    for x in tickers:
        df = get_stock_df_from_csv(x)
        
        # NEW Check if your dataframe has duplicate indexes
        if not df.index.is_unique:
            # Delete duplicates 
            df = df.loc[~df.index.duplicated(), :]
        
        mask = (df.index >= sdate) & (df.index <= edate)
        mult_df[x] = df.loc[mask][col_name]
        
    return mult_df

# %%
mult_df = merge_df_by_column_name('cum_return',  S_DATE, 
                                  E_DATE, *tickers)
mult_df
# Out:
#                   FB      AMZN      AAPL      NFLX      GOOG
# Date
# 2016-12-29       NaN       NaN       NaN       NaN       NaN
# 2016-12-30  0.988827  0.980030  0.992204  0.987792  0.985986
# 2017-01-03  1.004383  0.984996  0.995031  1.017234  1.004280
# 2017-01-04  1.020112  0.989584  0.993918  1.032554  1.005251
# 2017-01-05  1.037129  1.019996  0.998972  1.051703  1.014346
# ...              ...       ...       ...       ...       ...
# 2021-12-06  2.732015  4.479344  6.018431  4.888614  3.673948
# 2021-12-07  2.774474  4.604705  6.231762  4.991463  3.782279
# 2021-12-08  2.841083  4.604535  6.373741  5.011410  3.799755
# 2021-12-09  2.834723  4.552597  6.354810  4.875130  3.784055
# 2021-12-10  2.834121  4.501392  6.532829  4.880395  3.798592
#
# [1247 rows x 5 columns]

# %%
# Plot out cumulative returns on $1 in each stock since beginning of 2017
fig = px.line(mult_df, x=mult_df.index, y=mult_df.columns)
fig.update_xaxes(title="Date", rangeslider_visible=True)
fig.update_yaxes(title="Price")
fig.update_layout(height=1200, width=1800, 
                  showlegend=True)
fig.show()
# Out:
# <div>                            <div id="ee151d8f-5669-4993-bf81-ac295a1c7b04" class="plotly-graph-div" style="height:1200px; width:1800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee151d8f-5669-4993-bf81-ac295a1c7b04")) {                    Plotly.newPlot(                        "ee151d8f-5669-4993-bf81-ac295a1c7b04",                        [{"hovertemplate":"variable=FB<br>Date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"FB","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"FB","showlegend":true,"type":"scattergl","x":["2016-12-29","2016-12-30","2017-01-03","2017-01-04","2017-01-05","2017-01-06","2017-01-09","2017-01-10","2017-01-11","2017-01-12","2017-01-13","2017-01-17","2017-01-18","2017-01-19","2017-01-20","2017-01-23","2017-01-24","2017-01-25","2017-01-26","2017-01-27","2017-01-30","2017-01-31","2017-02-01","2017-02-02","2017-02-03","2017-02-06","2017-02-07","2017-02-08","2017-02-09","2017-02-10","2017-02-13","2017-02-14","2017-02-15","2017-02-16","2017-02-17","2017-02-21","2017-02-22","2017-02-23","2017-02-24","2017-02-27","2017-02-28","2017-03-01","2017-03-02","2017-03-03","2017-03-06","2017-03-07","2017-03-08","2017-03-09","2017-03-10","2017-03-13","2017-03-14","2017-03-15","2017-03-16","2017-03-17","2017-03-20","2017-03-21","2017-03-22","2017-03-23","2017-03-24","2017-03-27","2017-03-28","2017-03-29","2017-03-30","2017-03-31","2017-04-03","2017-04-04","2017-04-05","2017-04-06","2017-04-07","2017-04-10","2017-04-11","2017-04-12","2017-04-13","2017-04-17","2017-04-18","2017-04-19","2017-04-20","2017-04-21","2017-04-24","2017-04-25","2017-04-26","2017-04-27","2017-04-28","2017-05-01","2017-05-02","2017-05-03","2017-05-04","2017-05-05","2017-05-08","2017-05-09","2017-05-10","2017-05-11","2017-05-12","2017-05-15","2017-05-16","2017-05-17","2017-05-18","2017-05-19","2017-05-22","2017-05-23","2017-05-24","2017-05-25","2017-05-26","2017-05-30","2017-05-31","2017-06-01","2017-06-02","2017-06-05","2017-06-06","2017-06-07","2017-06-08","2017-06-09","2017-06-12","2017-06-13","2017-06-14","2017-06-15","2017-06-16","2017-06-19","2017-06-20","2017-06-21","2017-06-22","2017-06-23","2017-06-26","2017-06-27","2017-06-28","2017-06-29","2017-06-30","2017-07-03","2017-07-05","2017-07-06","2017-07-07","2017-07-10","2017-07-11","2017-07-12","2017-07-13","2017-07-14","2017-07-17","2017-07-18","2017-07-19","2017-07-20","2017-07-21","2017-07-24","2017-07-25","2017-07-26","2017-07-27","2017-07-28","2017-07-31","2017-08-01","2017-08-02","2017-08-03","2017-08-04","2017-08-07","2017-08-08","2017-08-09","2017-08-10","2017-08-11","2017-08-14","2017-08-15","2017-08-16","2017-08-17","2017-08-18","2017-08-21","2017-08-22","2017-08-23","2017-08-24","2017-08-25","2017-08-28","2017-08-29","2017-08-30","2017-08-31","2017-09-01","2017-09-05","2017-09-06","2017-09-07","2017-09-08","2017-09-11","2017-09-12","2017-09-13","2017-09-14","2017-09-15","2017-09-18","2017-09-19","2017-09-20","2017-09-21","2017-09-22","2017-09-25","2017-09-26","2017-09-27","2017-09-28","2017-09-29","2017-10-02","2017-10-03","2017-10-04","2017-10-05","2017-10-06","2017-10-09","2017-10-10","2017-10-11","2017-10-12","2017-10-13","2017-10-16","2017-10-17","2017-10-18","2017-10-19","2017-10-20","2017-10-23","2017-10-24","2017-10-25","2017-10-26","2017-10-27","2017-10-30","2017-10-31","2017-11-01","2017-11-02","2017-11-03","2017-11-06","2017-11-07","2017-11-08","2017-11-09","2017-11-10","2017-11-13","2017-11-14","2017-11-15","2017-11-16","2017-11-17","2017-11-20","2017-11-21","2017-11-22","2017-11-24","2017-11-27","2017-11-28","2017-11-29","2017-11-30","2017-12-01","2017-12-04","2017-12-05","2017-12-06","2017-12-07","2017-12-08","2017-12-11","2017-12-12","2017-12-13","2017-12-14","2017-12-15","2017-12-18","2017-12-19","2017-12-20","2017-12-21","2017-12-2 ...

# %% [markdown]
# ## Create a Price / Volume Chart

# %%
fig = go.Figure()
nflx_plot = go.Scatter(x=nflx_df.index, y=nflx_df['Close'], name="Netflix")

# Plot price changes
fig.add_trace(nflx_plot)

# Plot volume as bar graph
fig.add_trace(go.Bar(x=nflx_df.index, y=nflx_df['Volume']/200000, name='Volume Traded'))

fig.update_xaxes(title="Date", rangeslider_visible=True)
fig.update_yaxes(title="Price")
fig.update_layout(height=1200, width=1800, 
                  showlegend=True)
fig.show()
# Out:
# <div>                            <div id="cc3b54ad-ff6b-46eb-8d71-6cb082ae7cc1" class="plotly-graph-div" style="height:1200px; width:1800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc3b54ad-ff6b-46eb-8d71-6cb082ae7cc1")) {                    Plotly.newPlot(                        "cc3b54ad-ff6b-46eb-8d71-6cb082ae7cc1",                        [{"name":"Netflix","type":"scatter","x":["2016-12-29","2016-12-30","2017-01-03","2017-01-04","2017-01-05","2017-01-06","2017-01-09","2017-01-10","2017-01-11","2017-01-12","2017-01-13","2017-01-17","2017-01-18","2017-01-19","2017-01-20","2017-01-23","2017-01-24","2017-01-25","2017-01-26","2017-01-27","2017-01-30","2017-01-31","2017-02-01","2017-02-02","2017-02-03","2017-02-06","2017-02-07","2017-02-08","2017-02-09","2017-02-10","2017-02-13","2017-02-14","2017-02-15","2017-02-16","2017-02-17","2017-02-21","2017-02-22","2017-02-23","2017-02-24","2017-02-27","2017-02-28","2017-03-01","2017-03-02","2017-03-03","2017-03-06","2017-03-07","2017-03-08","2017-03-09","2017-03-10","2017-03-13","2017-03-14","2017-03-15","2017-03-16","2017-03-17","2017-03-20","2017-03-21","2017-03-22","2017-03-23","2017-03-24","2017-03-27","2017-03-28","2017-03-29","2017-03-30","2017-03-31","2017-04-03","2017-04-04","2017-04-05","2017-04-06","2017-04-07","2017-04-10","2017-04-11","2017-04-12","2017-04-13","2017-04-17","2017-04-18","2017-04-19","2017-04-20","2017-04-21","2017-04-24","2017-04-25","2017-04-26","2017-04-27","2017-04-28","2017-05-01","2017-05-02","2017-05-03","2017-05-04","2017-05-05","2017-05-08","2017-05-09","2017-05-10","2017-05-11","2017-05-12","2017-05-15","2017-05-16","2017-05-17","2017-05-18","2017-05-19","2017-05-22","2017-05-23","2017-05-24","2017-05-25","2017-05-26","2017-05-30","2017-05-31","2017-06-01","2017-06-02","2017-06-05","2017-06-06","2017-06-07","2017-06-08","2017-06-09","2017-06-12","2017-06-13","2017-06-14","2017-06-15","2017-06-16","2017-06-19","2017-06-20","2017-06-21","2017-06-22","2017-06-23","2017-06-26","2017-06-27","2017-06-28","2017-06-29","2017-06-30","2017-07-03","2017-07-05","2017-07-06","2017-07-07","2017-07-10","2017-07-11","2017-07-12","2017-07-13","2017-07-14","2017-07-17","2017-07-18","2017-07-19","2017-07-20","2017-07-21","2017-07-24","2017-07-25","2017-07-26","2017-07-27","2017-07-28","2017-07-31","2017-08-01","2017-08-02","2017-08-03","2017-08-04","2017-08-07","2017-08-08","2017-08-09","2017-08-10","2017-08-11","2017-08-14","2017-08-15","2017-08-16","2017-08-17","2017-08-18","2017-08-21","2017-08-22","2017-08-23","2017-08-24","2017-08-25","2017-08-28","2017-08-29","2017-08-30","2017-08-31","2017-09-01","2017-09-05","2017-09-06","2017-09-07","2017-09-08","2017-09-11","2017-09-12","2017-09-13","2017-09-14","2017-09-15","2017-09-18","2017-09-19","2017-09-20","2017-09-21","2017-09-22","2017-09-25","2017-09-26","2017-09-27","2017-09-28","2017-09-29","2017-10-02","2017-10-03","2017-10-04","2017-10-05","2017-10-06","2017-10-09","2017-10-10","2017-10-11","2017-10-12","2017-10-13","2017-10-16","2017-10-17","2017-10-18","2017-10-19","2017-10-20","2017-10-23","2017-10-24","2017-10-25","2017-10-26","2017-10-27","2017-10-30","2017-10-31","2017-11-01","2017-11-02","2017-11-03","2017-11-06","2017-11-07","2017-11-08","2017-11-09","2017-11-10","2017-11-13","2017-11-14","2017-11-15","2017-11-16","2017-11-17","2017-11-20","2017-11-21","2017-11-22","2017-11-24","2017-11-27","2017-11-28","2017-11-29","2017-11-30","2017-12-01","2017-12-04","2017-12-05","2017-12-06","2017-12-07","2017-12-08","2017-12-11","2017-12-12","2017-12-13","2017-12-14","2017-12-15","2017-12-18","2017-12-19","2017-12-20","2017-12-21","2017-12-22","2017-12-26","2017-12-27","2017-12-28","2017-12-29","2018-01-02","2018-01-03","2018-01-04","2018-01-05","2018-01-08","2018-01-09","2018-01-10","2018-01-11","2018-01-12","2018-01-16","2018-0 ...

# %% [markdown]
# ## Adding Bollinger Bands

# %% [markdown]
# Bollinger Bands plot 2 lines using a moving average and the standard deviation defines how far apart the lines are. They also are used to define if prices are to high or low. When bands tighten it is believed a sharp price move in some direction. Prices tend to bounce off of the bands which provides potential market actions.
#
# A strong trend should be noted if the price moves outside the band. If prices go over the resistance line it is in overbought territory and if it breaks through support it is a sign of an oversold position.
#
# You normally use 20 sessions when using them.

# %%
# Here we will add a middle band (20 days), upper band (20 days + 1.96 std),
# and lower band (20 days - 1.96 std)

# %%
# Here we will add a middle band (20 days), upper band (20 days + 1.96 std),
# and lower band (20 days - 1.96 std)
def add_bollinger_bands(df):
    df['middle_band'] = df['Close'].rolling(window=20).mean()
    df['upper_band'] = df['middle_band'] + 1.96 * df['Close'].rolling(window=20).std()
    df['lower_band'] = df['middle_band'] - 1.96 * df['Close'].rolling(window=20).std()

# %%
stk_dfs = [fb_df, amzn_df, aapl_df, nflx_df, goog_df]

# %%
for x in stk_dfs:
    add_bollinger_bands(x)

# %%
fb_df
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2016-12-29  117.000000  117.529999  116.059998  116.349998   9934900
# 2016-12-30  116.599998  116.830002  114.769997  115.050003  18684100
# 2017-01-03  116.029999  117.839996  115.510002  116.860001  20663900
# 2017-01-04  117.550003  119.660004  117.290001  118.690002  19630900
# 2017-01-05  118.860001  120.949997  118.320000  120.669998  19492200
# ...                ...         ...         ...         ...       ...
# 2021-12-22  333.799988  334.510010  328.260010  330.450012  16764600
# 2021-12-23  330.100006  336.670013  328.359985  335.239990  13977200
# 2021-12-27  338.850006  347.869995  338.010010  346.179993  17795000
# 2021-12-28  346.630005  352.709991  345.200012  346.220001  16611200
# 2021-12-29  346.910004  349.689911  341.679993  342.501495   6225877
#
#             Dividends  Stock Splits  daily_return  cum_return  middle_band  \
# Date
# 2016-12-29          0             0           NaN         NaN          NaN
# 2016-12-30          0             0     -0.011173    0.988827          NaN
# 2017-01-03          0             0      0.015732    1.004383          NaN
# 2017-01-04          0             0      0.015660    1.020112          NaN
# 2017-01-05          0             0      0.016682    1.037129          NaN
# ...               ...           ...           ...         ...          ...
# 2021-12-22          0             0     -0.011221    2.840138   328.199501
# 2021-12-23          0             0      0.014495    2.881306   327.908501
# 2021-12-27          0             0      0.032633    2.975333   328.561501
# 2021-12-28          0             0      0.000116    2.975677   328.971001
# 2021-12-29          0             0     -0.010740    2.943717   329.873076
#
#             upper_band  lower_band
# Date
# 2016-12-29         NaN         NaN
# 2016-12-30         NaN         NaN
# 2017-01-03         NaN         NaN
# 2017-01-04         NaN         NaN
# 2017-01-05         NaN         NaN
# ...                ...         ...
# 2021-12-22  347.830195  308.568807
# 2021-12-23  346.924372  308.892629
# 2021-12-27  349.101415  308.021586
# 2021-12-28  350.561055  307.380946
# 2021-12-29  352.138321  307.607830
#
# [1259 rows x 12 columns]

# %% [markdown]
# ## Plot with Bollinger Bands

# %%
def plot_with_boll_bands(ticker):
    save_to_csv_from_yahoo("D:/Python for Finance/Wilshire_Stocks/", ticker)

    df = get_stock_df_from_csv(ticker)

    add_bollinger_bands(df)
    
    fig = go.Figure()

    candle = go.Candlestick(x=df.index, open=df['Open'],
    high=df['High'], low=df['Low'],
    close=df['Close'], name="Candlestick")

    upper_line = go.Scatter(x=df.index, y=df['upper_band'], 
    line=dict(color='rgba(250, 0, 0, 0.75)', 
    width=1), name="Upper Band")

    mid_line = go.Scatter(x=df.index, y=df['middle_band'], 
    line=dict(color='rgba(0, 0, 250, 0.75)', 
    width=0.7), name="Middle Band")

    lower_line = go.Scatter(x=df.index, y=df['lower_band'], 
    line=dict(color='rgba(0, 250, 0, 0.75)', 
    width=1), name="Lower Band")

    fig.add_trace(candle)
    fig.add_trace(upper_line)
    fig.add_trace(mid_line)
    fig.add_trace(lower_line)

    fig.update_xaxes(title="Date", rangeslider_visible=True)
    fig.update_yaxes(title="Price")
    fig.update_layout(title=ticker + " Bollinger Bands", 
    height=1200, width=1800, showlegend=True)
    fig.show()

# %%
plot_with_boll_bands("AMD")
# Out:
# Get Data for :  AMD
# D:/Python for Finance/Wilshire_Stocks/AMD.csv  Saved
# <div>                            <div id="c77b07d6-ddd4-4936-996f-b1f8c172b014" class="plotly-graph-div" style="height:1200px; width:1800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c77b07d6-ddd4-4936-996f-b1f8c172b014")) {                    Plotly.newPlot(                        "c77b07d6-ddd4-4936-996f-b1f8c172b014",                        [{"close":[11.59000015258789,11.34000015258789,11.43000030517578,11.43000030517578,11.239999771118164,11.31999969482422,11.489999771118164,11.4399995803833,11.199999809265137,10.760000228881836,10.579999923706056,9.81999969482422,9.880000114440918,9.770000457763672,9.75,9.90999984741211,10.4399995803833,10.350000381469728,10.520000457763672,10.670000076293944,10.609999656677246,10.369999885559082,12.0600004196167,12.279999732971191,12.239999771118164,13.630000114440918,13.289999961853027,13.5600004196167,13.420000076293944,13.579999923706056,13.489999771118164,13.260000228881836,13.300000190734863,12.970000267028809,13.130000114440918,14.0,14.279999732971191,14.31999969482422,14.119999885559082,15.199999809265137,14.460000038146973,14.960000038146973,13.899999618530272,13.029999732971191,13.039999961853027,13.050000190734863,13.220000267028809,13.329999923706056,13.90999984741211,14.279999732971191,14.100000381469728,13.979999542236328,13.649999618530272,13.489999771118164,14.399999618530272,13.81999969482422,14.100000381469728,13.789999961853027,13.699999809265137,13.699999809265137,13.6899995803833,13.710000038146973,14.050000190734863,14.550000190734863,14.640000343322754,14.15999984741211,14.170000076293944,13.270000457763672,13.520000457763672,13.100000381469728,13.100000381469728,12.760000228881836,12.3100004196167,12.789999961853027,12.949999809265137,12.84000015258789,13.109999656677246,13.0,13.130000114440918,13.489999771118164,13.40999984741211,13.619999885559082,13.300000190734863,13.619999885559082,10.31999969482422,10.390000343322754,10.100000381469728,10.1899995803833,10.039999961853027,10.18000030517578,10.789999961853027,11.06999969482422,11.260000228881836,11.420000076293944,12.75,11.199999809265137,11.279999732971191,11.40999984741211,11.039999961853027,10.890000343322754,10.890000343322754,10.979999542236328,11.0,11.119999885559082,11.1899995803833,10.93000030517578,10.899999618530272,11.239999771118164,12.029999732971191,12.380000114440918,12.899999618530272,12.279999732971191,12.09000015258789,11.960000038146973,11.770000457763672,11.5,11.4399995803833,11.93000030517578,12.640000343322754,13.979999542236328,14.380000114440918,14.170000076293944,14.079999923706056,13.399999618530272,13.229999542236328,12.600000381469728,12.479999542236328,12.149999618530272,13.1899995803833,13.020000457763672,13.359999656677246,13.8100004196167,13.890000343322754,14.289999961853027,13.529999732971191,13.920000076293944,13.800000190734863,13.479999542236328,13.550000190734863,13.800000190734863,13.880000114440918,14.15999984741211,14.109999656677246,14.760000228881836,14.119999885559082,13.949999809265137,13.609999656677246,13.710000038146973,13.369999885559082,13.239999771118164,13.119999885559082,13.43000030517578,13.109999656677246,12.829999923706056,12.119999885559082,12.229999542236328,12.760000228881836,13.020000457763672,12.630000114440918,12.34000015258789,12.369999885559082,12.050000190734863,12.170000076293944,12.479999542236328,12.5,12.43000030517578,12.229999542236328,12.149999618530272,12.670000076293944,13.0,13.1899995803833,12.920000076293944,12.859999656677246,12.630000114440918,12.25,12.550000190734863,12.300000190734863,12.220000267028809,12.260000228881836,12.520000457763672,13.079999923706056,13.119999885559082,13.739999771118164,13.40999984741211,13.300000190734863,12.609999656677246,12.449999809265137,12.739999771118164,12.739999771118164,12.75,12.710000038146973,13.42000007629394 ...

# %% [markdown]
# ## Support & Resistance

# %% [markdown]
# We normally use multiple moving averages to develop our support and resistance lines. 50 day for medium, 100 for long and 200 for very long terms are commonly used.

# %% [markdown]
# ## Download S&P Data for 5 years

# %%
save_to_csv_from_yahoo(PATH, "^GSPC")
gspc_df = get_stock_df_from_csv("^GSPC")
gspc_df
# Out:
# Get Data for :  ^GSPC
# D:/Python for Finance/Wilshire_Stocks/^GSPC.csv  Saved
#                    Open         High          Low        Close      Volume  \
# Date
# 2016-12-29  2249.500000  2254.510010  2244.560059  2249.260010  2336370000
# 2016-12-30  2251.610107  2253.580078  2233.620117  2238.830078  2670900000
# 2017-01-03  2251.570068  2263.879883  2245.129883  2257.830078  3770530000
# 2017-01-04  2261.600098  2272.820068  2261.600098  2270.750000  3764890000
# 2017-01-05  2268.179932  2271.500000  2260.449951  2269.000000  3761820000
# ...                 ...          ...          ...          ...         ...
# 2021-12-22  4650.359863  4697.669922  4645.529785  4696.560059  2439570000
# 2021-12-23  4703.959961  4740.740234  4703.959961  4725.790039  2194630000
# 2021-12-27  4733.990234  4791.490234  4733.990234  4791.189941  2264120000
# 2021-12-28  4795.490234  4807.020020  4780.040039  4786.350098  2217050000
# 2021-12-29  4788.640137  4800.419922  4778.080078  4789.100098   667622843
#
#             Dividends  Stock Splits
# Date
# 2016-12-29          0             0
# 2016-12-30          0             0
# 2017-01-03          0             0
# 2017-01-04          0             0
# 2017-01-05          0             0
# ...               ...           ...
# 2021-12-22          0             0
# 2021-12-23          0             0
# 2021-12-27          0             0
# 2021-12-28          0             0
# 2021-12-29          0             0
#
# [1259 rows x 7 columns]

# %% [markdown]
# ## Calculate Moving Averages

# %% [markdown]
# Moving averages are used to mitigate short term flucuations in a stock price. We create them by calculating the mean of a set of prices over a specified number of time periods. The Simple moving average (SMA) is just a simple mean. An Exponential Moving Average (EMA) is a weighted average that put more emphasis on more recent data.

# %%
# SMA
gspc_df['MA50'] = gspc_df['Close'].rolling(50).mean()
gspc_df['MA100'] = gspc_df['Close'].rolling(100).mean()

# EMA If we set adjust to False the weighted function is calculated recursively
gspc_df['EMA20'] = gspc_df['Close'].ewm(span=20, adjust=False).mean()
gspc_df['EMA50'] = gspc_df['Close'].ewm(span=50, adjust=False).mean()
gspc_df['EMA100'] = gspc_df['Close'].ewm(span=100, adjust=False).mean()

gspc_df
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 2016-12-29  2249.500000  2254.510010  2244.560059  2249.260010  2336370000
# 2016-12-30  2251.610107  2253.580078  2233.620117  2238.830078  2670900000
# 2017-01-03  2251.570068  2263.879883  2245.129883  2257.830078  3770530000
# 2017-01-04  2261.600098  2272.820068  2261.600098  2270.750000  3764890000
# 2017-01-05  2268.179932  2271.500000  2260.449951  2269.000000  3761820000
# ...                 ...          ...          ...          ...         ...
# 2021-12-22  4650.359863  4697.669922  4645.529785  4696.560059  2439570000
# 2021-12-23  4703.959961  4740.740234  4703.959961  4725.790039  2194630000
# 2021-12-27  4733.990234  4791.490234  4733.990234  4791.189941  2264120000
# 2021-12-28  4795.490234  4807.020020  4780.040039  4786.350098  2217050000
# 2021-12-29  4788.640137  4800.419922  4778.080078  4789.100098   667622843
#
#             Dividends  Stock Splits         MA50        MA100        EMA20  \
# Date
# 2016-12-29          0             0          NaN          NaN  2249.260010
# 2016-12-30          0             0          NaN          NaN  2248.266683
# 2017-01-03          0             0          NaN          NaN  2249.177482
# 2017-01-04          0             0          NaN          NaN  2251.232008
# 2017-01-05          0             0          NaN          NaN  2252.924198
# ...               ...           ...          ...          ...          ...
# 2021-12-22          0             0  4620.479189  4528.501689  4646.065583
# 2021-12-23          0             0  4627.718994  4531.528091  4653.658388
# 2021-12-27          0             0  4634.777598  4535.413389  4666.756632
# 2021-12-28          0             0  4641.077197  4538.985889  4678.146485
# 2021-12-29          0             0  4647.130000  4542.511689  4688.713496
#
#                   EMA50       EMA100
# Date
# 2016-12-29  2249.260010  2249.260010
# 2016-12-30  2248.850993  2249.053476
# 2017-01-03  2249.203114  2249.227271
# 2017-01-04  2250.048090  2249.653463
# 2017-01-05  2250.791302  2250.036563
# ...                 ...          ...
# 2021-12-22  4606.320840  4522.768008
# 2021-12-23  4611.005907  4526.788247
# 2021-12-27  4618.071947  4532.023924
# 2021-12-28  4624.671090  4537.060086
# 2021-12-29  4631.119287  4542.050977
#
# [1259 rows x 12 columns]

# %% [markdown]
# ## Plotting Moving Averages

# %%
fig = go.Figure()

candle = go.Candlestick(x=gspc_df.index, open=gspc_df['Open'],
    high=gspc_df['High'], low=gspc_df['Low'],
    close=gspc_df['Close'], name="Candlestick")

ema50_line = go.Scatter(x=gspc_df.index, y=gspc_df['EMA50'], 
    line=dict(color='rgba(250, 0, 0, 0.75)', 
    width=1), name="EMA50")

ema100_line = go.Scatter(x=gspc_df.index, y=gspc_df['EMA100'], 
    line=dict(color='rgba(0, 250, 0, 0.75)', 
    width=1), name="EMA100")

fig.add_trace(candle)
# 1st support line
fig.add_trace(ema50_line)
# 2nd support line
fig.add_trace(ema100_line)

fig.show()

# What we see with the support line is that if we hit it the market bounces back. When candles are green that means we have more buyers than sellers and vice versa.
# Support levels are good indicators and the market normally only breaks support when an event occurs that is external to the market.
# Out:
# <div>                            <div id="fd5913ea-355d-45dd-b7d7-d1f610109781" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fd5913ea-355d-45dd-b7d7-d1f610109781")) {                    Plotly.newPlot(                        "fd5913ea-355d-45dd-b7d7-d1f610109781",                        [{"close":[2249.260009765625,2238.830078125,2257.830078125,2270.75,2269.0,2276.97998046875,2268.89990234375,2268.89990234375,2275.320068359375,2270.43994140625,2274.639892578125,2267.889892578125,2271.889892578125,2263.68994140625,2271.31005859375,2265.199951171875,2280.070068359375,2298.3701171875,2296.679931640625,2294.68994140625,2280.89990234375,2278.8701171875,2279.550048828125,2280.85009765625,2297.419921875,2292.56005859375,2293.080078125,2294.669921875,2307.8701171875,2316.10009765625,2328.25,2337.580078125,2349.25,2347.219970703125,2351.159912109375,2365.3798828125,2362.820068359375,2363.81005859375,2367.340087890625,2369.75,2363.639892578125,2395.9599609375,2381.919921875,2383.1201171875,2375.31005859375,2368.389892578125,2362.97998046875,2364.8701171875,2372.60009765625,2373.469970703125,2365.449951171875,2385.260009765625,2381.3798828125,2378.25,2373.469970703125,2344.02001953125,2348.449951171875,2345.9599609375,2343.97998046875,2341.590087890625,2358.570068359375,2361.1298828125,2368.06005859375,2362.719970703125,2358.840087890625,2360.159912109375,2352.949951171875,2357.489990234375,2355.5400390625,2357.159912109375,2353.780029296875,2344.929931640625,2328.949951171875,2349.010009765625,2342.18994140625,2338.169921875,2355.840087890625,2348.68994140625,2374.14990234375,2388.610107421875,2387.449951171875,2388.77001953125,2384.199951171875,2388.330078125,2391.169921875,2388.1298828125,2389.52001953125,2399.2900390625,2399.3798828125,2396.919921875,2399.6298828125,2394.43994140625,2390.89990234375,2402.320068359375,2400.669921875,2357.030029296875,2365.719970703125,2381.72998046875,2394.02001953125,2398.419921875,2404.389892578125,2415.070068359375,2415.820068359375,2412.909912109375,2411.800048828125,2430.06005859375,2439.070068359375,2436.10009765625,2429.330078125,2433.139892578125,2433.7900390625,2431.77001953125,2429.389892578125,2440.35009765625,2437.919921875,2432.4599609375,2433.14990234375,2453.4599609375,2437.030029296875,2435.610107421875,2434.5,2438.300048828125,2439.070068359375,2419.3798828125,2440.68994140625,2419.699951171875,2423.409912109375,2429.010009765625,2432.5400390625,2409.75,2425.179931640625,2427.429931640625,2425.530029296875,2443.25,2447.830078125,2459.27001953125,2459.139892578125,2460.610107421875,2473.830078125,2473.449951171875,2472.5400390625,2469.909912109375,2477.1298828125,2477.830078125,2475.419921875,2472.10009765625,2470.300048828125,2476.35009765625,2477.570068359375,2472.159912109375,2476.830078125,2480.909912109375,2474.919921875,2474.02001953125,2438.2099609375,2441.320068359375,2465.840087890625,2464.610107421875,2468.110107421875,2430.010009765625,2425.550048828125,2428.3701171875,2452.510009765625,2444.0400390625,2438.969970703125,2443.050048828125,2444.239990234375,2446.300048828125,2457.590087890625,2471.64990234375,2476.550048828125,2457.85009765625,2465.5400390625,2465.10009765625,2461.429931640625,2488.110107421875,2496.47998046875,2498.3701171875,2495.6201171875,2500.22998046875,2503.8701171875,2506.64990234375,2508.239990234375,2500.60009765625,2502.219970703125,2496.659912109375,2496.840087890625,2507.0400390625,2510.06005859375,2519.360107421875,2529.1201171875,2534.580078125,2537.739990234375,2552.070068359375,2549.330078125,2544.72998046875,2550.639892578125,2555.239990234375,2550.929931640625,2553.169921875,2557.639892578125,2559.360107421875,2561.260009765625,2562.10009765625,2575.2099609375,2564.97998046875,2569.1298828125,2557.149902 ...

# %% [markdown]
# ## Analyzing Bitcoin

# %%
btc_df = yf.download(tickers='BTC-USD', period='3d', interval='15m')
btc_df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                    Open          High           Low  \
# Datetime
# 2021-12-27 00:00:00+00:00  50802.609375  50852.589844  50749.414062
# 2021-12-27 00:15:00+00:00  50911.031250  50949.320312  50849.449219
# 2021-12-27 00:30:00+00:00  50845.812500  50917.070312  50654.527344
# 2021-12-27 00:45:00+00:00  50683.261719  50735.550781  50630.910156
# 2021-12-27 01:00:00+00:00  50655.824219  50655.824219  50499.468750
# ...                                 ...           ...           ...
# 2021-12-29 17:15:00+00:00  47662.640625  47719.015625  47619.195312
# 2021-12-29 17:30:00+00:00  47644.984375  47687.628906  47543.664062
# 2021-12-29 17:45:00+00:00  47655.484375  47712.144531  47517.117188
# 2021-12-29 18:00:00+00:00  47550.507812  47668.429688  47550.507812
# 2021-12-29 18:14:02+00:00  47561.031250  47561.031250  47561.031250
#
#                                   Close     Adj Close    Volume
# Datetime
# 2021-12-27 00:00:00+00:00  50807.171875  50807.171875         0
# 2021-12-27 00:15:00+00:00  50931.328125  50931.328125  72159232
# 2021-12-27 00:30:00+00:00  50690.718750  50690.718750  35293184
# 2021-12-27 00:45:00+00:00  50630.910156  50630.910156  63633408
# 2021-12-27 01:00:00+00:00  50521.007812  50521.007812  67692544
# ...                                 ...           ...       ...
# 2021-12-29 17:15:00+00:00  47657.976562  47657.976562         0
# 2021-12-29 17:30:00+00:00  47687.628906  47687.628906  17651712
# 2021-12-29 17:45:00+00:00  47572.785156  47572.785156  20891648
# 2021-12-29 18:00:00+00:00  47592.734375  47592.734375   9199616
# 2021-12-29 18:14:02+00:00  47561.031250  47561.031250         0
#
# [266 rows x 6 columns]

# %%
# We'll create a short term moving average using 5 periods
# and another using 20 periods
# When the longterm MA goes above the short term that is a sell sign
# and vice versa
btc_df['MA5'] = btc_df['Close'].rolling(5).mean()
btc_df['MA20'] = btc_df['Close'].rolling(20).mean()

# %% [markdown]
# ## Plot

# %%
fig = go.Figure()

candle = go.Candlestick(x=btc_df.index, open=btc_df['Open'],
    high=btc_df['High'], low=btc_df['Low'],
    close=btc_df['Close'], name="Candlestick")

ma5_line = go.Scatter(x=btc_df.index, y=btc_df['MA5'], 
    line=dict(color='rgba(255,165,0, 0.75)', 
    width=1), name="MA5")

ma20_line = go.Scatter(x=btc_df.index, y=btc_df['MA20'], 
    line=dict(color='rgba(0, 0, 250, 0.75)', 
    width=1), name="MA20")

fig.add_trace(candle)
fig.add_trace(ma5_line)
fig.add_trace(ma20_line)

fig.show()

# When the MA20 (Blue) crosses above the MA5 (Orange) that is a Death Cross (Sell)
# When the MA5 (Orange) crosses above the MA20 (Blue)that is a Golden Cross (Buy)
# Out:
# <div>                            <div id="f62daa00-a4a3-4703-a215-bacf32364959" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f62daa00-a4a3-4703-a215-bacf32364959")) {                    Plotly.newPlot(                        "f62daa00-a4a3-4703-a215-bacf32364959",                        [{"close":[50807.171875,50931.328125,50690.71875,50630.91015625,50521.0078125,50701.00390625,50677.59375,50874.21875,50750.140625,50794.14453125,50862.75,50861.55078125,50933.7578125,51065.22265625,51083.0078125,50975.96875,51039.81640625,50904.4375,50987.51171875,51020.8828125,50946.93359375,50962.9140625,50957.8203125,50917.17578125,50788.56640625,50899.17578125,50953.921875,50961.3046875,50925.38671875,50891.109375,50836.92578125,50798.8046875,50860.65234375,50883.1796875,50829.921875,50658.19921875,50649.13671875,50675.60546875,50612.578125,50754.09765625,50778.26171875,50749.33203125,50728.23828125,50894.59375,50862.24609375,50745.72265625,50784.734375,50688.32421875,50680.73046875,50713.67578125,51075.546875,51056.55078125,51025.484375,51304.0625,51218.47265625,51298.78515625,51360.40234375,51312.3125,51604.29296875,51600.7421875,51561.30859375,51513.953125,51457.04296875,51462.0546875,51398.05859375,51355.171875,51365.61328125,51505.21875,51533.9140625,51768.58203125,51953.625,51818.16796875,51777.9921875,51707.37890625,51721.59375,51688.55078125,51579.8828125,51496.9921875,51481.40625,51286.5390625,51353.015625,51159.9921875,50987.70703125,51258.6015625,51205.94921875,51292.2578125,51252.02734375,50992.83203125,51091.90625,51128.734375,50984.7890625,50978.40625,50959.015625,50893.328125,50813.24609375,50729.48046875,50548.51953125,50328.265625,50266.98046875,50388.4765625,50195.66796875,50245.97265625,49869.57421875,49881.2265625,49814.15625,49814.78515625,49853.6171875,49823.25390625,49566.8671875,49703.33984375,49657.73828125,49838.79296875,49703.765625,48963.4453125,49096.4140625,49161.80078125,49188.9921875,48978.92578125,49203.98046875,49298.40625,49178.02734375,49281.1484375,49289.171875,49209.13671875,49315.703125,49218.05859375,49174.07421875,49257.44140625,49419.921875,49419.50390625,49403.54296875,49458.7265625,49362.61328125,49370.84765625,49238.30078125,49125.9140625,48960.61328125,49061.8359375,49048.72265625,49051.859375,49028.22265625,49166.515625,49148.3828125,49237.2578125,49144.50390625,49281.71875,49264.5703125,49158.4296875,49119.74609375,49161.62890625,49277.328125,49031.34765625,48955.29296875,49045.40625,48854.79296875,49124.39453125,49020.2109375,49055.875,48969.71484375,48970.7109375,48612.30859375,48286.7734375,48533.03515625,48649.9921875,48416.984375,48155.7890625,47865.71484375,47978.671875,47930.9453125,47926.078125,47946.2109375,47836.828125,47552.203125,47571.41796875,47760.7109375,47732.66015625,47746.26171875,47867.953125,47964.12109375,47760.05078125,47817.8828125,47762.9375,47746.109375,47669.5859375,47575.4140625,47580.66015625,47534.296875,47723.4765625,47665.8984375,47738.81640625,47804.3984375,47657.25390625,47768.60546875,47776.48046875,47675.26953125,47777.26171875,47901.421875,47924.30078125,47844.0546875,47746.4765625,47903.23828125,47949.2265625,47960.51953125,48029.73828125,48090.80078125,48007.30859375,48008.765625,48023.34375,47938.30078125,47901.0234375,47963.53125,47849.37109375,47843.9609375,47837.4296875,47800.58984375,47932.921875,47947.7265625,47965.265625,47939.3359375,47833.34375,47731.72265625,47684.91015625,47652.90625,47603.02734375,47717.3515625,47674.5,47729.14453125,47728.69140625,47731.87109375,47523.74609375,47628.3125,48000.68359375,47904.83984375,47791.40234375,47798.01171875,47714.12109375,47667.35546875,47632.89453125,47678.8203125,47744.57421875,47070.5546875,46865.765625,46903.30859375,46913.41796875,46907.34765625,46730.20703125, ...

# %% [markdown]
# ## Longterm Bitcoin

# %%
# btcl_df = yf.download(tickers='BTC-USD', period='3mo', interval='1d')
# btcl_df

# %%
# btcl_df['MA5'] = btcl_df['Close'].rolling(5).mean()
# btcl_df['MA20'] = btcl_df['Close'].rolling(20).mean()

# %%
# fig = go.Figure()

# candle = go.Candlestick(x=btcl_df.index, open=btcl_df['Open'],
#     high=btcl_df['High'], low=btcl_df['Low'],
#     close=btcl_df['Close'], name="Candlestick")

# ma5_line = go.Scatter(x=btcl_df.index, y=btcl_df['MA5'], 
#     line=dict(color='rgba(255,165,0, 0.75)', 
#     width=1), name="MA5")

# ma20_line = go.Scatter(x=btcl_df.index, y=btcl_df['MA20'], 
#     line=dict(color='rgba(0, 0, 250, 0.75)', 
#     width=1), name="MA20")

# fig.add_trace(candle)
# fig.add_trace(ma5_line)
# fig.add_trace(ma20_line)

# fig.show()

# We see here that we are in a down trend long term

# %% [markdown]
# ## Short Term Plot Function

# %%
def get_short_ma(ticker):
    df = yf.download(tickers=ticker, period='3d', interval='15m')
    df['MA5'] = df['Close'].rolling(5).mean()
    df['MA20'] = df['Close'].rolling(20).mean()
    fig = go.Figure()

    candle = go.Candlestick(x=df.index, open=df['Open'],
        high=df['High'], low=df['Low'],
        close=df['Close'], name="Candlestick")

    ma5_line = go.Scatter(x=df.index, y=df['MA5'], 
    line=dict(color='rgba(255,165,0, 0.75)', 
    width=1), name="MA5")

    ma20_line = go.Scatter(x=df.index, y=df['MA20'], 
    line=dict(color='rgba(0, 0, 250, 0.75)', 
    width=1), name="MA20")

    fig.add_trace(candle)
    fig.add_trace(ma5_line)
    fig.add_trace(ma20_line)

    fig.show()

# %% [markdown]
# ## Long Term Plot Function

# %%
def get_long_ma(ticker):
    df = yf.download(tickers=ticker, period='3mo', interval='1d')
    df['MA5'] = df['Close'].rolling(5).mean()
    df['MA20'] = df['Close'].rolling(20).mean()
    fig = go.Figure()

    candle = go.Candlestick(x=df.index, open=df['Open'],
        high=df['High'], low=df['Low'],
        close=df['Close'], name="Candlestick")

    ma5_line = go.Scatter(x=df.index, y=df['MA5'], 
    line=dict(color='rgba(255,165,0, 0.75)', 
    width=1), name="MA5")

    ma20_line = go.Scatter(x=df.index, y=df['MA20'], 
    line=dict(color='rgba(0, 0, 250, 0.75)', 
    width=1), name="MA20")

    fig.add_trace(candle)
    fig.add_trace(ma5_line)
    fig.add_trace(ma20_line)

    fig.show()

# %% [markdown]
# ## Long Term Ethereum Plot

# %%
# get_long_ma('ETH-USD')

# %% [markdown]
# ## Short Term Ethereum Plot

# %%
get_short_ma('ETH-USD')
# Out:
# [*********************100%***********************]  1 of 1 completed
# <div>                            <div id="556d5973-4f7f-4a77-ad37-ffa7e4845a9b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("556d5973-4f7f-4a77-ad37-ffa7e4845a9b")) {                    Plotly.newPlot(                        "556d5973-4f7f-4a77-ad37-ffa7e4845a9b",                        [{"close":[4069.781005859375,4076.08349609375,4065.9658203125,4062.51318359375,4055.14453125,4068.517822265625,4062.273681640625,4081.233642578125,4074.4140625,4078.377685546875,4080.06005859375,4071.9228515625,4069.904052734375,4087.22607421875,4086.357666015625,4082.89013671875,4075.436767578125,4069.40771484375,4072.66650390625,4068.0869140625,4069.345458984375,4068.487548828125,4069.0341796875,4063.14013671875,4058.2177734375,4063.54833984375,4072.29345703125,4069.80908203125,4067.21826171875,4070.7431640625,4057.962646484375,4058.842041015625,4064.03857421875,4065.106201171875,4060.01416015625,4042.437744140625,4046.76025390625,4047.135986328125,4048.12060546875,4052.90966796875,4058.49267578125,4058.56591796875,4055.034912109375,4059.3369140625,4068.350830078125,4054.501220703125,4062.07080078125,4056.58251953125,4051.697998046875,4058.99365234375,4079.055419921875,4078.40380859375,4078.539794921875,4091.21044921875,4088.6953125,4091.044189453125,4094.443603515625,4086.425537109375,4099.40673828125,4102.17822265625,4100.64111328125,4099.21044921875,4094.09375,4094.19970703125,4091.994140625,4085.6865234375,4091.13671875,4092.837646484375,4098.07763671875,4113.10009765625,4123.70556640625,4114.609375,4115.7705078125,4102.42236328125,4102.421875,4099.68896484375,4096.43798828125,4082.9853515625,4086.130615234375,4079.7880859375,4087.437744140625,4073.245361328125,4067.139404296875,4092.70166015625,4080.859375,4082.2353515625,4080.3125,4060.11572265625,4070.571044921875,4065.654052734375,4054.075439453125,4062.658935546875,4060.39404296875,4046.224365234375,4044.44140625,4044.028564453125,4032.175537109375,4021.784912109375,4020.584716796875,4031.687744140625,4014.686767578125,4022.48486328125,3991.0322265625,3984.64501953125,3985.45751953125,3985.40478515625,3979.12353515625,3971.604248046875,3937.981201171875,3954.48583984375,3947.54931640625,3964.556640625,3942.40283203125,3900.622314453125,3912.48193359375,3919.31884765625,3917.59716796875,3906.263916015625,3917.498291015625,3929.434326171875,3917.736328125,3931.26171875,3931.975341796875,3922.988525390625,3921.7041015625,3912.771728515625,3909.2978515625,3919.81396484375,3930.565673828125,3927.510498046875,3925.17431640625,3923.8837890625,3916.789794921875,3913.614501953125,3901.836669921875,3895.469970703125,3895.457275390625,3906.27294921875,3904.402099609375,3905.349609375,3902.241943359375,3912.83349609375,3917.570556640625,3924.15478515625,3910.71240234375,3916.3994140625,3920.5537109375,3912.23095703125,3911.217041015625,3912.884521484375,3924.720947265625,3910.754150390625,3902.40380859375,3912.412109375,3889.87744140625,3917.17236328125,3907.106201171875,3913.855712890625,3900.250732421875,3900.77978515625,3868.863525390625,3838.583740234375,3858.370849609375,3868.5390625,3844.564697265625,3812.487060546875,3799.15771484375,3823.282470703125,3804.7734375,3807.23193359375,3815.668212890625,3804.03759765625,3786.394775390625,3787.846923828125,3811.594482421875,3810.068359375,3812.2685546875,3824.52392578125,3837.322998046875,3823.533935546875,3833.450439453125,3825.720947265625,3817.015869140625,3812.651611328125,3804.79248046875,3808.2509765625,3809.608642578125,3818.292724609375,3807.710693359375,3815.970947265625,3814.23876953125,3800.959716796875,3819.678466796875,3813.759765625,3803.337646484375,3819.2373046875,3824.07568359375,3820.475830078125,3806.18798828125,3804.758056640625,3814.66064453125,3817.9462890625,3818.08935546875,3821.2373 ...

# %% [markdown]
# ## Long Term Litecoin

# %%
# get_long_ma('LTC-USD')

# %% [markdown]
# ## Long Term Cardano

# %%
# get_long_ma('ADA-USD')

# %% [markdown]
# ## Get Stock File Names in a List

# %%
files = [x for x in listdir(PATH) if isfile(join(PATH, x))]
tickers = [os.path.splitext(x)[0] for x in files]
tickers
# tickers.remove('.ds_Store')
tickers.sort()
len(tickers)
# Out:
# 3000

# %% [markdown]
# ## Add Daily & Cumulative Return to All Stock Data

# %%
for x in tickers:
    try:
        print("Working on :", x)
        new_df = get_stock_df_from_csv(x)
        new_df = add_daily_return_to_df(new_df, x)
        new_df = add_cum_return_to_df(new_df, x)
        new_df.to_csv(PATH + x + '.csv')
    except Exception as ex:
        print(ex)
# Out:
# Working on : A
# Working on : AA
# Working on : AAL
# Working on : AAME
# Working on : AAN
# Working on : AAOI
# Working on : AAON
# Working on : AAP
# Working on : AAPL
# Working on : AAT
# Working on : AAWW
# Working on : AAXN
# Working on : ABBV
# Working on : ABC
# Working on : ABCB
# Working on : ABEO
# Working on : ABG
# Working on : ABIO
# Working on : ABM
# Working on : ABMD
# Working on : ABR
# Working on : ABT
# Working on : ABTX
# Working on : AC
# Working on : ACA
# Working on : ACAD
# Working on : ACBI
# Working on : ACC
# Working on : ACCO
# Working on : ACER
# Working on : ACGL
# Working on : ACHC
# Working on : ACHV
# Working on : ACIW
# Working on : ACLS
# Working on : ACM
# Working on : ACMR
# Working on : ACN
# Working on : ACNB
# Working on : ACOR
# Working on : ACRE
# Working on : ACRS
# Working on : ACRX
# Working on : ACTG
# Working on : ACU
# Working on : ACY
# Working on : ADBE
# Working on : ADC
# Working on : ADES
# Working on : ADI
# Working on : ADM
# Working on : ADMA
# Working on : ADMP
# Working on : ADMS
# Working on : ADNT
# Working on : ADP
# Working on : ADS
# Working on : ADSK
# Working on : ADT
# Working on : ADTN
# Working on : ADUS
# Working on : ADVM
# Working on : ADXS
# Working on : AE
# Working on : AEE
# Working on : AEHR
# Working on : AEIS
# Working on : AEL
# Working on : AEMD
# Working on : AEO
# Working on : AEP
# Working on : AERI
# Working on : AES
# Working on : AEY
# Working on : AFG
# Working on : AFI
# Working on : AFIN
# Working on : AFL
# Working on : AGCO
# Working on : AGE
# Working on : AGEN
# Working on : AGFS
# Working on : AGIO
# Working on : AGLE
# Working on : AGM
# Working on : AGNC
# Working on : AGO
# Working on : AGR
# Working on : AGRX
# Working on : AGS
# Working on : AGTC
# Working on : AGX
# Working on : AGYS
# Working on : AHH
# Working on : AIG
# Working on : AIMC
# Working on : AIN
# Working on : AINC
# Working on : AIR
# Working on : AIRG
# Working on : AIRI
# Working on : AIRT
# Working on : AIT
# Working on : AIV
# Working on : AIZ
# Working on : AJG
# Working on : AJRD
# Working on : AJX
# Working on : AKAM
# Working on : AKBA
# Working on : AKR
# Working on : AKTS
# Working on : AL
# Working on : ALB
# Working on : ALBO
# Working on : ALCO
# Working on : ALDX
# Working on : ALE
# Working on : ALEC
# Working on : ALEX
# Working on : ALG
# Working on : ALGN
# Working on : ALGT
# Working on : ALIM
# Working on : ALJJ
# Working on : ALK
# Working on : ALKS
# Working on : ALL
# Working on : ALLE
# Working on : ALLK
# Working on : ALLO
# Working on : ALLY
# Working on : ALNA
# Working on : ALNY
# Working on : ALOT
# Working on : ALPN
# Working on : ALRM
# Working on : ALSN
# Working on : ALT
# Working on : ALTM
# Working on : ALTR
# Working on : ALV
# Working on : ALX
# Working on : AM
# Working on : AMAL
# Working on : AMAT
# Working on : AMBC
# Working on : AMC
# Working on : AMCX
# Working on : AMD
# Working on : AME
# Working on : AMED
# Working on : AMG
# Working on : AMGN
# Working on : AMH
# Working on : AMKR
# Working on : AMN
# Working on : AMNB
# Working on : AMOT
# Working on : AMP
# Working on : AMPE
# Working on : AMPH
# Working on : AMRC
# Working on : AMRK
# Working on : AMRS
# Working on : AMRX
# Working on : AMS
# Working on : AMSC
# Working on : AMSF
# Working on : AMSWA
# Working on : AMT
# Working on : AMTX
# Working on : AMWD
# Working on : AMZN
# Working on : AN
# Working on : ANAB
# Working on : ANAT
# Working on : ANDE
# Working on : ANET
# Working on : ANF
# Working on : ANGI
# Working on : ANGO
# Working on : ANIK
# Working on : ANIP
# Working on : ANSS
# Working on : ANTM
# Working on : AON
# Working on : AOS
# Working on : AOSL
# Working on : AP
# Working on : APA
# Working on : APAM
# Working on : APD
# Working on : APDN
# Working on : APEI
# Working on : APEN
# Working on : APH
# Working on : APLE
# Working on : APLS
# Working on : APOG
# Working on : APPF
# Working on : APPN
# Working on : APPS
# Working on : APRN
# Working on : APT
# Working on : APTS
# Working on : APTV
# Working on : APVO
# Working on : APYX
# Working on : AQB
# Working on : AQMS
# Working on : AQUA
# Working on : AR
# Working on : ARAV
# Working on : ARAY
# Working on : ARC
# Working on : ARCB
# Working on : ARCH
# Working on : ARDX
# Working on : ARE
# Working on : ARES
# Working on : ARGO
# Working on : ARI
# Working on : ARKR
# Working on : ARL
# Working on : ARLO
# Working on : ARMK
# Working on : ARNA
# Working on : ARNC
# Working on : AROC
# Working on : AROW
# Working on : ARR
# Working on : ARTNA
# Working on : ARTW
# Working on : ARVN
# Working on : ARW
# Working on : ARWR
# Working on : ASB
# Working on : ASGN
# Working on : ASH
# Working on : ASIX
# Working on : ASMB
# Working on : ASPN
# Working on : ASPS
# Working on : ASRT
# Working on : ASRV
# Working on : ASTC
# Working on : ASTE
# Working on : ASUR
# Working on : ASYS
# Working on : ATEC
# Working on : ATEN
# Working on : ATGE
# Working on : ATH
# Working on : ATHX
# Working on : ATI
# Working on : ATKR
# Working on : ATLC
# Working on : ATLO
# Working on : ATNI
# Working on : ATNM
# Working on : ATNX
# Working on : ATO
# Working on : ATOS
# Working on : ATR
# Working on : ATRA
# Working on : ATRC
# Working on : ATRI
# Working on : ATRO
# Working on : ATRS
# Working on : ATSG
# Working on : ATUS
# Working on : ATVI
# Working on : AUBN
# Working on : AUMN
# Working on : AUTO
# Working on : AVA
# Working on : AVAV
# Working on : AVB
# Working on : AVD
# Working on : AVEO
# Working on : AVGO
# Working on : AVGR
# Working on : AVID
# Working on : AVLR
# Working on : AVNS
# Working on : AVNW
# Working on : AVRO
# Working on : AVT
# Working on : AVTR
# Working on : AVXL
# Working on : AVY
# Working on : AVYA
# Working on : AWI
# Working on : AWK
# Working on : AWR
# Working on : AWRE
# Working on : AX
# Working on : AXAS
# Working on : AXDX
# Working on : AXGN
# Working on : AXL
# Working on : AXNX
# Working on : AXP
# Working on : AXR
# Working on : AXS
# Working on : AXSM
# Working on : AXTA
# Working on : AXTI
# Working on : AYI
# Working on : AYX
# Working on : AZO
# Working on : AZPN
# Working on : AZZ
# Working on : B
# Working on : BA
# Working on : BAC
# Working on : BAH
# Working on : BANC
# Working on : BAND
# Working on : BANF
# Working on : BANR
# Working on : BATRA
# Working on : BATRK
# Working on : BAX
# Working on : BBBY
# Working on : BBCP
# Working on : BBGI
# Working on : BBSI
# Working on : BBW
# Working on : BBY
# Working on : BC
# Working on : BCBP
# Working on : BCC
# Working on : BCEI
# Working on : BCLI
# Working on : BCO
# Working on : BCOR
# Working on : BCOV
# Working on : BCPC
# Working on : BCRX
# Working on : BDC
# Working on : BDL
# Working on : BDN
# Working on : BDSI
# Working on : BDX
# Working on : BE
# Working on : BEAT
# Working on : BECN
# Working on : BELFA
# Working on : BELFB
# Working on : BEN
# Working on : BERY
# Working on : BFAM
# Working on : BFIN
# Working on : BFS
# Working on : BFST
# Working on : BG
# Working on : BGCP
# Working on : BGFV
# Working on : BGS
# Working on : BGSF
# Working on : BH
# Working on : BHB
# Working on : BHE
# Working on : BHF
# Working on : BHLB
# Working on : BHR
# Working on : BHVN
# Working on : BIG
# Working on : BIIB
# Working on : BIO
# Working on : BIOC
# Working on : BIOL
# Working on : BJ
# Working on : BJRI
# Working on : BK
# Working on : BKD
# Working on : BKE
# Working on : BKH
# Working on : BKI
# Working on : BKNG
# Working on : BKSC
# Working on : BKTI
# Working on : BKU
# Working on : BL
# Working on : BLBD
# Working on : BLCM
# Working on : BLD
# Working on : BLDR
# Working on : BLFS
# Working on : BLK
# Working on : BLKB
# Working on : BLL
# Working on : BLMN
# Working on : BLUE
# Working on : BMI
# Working on : BMRC
# Working on : BMRN
# Working on : BMTC
# Working on : BMY
# Working on : BNED
# Working on : BNFT
# Working on : BOH
# Working on : BOKF
# Working on : BOMN
# Working on : BOOM
# Working on : BOOT
# Working on : BOTJ
# Working on : BOX
# Working on : BPMC
# Working on : BPOP
# Working on : BPRN
# Working on : BPTH
# Working on : BR
# Working on : BRC
# Working on : BRG
# Working on : BRID
# Working on : BRKL
# Working on : BRKR
# Working on : BRKS
# Working on : BRN
# Working on : BRO
# Working on : BRT
# Working on : BRX
# Working on : BRY
# Working on : BSET
# Working on : BSGM
# Working on : BSQR
# Working on : BSRR
# Working on : BSX
# Working on : BTN
# Working on : BTU
# Working on : BURL
# Working on : BUSE
# Working on : BV
# Working on : BW
# Working on : BWA
# Working on : BWEN
# Working on : BWFG
# Working on : BWXT
# Working on : BXC
# Working on : BXMT
# Working on : BXP
# Working on : BXS
# Working on : BY
# Working on : BYD
# Working on : BYFC
# Working on : BYND
# Working on : BZH
# Working on : C
# Working on : CABO
# Working on : CAC
# Working on : CACC
# Working on : CACI
# Working on : CADE
# Working on : CAG
# Working on : CAH
# Working on : CAI
# Working on : CAKE
# Working on : CAL
# Working on : CALA
# Working on : CALM
# Working on : CALX
# Working on : CAMP
# Working on : CAPR
# Working on : CAR
# Working on : CARA
# Working on : CARG
# Working on : CARS
# Working on : CASH
# Working on : CASI
# Working on : CASS
# Working on : CASY
# Working on : CAT
# Working on : CATC
# Working on : CATO
# Working on : CATY
# Working on : CB
# Working on : CBAN
# Working on : CBAY
# Working on : CBFV
# Working on : CBIO
# Working on : CBOE
# Working on : CBRE
# Working on : CBRL
# Working on : CBS
# Working on : CBSH
# Working on : CBT
# Working on : CBTX
# Working on : CBU
# Working on : CBZ
# Working on : CC
# Working on : CCBG
# Working on : CCF
# Working on : CCI
# Working on : CCK
# Working on : CCL
# Working on : CCMP
# Working on : CCNE
# Working on : CCO
# Working on : CCOI
# Working on : CCRN
# Working on : CCS
# Working on : CCXI
# Working on : CDAY
# Working on : CDE
# Working on : CDEV
# Working on : CDK
# Working on : CDLX
# Working on : CDMO
# Working on : CDNA
# Working on : CDNS
# Working on : CDR
# Working on : CDTX
# Working on : CDW
# Working on : CDXC
# Working on : CDXS
# Working on : CDZI
# Working on : CE
# Working on : CECE
# Working on : CEI
# Working on : CEIX
# Working on : CELC
# Working on : CELH
# Working on : CEMI
# Working on : CENT
# Working on : CENTA
# Working on : CENX
# Working on : CERN
# Working on : CERS
# Working on : CETX
# Working on : CEVA
# Working on : CF
# Working on : CFBK
# Working on : CFFI
# Working on : CFFN
# Working on : CFG
# Working on : CFMS
# Working on : CFR
# Working on : CFX
# Working on : CGNX
# Working on : CHCI
# Working on : CHCO
# Working on : CHCT
# Working on : CHD
# Working on : CHDN
# Working on : CHE
# Working on : CHEF
# Working on : CHGG
# Working on : CHH
# Working on : CHK
# Working on : CHMA
# Working on : CHMG
# Working on : CHMI
# Working on : CHRS
# Working on : CHRW
# Working on : CHS
# Working on : CHTR
# Working on : CHUY
# Working on : CI
# Working on : CIA
# Working on : CIDM
# Working on : CIEN
# Working on : CIM
# Working on : CINF
# Working on : CIO
# Working on : CIR
# Working on : CIT
# Working on : CIVB
# Working on : CIX
# Working on : CIZN
# Working on : CKX
# Working on : CL
# Working on : CLAR
# Working on : CLB
# Working on : CLBS
# Working on : CLDT
# Working on : CLDX
# Working on : CLF
# Working on : CLFD
# Working on : CLH
# Working on : CLI
# Working on : CLIR
# Working on : CLNE
# Working on : CLPR
# Working on : CLR
# Working on : CLRB
# Working on : CLRO
# Working on : CLSN
# Working on : CLVS
# Working on : CLW
# Working on : CLX
# Working on : CLXT
# Working on : CMA
# Working on : CMC
# Working on : CMCO
# Working on : CMCSA
# Working on : CMCT
# Working on : CME
# Working on : CMG
# Working on : CMI
# Working on : CMO
# Working on : CMP
# Working on : CMRX
# Working on : CMS
# Working on : CMT
# Working on : CMTL
# Working on : CNA
# Working on : CNBKA
# Working on : CNC
# Working on : CNCE
# Working on : CNDT
# Working on : CNFR
# Working on : CNK
# Working on : CNMD
# Working on : CNNE
# Working on : CNO
# Working on : CNOB
# Working on : CNP
# Working on : CNS
# Working on : CNSL
# Working on : CNTY
# Working on : CNX
# Working on : CNXN
# Working on : CODA
# Working on : COF
# Working on : COHN
# Working on : COHR
# Working on : COHU
# Working on : COKE
# Working on : COLB
# Working on : COLD
# Working on : COLL
# Working on : COLM
# Working on : COMM
# Working on : CONE
# Working on : CONN
# Working on : COO
# Working on : COOP
# Working on : COP
# Working on : COR
# Working on : CORR
# Working on : CORT
# Working on : COST
# Working on : COTY
# Working on : COUP
# Working on : COWN
# Working on : CPB
# Working on : CPE
# Working on : CPF
# Working on : CPHC
# Working on : CPIX
# Working on : CPK
# Working on : CPLG
# Working on : CPRI
# Working on : CPRT
# Working on : CPRX
# Working on : CPS
# Working on : CPSH
# Working on : CPSI
# Working on : CPSS
# Working on : CPT
# Working on : CR
# Working on : CRAI
# Working on : CRBP
# Working on : CRC
# Working on : CRI
# Working on : CRIS
# Working on : CRK
# Working on : CRL
# Working on : CRM
# Working on : CRMD
# Working on : CRMT
# Working on : CRNX
# Working on : CROX
# Working on : CRS
# Working on : CRTX
# Working on : CRUS
# Working on : CRVL
# Working on : CRVS
# Working on : CRWS
# Working on : CRY
# Working on : CSCO
# Working on : CSGP
# Working on : CSGS
# Working on : CSII
# Working on : CSL
# Working on : CSLT
# Working on : CSOD
# Working on : CSPI
# Working on : CSTR
# Working on : CSU
# Working on : CSV
# Working on : CSWI
# Working on : CSX
# Working on : CTAS
# Working on : CTBI
# Working on : CTG
# Working on : CTHR
# Working on : CTIB
# Working on : CTIC
# Working on : CTLT
# Working on : CTMX
# Working on : CTO
# Working on : CTRE
# Working on : CTRN
# Working on : CTS
# Working on : CTSH
# Working on : CTSO
# Working on : CTT
# Working on : CTXS
# Working on : CUBE
# Working on : CUBI
# Working on : CUE
# Working on : CULP
# Working on : CURO
# Working on : CUTR
# Working on : CUZ
# Working on : CVA
# Working on : CVBF
# Working on : CVCO
# Working on : CVCY
# Working on : CVGI
# Working on : CVGW
# Working on : CVI
# Working on : CVLT
# Working on : CVLY
# Working on : CVM
# Working on : CVNA
# Working on : CVR
# Working on : CVS
# Working on : CVU
# Working on : CVV
# Working on : CVX
# Working on : CW
# Working on : CWBC
# Working on : CWBR
# Working on : CWEN
# Working on : CWH
# Working on : CWST
# Working on : CWT
# Working on : CXP
# Working on : CXW
# Working on : CYAN
# Working on : CYBE
# Working on : CYCC
# Working on : CYH
# Working on : CYRX
# Working on : CYTK
# Working on : CYTR
# Working on : CZNC
# Working on : CZR
# Working on : CZWI
# Working on : D
# Working on : DAIO
# Working on : DAKT
# Working on : DAL
# Working on : DAN
# Working on : DAR
# Working on : DARE
# Working on : DBD
# Working on : DBI
# Working on : DBX
# Working on : DCI
# Working on : DCO
# Working on : DCOM
# Working on : DCPH
# Working on : DD
# Working on : DDD
# Working on : DDS
# Working on : DE
# Working on : DEA
# Working on : DECK
# Working on : DEI
# Working on : DELL
# Working on : DENN
# Working on : DFIN
# Working on : DFS
# Working on : DG
# Working on : DGICA
# Working on : DGII
# Working on : DGLY
# Working on : DGX
# Working on : DHI
# Working on : DHIL
# Working on : DHR
# Working on : DHX
# Working on : DIN
# Working on : DIOD
# Working on : DIS
# Working on : DISCA
# Working on : DISCK
# Working on : DISH
# Working on : DIT
# Working on : DJCO
# Working on : DK
# Working on : DKS
# Working on : DLA
# Working on : DLB
# Working on : DLHC
# Working on : DLR
# Working on : DLTH
# Working on : DLTR
# Working on : DLX
# Working on : DMRC
# Working on : DNLI
# Working on : DNOW
# Working on : DOC
# Working on : DOCU
# Working on : DOMO
# Working on : DOOR
# Working on : DORM
# Working on : DOV
# Working on : DOW
# Working on : DPZ
# Working on : DRE
# Working on : DRH
# Working on : DRI
# Working on : DRNA
# Working on : DRQ
# Working on : DRRX
# Working on : DS
# Working on : DSKE
# Working on : DSPG
# Working on : DSS
# Working on : DTE
# Working on : DUK
# Working on : DVA
# Working on : DVAX
# Working on : DVD
# Working on : DVN
# Working on : DWSN
# Working on : DX
# Working on : DXC
# Working on : DXCM
# Working on : DXLG
# Working on : DXPE
# Working on : DXYN
# Working on : DY
# Working on : DZSI
# Working on : EA
# Working on : EAF
# Working on : EARN
# Working on : EAT
# Working on : EB
# Working on : EBAY
# Working on : EBF
# Working on : EBIX
# Working on : EBMT
# Working on : EBS
# Working on : EBSB
# Working on : EBTC
# Working on : ECHO
# Working on : ECL
# Working on : ECOL
# Working on : ECOM
# Working on : ECPG
# Working on : ED
# Working on : EDIT
# Working on : EDUC
# Working on : EEFT
# Working on : EEX
# Working on : EFC
# Working on : EFOI
# Working on : EFSC
# Working on : EFX
# Working on : EGAN
# Working on : EGBN
# Working on : EGHT
# Working on : EGLE
# Working on : EGP
# Working on : EGRX
# Working on : EGY
# Working on : EHC
# Working on : EHTH
# Working on : EIG
# Working on : EIGR
# Working on : EIX
# Working on : EKSO
# Working on : EL
# Working on : ELAN
# Working on : ELF
# Working on : ELMD
# Working on : ELOX
# Working on : ELS
# Working on : ELSE
# Working on : ELVT
# Working on : ELY
# Working on : EMAN
# Working on : EMCF
# Working on : EME
# Working on : EMKR
# Working on : EML
# Working on : EMMS
# Working on : EMN
# Working on : EMR
# Working on : ENDP
# Working on : ENG
# Working on : ENOB
# Working on : ENPH
# Working on : ENR
# Working on : ENS
# Working on : ENSG
# Working on : ENSV
# Working on : ENTA
# Working on : ENTG
# Working on : ENV
# Working on : ENVA
# Working on : ENZ
# Working on : EOG
# Working on : EOLS
# Working on : EPAM
# Working on : EPAY
# Working on : EPC
# Working on : EPM
# Working on : EPR
# Working on : EPRT
# Working on : EPZM
# Working on : EQBK
# Working on : EQC
# Working on : EQH
# Working on : EQIX
# Working on : EQR
# Working on : EQT
# Working on : ERIE
# Working on : ERII
# Working on : ES
# Working on : ESBK
# Working on : ESCA
# Working on : ESE
# Working on : ESNT
# Working on : ESP
# Working on : ESPR
# Working on : ESRT
# Working on : ESS
# Working on : ESSA
# Working on : ESTC
# Working on : ESTE
# Working on : ESXB
# Working on : ETN
# Working on : ETR
# Working on : ETRN
# Working on : ETSY
# Working on : EVBG
# Working on : EVBN
# Working on : EVC
# Working on : EVER
# Working on : EVFM
# Working on : EVH
# Working on : EVI
# Working on : EVOK
# Working on : EVOL
# Working on : EVOP
# Working on : EVR
# Working on : EVRG
# Working on : EVRI
# Working on : EVTC
# Working on : EW
# Working on : EWBC
# Working on : EXAS
# Working on : EXC
# Working on : EXEL
# Working on : EXLS
# Working on : EXP
# Working on : EXPD
# Working on : EXPE
# Working on : EXPI
# Working on : EXPO
# Working on : EXPR
# Working on : EXR
# Working on : EXTN
# Working on : EXTR
# Working on : EYE
# Working on : EYEG
# Working on : EYES
# Working on : EYPT
# Working on : EZPW
# Working on : F
# Working on : FAF
# Working on : FANG
# Working on : FARM
# Working on : FARO
# Working on : FAST
# Working on : FATE
# Working on : FB
# Working on : FBC
# Working on : FBHS
# Working on : FBIO
# Working on : FBIZ
# Working on : FBK
# Working on : FBMS
# Working on : FBNC
# Working on : FBP
# Working on : FC
# Working on : FCAP
# Working on : FCBC
# Working on : FCCO
# Working on : FCCY
# Working on : FCEL
# Working on : FCF
# Working on : FCFS
# Working on : FCN
# Working on : FCNCA
# Working on : FCPT
# Working on : FCX
# Working on : FDBC
# Working on : FDP
# Working on : FDS
# Working on : FDX
# Working on : FE
# Working on : FEIM
# Working on : FELE
# Working on : FET
# Working on : FF
# Working on : FFBC
# Working on : FFIC
# Working on : FFIN
# Working on : FFIV
# Working on : FFNW
# Working on : FFWM
# Working on : FGBI
# Working on : FGEN
# Working on : FHB
# Working on : FHN
# Working on : FIBK
# Working on : FICO
# Working on : FIS
# Working on : FISI
# Working on : FISV
# Working on : FITB
# Working on : FIVE
# Working on : FIVN
# Working on : FIX
# Working on : FIXX
# Working on : FIZZ
# Working on : FL
# Working on : FLDM
# Working on : FLIC
# Working on : FLL
# Working on : FLMN
# Working on : FLNT
# Working on : FLO
# Working on : FLOW
# Working on : FLR
# Working on : FLS
# Working on : FLT
# Working on : FLWS
# Working on : FLXN
# Working on : FLXS
# Working on : FMAO
# Working on : FMBH
# Working on : FMBI
# Working on : FMC
# Working on : FMNB
# Working on : FN
# Working on : FNB
# Working on : FNCB
# Working on : FND
# Working on : FNF
# Working on : FNHC
# Working on : FNKO
# Working on : FNLC
# Working on : FNWB
# Working on : FOCS
# Working on : FOE
# Working on : FOLD
# Working on : FONR
# Working on : FOR
# Working on : FORD
# Working on : FORM
# Working on : FORR
# Working on : FOSL
# Working on : FOX
# Working on : FOXA
# Working on : FOXF
# Working on : FPI
# Working on : FR
# Working on : FRBA
# Working on : FRBK
# Working on : FRC
# Working on : FRD
# Working on : FRGI
# Working on : FRME
# Working on : FRPH
# Working on : FRPT
# Working on : FRT
# Working on : FRTA
# Working on : FSBW
# Working on : FSFG
# Working on : FSLR
# Working on : FSLY
# Working on : FSP
# Working on : FSS
# Working on : FSTR
# Working on : FTDR
# Working on : FTEK
# Working on : FTI
# Working on : FTK
# Working on : FTNT
# Working on : FTSI
# Working on : FTV
# Working on : FUL
# Working on : FULT
# Working on : FUNC
# Working on : FUSB
# Working on : FVE
# Working on : FWONA
# Working on : FWONK
# Working on : FWRD
# Working on : G
# Working on : GABC
# Working on : GAIA
# Working on : GALT
# Working on : GATX
# Working on : GBCI
# Working on : GBL
# Working on : GBLI
# Working on : GBT
# Working on : GBX
# Working on : GCBC
# Working on : GCI
# Working on : GCO
# Working on : GCP
# Working on : GD
# Working on : GDDY
# Working on : GDEN
# Working on : GDOT
# Working on : GDP
# Working on : GE
# Working on : GEF
# Working on : GENC
# Working on : GEO
# Working on : GEOS
# Working on : GERN
# Working on : GES
# Working on : GEVO
# Working on : GFED
# Working on : GFF
# Working on : GGG
# Working on : GH
# Working on : GHC
# Working on : GHL
# Working on : GHM
# Working on : GIFI
# Working on : GIII
# Working on : GILD
# Working on : GIS
# Working on : GKOS
# Working on : GLBZ
# Working on : GLDD
# Working on : GLPI
# Working on : GLRE
# Working on : GLT
# Working on : GLW
# Working on : GLYC
# Working on : GM
# Working on : GME
# Working on : GMED
# Working on : GMRE
# Working on : GMS
# Working on : GNCA
# Working on : GNE
# Working on : GNK
# Working on : GNL
# Working on : GNRC
# Working on : GNTX
# Working on : GNTY
# Working on : GNW
# Working on : GOGO
# Working on : GOLF
# Working on : GOOD
# Working on : GOOG
# Working on : GOOGL
# Working on : GORO
# Working on : GOSS
# Working on : GPC
# Working on : GPI
# Working on : GPK
# Working on : GPMT
# Working on : GPN
# Working on : GPOR
# Working on : GPRE
# Working on : GPRO
# Working on : GPS
# Working on : GPX
# Working on : GRBK
# Working on : GRC
# Working on : GRMN
# Working on : GROW
# Working on : GRPN
# Working on : GRTS
# Working on : GRUB
# Working on : GS
# Working on : GSAT
# Working on : GSBC
# Working on : GSHD
# Working on : GSIT
# Working on : GSKY
# Working on : GT
# Working on : GTES
# Working on : GTHX
# Working on : GTIM
# Working on : GTLS
# Working on : GTN
# Working on : GTS
# Working on : GTX
# Working on : GTY
# Working on : GTYH
# Working on : GVA
# Working on : GVP
# Working on : GWB
# Working on : GWGH
# Working on : GWRE
# Working on : GWRS
# Working on : GWW
# Working on : H
# Working on : HA
# Working on : HAE
# Working on : HAFC
# Working on : HAIN
# Working on : HAL
# Working on : HALL
# Working on : HALO
# Working on : HAS
# Working on : HASI
# Working on : HAYN
# Working on : HBAN
# Working on : HBB
# Working on : HBCP
# Working on : HBI
# Working on : HBIO
# Working on : HBMD
# Working on : HBNC
# Working on : HBP
# Working on : HCA
# Working on : HCC
# Working on : HCCI
# Working on : HCI
# Working on : HCKT
# Working on : HCSG
# Working on : HD
# Working on : HDSN
# Working on : HE
# Working on : HEAR
# Working on : HEES
# Working on : HEI
# Working on : HELE
# Working on : HES
# Working on : HFBL
# Working on : HFC
# Working on : HFWA
# Working on : HGV
# Working on : HHC
# Working on : HHS
# Working on : HI
# Working on : HIBB
# Working on : HIFS
# Working on : HIG
# Working on : HII
# Working on : HIL
# Working on : HIW
# Working on : HL
# Working on : HLF
# Working on : HLI
# Working on : HLIT
# Working on : HLNE
# Working on : HLT
# Working on : HLX
# Working on : HMHC
# Working on : HMN
# Working on : HMNF
# Working on : HMST
# Working on : HMTV
# Working on : HNI
# Working on : HNRG
# Working on : HOFT
# Working on : HOG
# Working on : HOLX
# Working on : HOMB
# Working on : HON
# Working on : HONE
# Working on : HOPE
# Working on : HOV
# Working on : HP
# Working on : HPE
# Working on : HPP
# Working on : HPQ
# Working on : HQY
# Working on : HR
# Working on : HRB
# Working on : HRC
# Working on : HRI
# Working on : HRL
# Working on : HROW
# Working on : HRTG
# Working on : HRTX
# Working on : HSC
# Working on : HSIC
# Working on : HSII
# Working on : HSKA
# Working on : HSON
# Working on : HST
# Working on : HSTM
# Working on : HSY
# Working on : HT
# Working on : HTA
# Working on : HTBI
# Working on : HTBK
# Working on : HTBX
# Working on : HTGM
# Working on : HTH
# Working on : HTLD
# Working on : HTLF
# Working on : HUBB
# Working on : HUBG
# Working on : HUBS
# Working on : HUM
# Working on : HUN
# Working on : HURC
# Working on : HURN
# Working on : HUSA
# Working on : HVT
# Working on : HWBK
# Working on : HWC
# Working on : HWKN
# Working on : HXL
# Working on : HY
# Working on : HZN
# Working on : HZNP
# Working on : HZO
# Working on : IAC
# Working on : IART
# Working on : IBCP
# Working on : IBIO
# Working on : IBKR
# Working on : IBM
# Working on : IBOC
# Working on : IBP
# Working on : IBTX
# Working on : ICAD
# Working on : ICBK
# Working on : ICCC
# Working on : ICD
# Working on : ICE
# Working on : ICFI
# Working on : ICHR
# Working on : ICPT
# Working on : ICUI
# Working on : IDA
# Working on : IDCC
# Working on : IDN
# Working on : IDRA
# Working on : IDT
# Working on : IDXG
# Working on : IDXX
# Working on : IESC
# Working on : IEX
# Working on : IFF
# Working on : IHC
# Working on : III
# Working on : IIIN
# Working on : IIIV
# Working on : IIN
# Working on : IIPR
# Working on : IIVI
# Working on : IKNX
# Working on : ILMN
# Working on : ILPT
# Working on : IMGN
# Working on : IMH
# Working on : IMKTA
# Working on : IMMR
# Working on : IMXI
# Working on : INBK
# Working on : INCY
# Working on : INDB
# Working on : INFI
# Working on : INFN
# Working on : INFO
# Working on : INFU
# Working on : INGN
# Working on : INGR
# Working on : INN
# Working on : INO
# Working on : INOD
# Working on : INOV
# Working on : INS
# Working on : INSE
# Working on : INSG
# Working on : INSM
# Working on : INSP
# Working on : INSW
# Working on : INT
# Working on : INTC
# Working on : INTG
# Working on : INTT
# Working on : INTU
# Working on : INUV
# Working on : INVA
# Working on : INVE
# Working on : INVH
# Working on : IO
# Working on : IONS
# Working on : IOR
# Working on : IOSP
# Working on : IOVA
# Working on : IP
# Working on : IPAR
# Working on : IPG
# Working on : IPGP
# Working on : IPI
# Working on : IPWR
# Working on : IQV
# Working on : IR
# Working on : IRBT
# Working on : IRDM
# Working on : IRIX
# Working on : IRM
# Working on : IRMD
# Working on : IROQ
# Working on : IRT
# Working on : IRTC
# Working on : IRWD
# Working on : ISBC
# Working on : ISDR
# Working on : ISIG
# Working on : ISR
# Working on : ISRG
# Working on : ISSC
# Working on : ISTR
# Working on : IT
# Working on : ITCI
# Working on : ITGR
# Working on : ITI
# Working on : ITIC
# Working on : ITRI
# Working on : ITT
# Working on : ITW
# Working on : IVAC
# Working on : IVC
# Working on : IVR
# Working on : IVZ
# Working on : IZEA
# Working on : JACK
# Working on : JAGX
# Working on : JAKK
# Working on : JAZZ
# Working on : JBGS
# Working on : JBHT
# Working on : JBL
# Working on : JBLU
# Working on : JBSS
# Working on : JBT
# Working on : JCI
# Working on : JCS
# Working on : JCTCF
# Working on : JEF
# Working on : JELD
# Working on : JHG
# Working on : JILL
# Working on : JJSF
# Working on : JKHY
# Working on : JLL
# Working on : JNCE
# Working on : JNJ
# Working on : JNPR
# Working on : JOB
# Working on : JOE
# Working on : JOUT
# Working on : JPM
# Working on : JRVR
# Working on : JVA
# Working on : JWN
# Working on : JYNT
# Working on : K
# Working on : KAI
# Working on : KALA
# Working on : KALU
# Working on : KALV
# Working on : KAMN
# Working on : KAR
# Working on : KBAL
# Working on : KBH
# Working on : KBR
# Working on : KDMN
# Working on : KDP
# Working on : KE
# Working on : KELYA
# Working on : KEQU
# Working on : KEX
# Working on : KEY
# Working on : KEYS
# Working on : KFFB
# Working on : KFRC
# Working on : KFY
# Working on : KHC
# Working on : KIDS
# Working on : KIM
# Working on : KINS
# Working on : KIRK
# Working on : KKR
# Working on : KLAC
# Working on : KLIC
# Working on : KLXE
# Working on : KMB
# Working on : KMI
# Working on : KMPH
# Working on : KMPR
# Working on : KMT
# Working on : KMX
# Working on : KN
# Working on : KNSA
# Working on : KNSL
# Working on : KNX
# Working on : KO
# Working on : KOD
# Working on : KODK
# Working on : KOP
# Working on : KOPN
# Working on : KOS
# Working on : KPTI
# Working on : KR
# Working on : KRA
# Working on : KRC
# Working on : KREF
# Working on : KRG
# Working on : KRNY
# Working on : KRO
# Working on : KRYS
# Working on : KSS
# Working on : KSU
# Working on : KTCC
# Working on : KTOS
# Working on : KURA
# Working on : KVHI
# Working on : KW
# Working on : KWR
# Working on : KZR
# Working on : L
# Working on : LAD
# Working on : LADR
# Working on : LAKE
# Working on : LAMR
# Working on : LANC
# Working on : LAND
# Working on : LARK
# Working on : LASR
# Working on : LAUR
# Working on : LAWS
# Working on : LAZ
# Working on : LBAI
# Working on : LBC
# Working on : LBRDA
# Working on : LBRDK
# Working on : LBRT
# Working on : LBTYA
# Working on : LBTYK
# Working on : LC
# Working on : LCI
# Working on : LCII
# Working on : LCNB
# Working on : LCUT
# Working on : LDOS
# Working on : LE
# Working on : LEA
# Working on : LECO
# Working on : LEE
# Working on : LEG
# Working on : LEGH
# Working on : LEN
# Working on : LEU
# Working on : LEVI
# Working on : LFUS
# Working on : LFVN
# Working on : LGIH
# Working on : LGL
# Working on : LGND
# Working on : LH
# Working on : LHCG
# Working on : LIFE
# Working on : LII
# Working on : LILA
# Working on : LILAK
# Working on : LIN
# Working on : LINC
# Working on : LIND
# Working on : LIQT
# Working on : LITE
# Working on : LIVE
# Working on : LIVN
# Working on : LJPC
# Working on : LKFN
# Working on : LKQ
# Working on : LL
# Working on : LLNW
# Working on : LLY
# Working on : LMAT
# Working on : LMFA
# Working on : LMNR
# Working on : LMT
# Working on : LNC
# Working on : LNDC
# Working on : LNG
# Working on : LNN
# Working on : LNT
# Working on : LNTH
# Working on : LOAN
# Working on : LOB
# Working on : LOCO
# Working on : LODE
# Working on : LOOP
# Working on : LOPE
# Working on : LORL
# Working on : LOVE
# Working on : LOW
# Working on : LPCN
# Working on : LPG
# Working on : LPI
# Working on : LPLA
# Working on : LPSN
# Working on : LPTH
# Working on : LPX
# Working on : LQDA
# Working on : LQDT
# Working on : LRCX
# Working on : LRN
# Working on : LSBK
# Working on : LSCC
# Working on : LSI
# Working on : LSTR
# Working on : LSXMA
# Working on : LSXMK
# Working on : LTBR
# Working on : LTC
# Working on : LTHM
# Working on : LTRPA
# Working on : LTRX
# Working on : LUB
# Working on : LULU
# Working on : LUNA
# Working on : LUV
# Working on : LVS
# Working on : LW
# Working on : LWAY
# Working on : LXP
# Working on : LXRX
# Working on : LXU
# Working on : LYB
# Working on : LYFT
# Working on : LYTS
# Working on : LYV
# Working on : LZB
# Working on : M
# Working on : MA
# Working on : MAA
# Working on : MAC
# Working on : MACK
# Working on : MAN
# Working on : MANH
# Working on : MANT
# Working on : MAR
# Working on : MARA
# Working on : MARK
# Working on : MAS
# Working on : MASI
# Working on : MAT
# Working on : MATW
# Working on : MATX
# Working on : MAYS
# Working on : MBCN
# Working on : MBI
# Working on : MBII
# Working on : MBIN
# Working on : MBIO
# Working on : MBOT
# Working on : MBUU
# Working on : MBWM
# Working on : MC
# Working on : MCB
# Working on : MCBC
# Working on : MCD
# Working on : MCF
# Working on : MCFT
# Working on : MCHP
# Working on : MCHX
# Working on : MCK
# Working on : MCO
# Working on : MCRB
# Working on : MCRI
# Working on : MCS
# Working on : MCY
# Working on : MD
# Working on : MDB
# Working on : MDC
# Working on : MDGL
# Working on : MDLZ
# Working on : MDP
# Working on : MDRX
# Working on : MDT
# Working on : MDU
# Working on : MED
# Working on : MEDP
# Working on : MEI
# Working on : MEIP
# Working on : MERC
# Working on : MESA
# Working on : MET
# Working on : MFA
# Working on : MG
# Working on : MGEE
# Working on : MGI
# Working on : MGLN
# Working on : MGM
# Working on : MGNX
# Working on : MGPI
# Working on : MGRC
# Working on : MGTA
# Working on : MGY
# Working on : MGYR
# Working on : MHH
# Working on : MHK
# Working on : MHLD
# Working on : MHO
# Working on : MIC
# Working on : MICR
# Working on : MICT
# Working on : MIDD
# Working on : MIND
# Working on : MITK
# Working on : MITT
# Working on : MKC
# Working on : MKL
# Working on : MKSI
# Working on : MKTX
# Working on : MLAB
# Working on : MLHR
# Working on : MLI
# Working on : MLM
# Working on : MLP
# Working on : MLR
# Working on : MLSS
# Working on : MLVF
# Working on : MMC
# Working on : MMI
# Working on : MMM
# Working on : MMS
# Working on : MMSI
# Working on : MN
# Working on : MNKD
# Working on : MNOV
# Working on : MNR
# Working on : MNRL
# Working on : MNRO
# Working on : MNST
# Working on : MNTX
# Working on : MO
# Working on : MOBL
# Working on : MOD
# Working on : MODN
# Working on : MOFG
# Working on : MOH
# Working on : MORN
# Working on : MOS
# Working on : MOSY
# Working on : MOTS
# Working on : MOV
# Working on : MPAA
# Working on : MPB
# Working on : MPC
# Working on : MPW
# Working on : MPWR
# Working on : MPX
# Working on : MRAM
# Working on : MRC
# Working on : MRCY
# Working on : MRIN
# Working on : MRK
# Working on : MRKR
# Working on : MRLN
# Working on : MRNS
# Working on : MRO
# Working on : MRSN
# Working on : MRTN
# Working on : MRTX
# Working on : MRVL
# Working on : MS
# Working on : MSA
# Working on : MSBI
# Working on : MSCI
# Working on : MSEX
# Working on : MSFT
# Working on : MSI
# Working on : MSM
# Working on : MSN
# Working on : MSON
# Working on : MSTR
# Working on : MTB
# Working on : MTCH
# Working on : MTD
# Working on : MTDR
# Working on : MTEM
# Working on : MTEX
# Working on : MTG
# Working on : MTH
# Working on : MTN
# Working on : MTNB
# Working on : MTOR
# Working on : MTRN
# Working on : MTRX
# Working on : MTSI
# Working on : MTW
# Working on : MTX
# Working on : MTZ
# Working on : MU
# Working on : MUR
# Working on : MUSA
# Working on : MUX
# Working on : MVBF
# Working on : MVIS
# Working on : MWA
# Working on : MXL
# Working on : MYE
# Working on : MYGN
# Working on : MYRG
# Working on : NAII
# Working on : NATH
# Working on : NATI
# Working on : NATR
# Working on : NAVB
# Working on : NAVI
# Working on : NBEV
# Working on : NBHC
# Working on : NBIX
# Working on : NBN
# Working on : NBR
# Working on : NBTB
# Working on : NBY
# Working on : NC
# Working on : NCBS
# Working on : NCLH
# Working on : NCMI
# Working on : NCR
# Working on : NCSM
# Working on : NDAQ
# Working on : NDLS
# Working on : NE
# Working on : NEE
# Working on : NEM
# Working on : NEO
# Working on : NEOG
# Working on : NEON
# Working on : NERV
# Working on : NETE
# Working on : NEU
# Working on : NEWR
# Working on : NFBK
# Working on : NFG
# Working on : NFLX
# Working on : NGS
# Working on : NGVC
# Working on : NGVT
# Working on : NHC
# Working on : NHI
# Working on : NHTC
# Working on : NI
# Working on : NICK
# Working on : NINE
# Working on : NJR
# Working on : NKE
# Working on : NKSH
# Working on : NKTR
# Working on : NL
# Working on : NLS
# Working on : NLSN
# Working on : NLY
# Working on : NMIH
# Working on : NMRK
# Working on : NNBR
# Working on : NNI
# Working on : NNN
# Working on : NNVC
# Working on : NOC
# Working on : NODK
# Working on : NOG
# Working on : NOV
# Working on : NOVT
# Working on : NOW
# Working on : NP
# Working on : NPK
# Working on : NPO
# Working on : NPTN
# Working on : NR
# Working on : NRC
# Working on : NRG
# Working on : NRIM
# Working on : NRZ
# Working on : NSA
# Working on : NSC
# Working on : NSEC
# Working on : NSIT
# Working on : NSP
# Working on : NSSC
# Working on : NSTG
# Working on : NTAP
# Working on : NTCT
# Working on : NTGR
# Working on : NTIC
# Working on : NTIP
# Working on : NTLA
# Working on : NTNX
# Working on : NTRA
# Working on : NTRS
# Working on : NTWK
# Working on : NUAN
# Working on : NUE
# Working on : NURO
# Working on : NUS
# Working on : NUVA
# Working on : NVAX
# Working on : NVDA
# Working on : NVEC
# Working on : NVEE
# Working on : NVFY
# Working on : NVIV
# Working on : NVR
# Working on : NVRO
# Working on : NVT
# Working on : NVTA
# Working on : NWBI
# Working on : NWE
# Working on : NWFL
# Working on : NWL
# Working on : NWLI
# Working on : NWN
# Working on : NWPX
# Working on : NWS
# Working on : NWSA
# Working on : NX
# Working on : NXGN
# Working on : NXRT
# Working on : NXST
# Working on : NXTD
# Working on : NYCB
# Working on : NYMT
# Working on : NYT
# Working on : O
# Working on : OAS
# Working on : OBCI
# Working on : OBNK
# Working on : OC
# Working on : OCC
# Working on : OCFC
# Working on : OCN
# Working on : OCUL
# Working on : OCX
# Working on : ODC
# Working on : ODFL
# Working on : ODP
# Working on : ODT
# Working on : OESX
# Working on : OFC
# Working on : OFED
# Working on : OFG
# Working on : OFIX
# Working on : OFLX
# Working on : OGE
# Working on : OGEN
# Working on : OGS
# Working on : OHI
# Working on : OI
# Working on : OII
# Working on : OIS
# Working on : OKE
# Working on : OKTA
# Working on : OLED
# Working on : OLLI
# Working on : OLN
# Working on : OLP
# Working on : OMC
# Working on : OMCL
# Working on : OMER
# Working on : OMEX
# Working on : OMF
# Working on : OMI
# Working on : ON
# Working on : ONB
# Working on : ONCS
# Working on : ONTX
# Working on : ONVO
# Working on : OOMA
# Working on : OPGN
# Working on : OPI
# Working on : OPK
# Working on : OPOF
# Working on : OPRX
# Working on : OPTN
# Working on : OPTT
# Working on : OPY
# Working on : ORA
# Working on : ORC
# Working on : ORCL
# Working on : ORGO
# Working on : ORI
# Working on : ORLY
# Working on : ORN
# Working on : ORRF
# Working on : OSBC
# Working on : OSG
# Working on : OSIS
# Working on : OSK
# Working on : OSPN
# Working on : OSTK
# Working on : OSUR
# Working on : OTIC
# Working on : OTTR
# Working on : OUT
# Working on : OVBC
# Working on : OVLY
# Working on : OXM
# Working on : OXY
# Working on : OZK
# Working on : PACB
# Working on : PACW
# Working on : PAG
# Working on : PAHC
# Working on : PANL
# Working on : PANW
# Working on : PAR
# Working on : PARR
# Working on : PATI
# Working on : PATK
# Working on : PAYC
# Working on : PAYX
# Working on : PB
# Working on : PBCT
# Working on : PBF
# Working on : PBH
# Working on : PBHC
# Working on : PBI
# Working on : PBIP
# Working on : PBPB
# Working on : PBYI
# Working on : PCAR
# Working on : PCH
# Working on : PCRX
# Working on : PCSB
# Working on : PCTI
# Working on : PCTY
# Working on : PCYG
# Working on : PCYO
# Working on : PD
# Working on : PDCE
# Working on : PDCO
# Working on : PDEX
# Working on : PDFS
# Working on : PDLB
# Working on : PDM
# Working on : PEB
# Working on : PEBK
# Working on : PEBO
# Working on : PED
# Working on : PEG
# Working on : PEGA
# Working on : PEI
# Working on : PEN
# Working on : PENN
# Working on : PEP
# Working on : PESI
# Working on : PETQ
# Working on : PETS
# Working on : PFBC
# Working on : PFE
# Working on : PFG
# Working on : PFGC
# Working on : PFIE
# Working on : PFIN
# Working on : PFIS
# Working on : PFMT
# Working on : PFS
# Working on : PFSW
# Working on : PG
# Working on : PGC
# Working on : PGR
# Working on : PGRE
# Working on : PGTI
# Working on : PH
# Working on : PHAS
# Working on : PHIO
# Working on : PHM
# Working on : PHX
# Working on : PI
# Working on : PII
# Working on : PINC
# Working on : PINS
# Working on : PJT
# Working on : PK
# Working on : PKBK
# Working on : PKE
# Working on : PKG
# Working on : PKI
# Working on : PKOH
# Working on : PLAB
# Working on : PLAN
# Working on : PLAY
# Working on : PLBC
# Working on : PLCE
# Working on : PLD
# Working on : PLNT
# Working on : PLOW
# Working on : PLPC
# Working on : PLSE
# Working on : PLUG
# Working on : PLUS
# Working on : PLXP
# Working on : PLXS
# Working on : PLYA
# Working on : PLYM
# Working on : PM
# Working on : PMBC
# Working on : PMD
# Working on : PMT
# Working on : PMTS
# Working on : PNBK
# Working on : PNC
# Working on : PNFP
# Working on : PNM
# Working on : PNR
# Working on : PNRG
# Working on : PNW
# Working on : PODD
# Working on : POOL
# Working on : POR
# Working on : POST
# Working on : POWI
# Working on : POWL
# Working on : PPBI
# Working on : PPC
# Working on : PPG
# Working on : PPIH
# Working on : PPL
# Working on : PPSI
# Working on : PRA
# Working on : PRAA
# Working on : PRFT
# Working on : PRGO
# Working on : PRGS
# Working on : PRI
# Working on : PRIM
# Working on : PRK
# Working on : PRLB
# Working on : PRMW
# Working on : PRO
# Working on : PROV
# Working on : PRPH
# Working on : PRTA
# Working on : PRTK
# Working on : PRTS
# Working on : PRTY
# Working on : PRU
# Working on : PRVB
# Working on : PSA
# Working on : PSB
# Working on : PSMT
# Working on : PSN
# Working on : PSTG
# Working on : PSX
# Working on : PTC
# Working on : PTCT
# Working on : PTE
# Working on : PTEN
# Working on : PTGX
# Working on : PTN
# Working on : PTSI
# Working on : PULM
# Working on : PUMP
# Working on : PVAC
# Working on : PVBC
# Working on : PVH
# Working on : PW
# Working on : PWOD
# Working on : PWR
# Working on : PXD
# Working on : PXLW
# Working on : PYPL
# Working on : PZG
# Working on : PZN
# Working on : PZZA
# Working on : QADA
# Working on : QADB
# Working on : QCOM
# Working on : QCRH
# Working on : QDEL
# Working on : QLYS
# Working on : QNST
# Working on : QRHC
# Working on : QRTEA
# Working on : QRVO
# Working on : QTRX
# Working on : QTWO
# Working on : QUAD
# Working on : QUIK
# Working on : QUMU
# Working on : QUOT
# Working on : R
# Working on : RAD
# Working on : RAIL
# Working on : RAMP
# Working on : RARE
# Working on : RAVE
# Working on : RAVN
# Working on : RBB
# Working on : RBBN
# Working on : RBCAA
# Working on : RBCN
# Working on : RBNC
# Working on : RC
# Working on : RCII
# Working on : RCKT
# Working on : RCKY
# Working on : RCL
# Working on : RCM
# Working on : RCMT
# Working on : RCUS
# Working on : RDFN
# Working on : RDI
# Working on : RDN
# Working on : RDNT
# Working on : RDUS
# Working on : RDVT
# Working on : RE
# Working on : REED
# Working on : REFR
# Working on : REG
# Working on : REGI
# Working on : REGN
# Working on : REI
# Working on : RELL
# Working on : RELV
# Working on : REPH
# Working on : REPL
# Working on : RES
# Working on : RESN
# Working on : RETA
# Working on : REV
# Working on : REVG
# Working on : REX
# Working on : REXR
# Working on : REZI
# Working on : RF
# Working on : RFIL
# Working on : RFL
# Working on : RFP
# Working on : RGA
# Working on : RGCO
# Working on : RGEN
# Working on : RGLD
# Working on : RGLS
# Working on : RGNX
# Working on : RGR
# Working on : RGS
# Working on : RH
# Working on : RHE
# Working on : RHI
# Working on : RHP
# Working on : RIBT
# Working on : RICK
# Working on : RIG
# Working on : RIGL
# Working on : RILY
# Working on : RIOT
# Working on : RJF
# Working on : RKDA
# Working on : RL
# Working on : RLGT
# Working on : RLGY
# Working on : RLI
# Working on : RLJ
# Working on : RM
# Working on : RMAX
# Working on : RMBS
# Working on : RMCF
# Working on : RMD
# Working on : RMR
# Working on : RMTI
# Working on : RNDB
# Working on : RNG
# Working on : RNR
# Working on : RNST
# Working on : RNWK
# Working on : ROCK
# Working on : ROG
# Working on : ROIC
# Working on : ROK
# Working on : ROKU
# Working on : ROL
# Working on : ROLL
# Working on : ROP
# Working on : ROST
# Working on : RPAI
# Working on : RPD
# Working on : RPM
# Working on : RPT
# Working on : RRC
# Working on : RRD
# Working on : RRGB
# Working on : RRR
# Working on : RRTS
# Working on : RS
# Working on : RSG
# Working on : RUBY
# Working on : RUN
# Working on : RUSHA
# Working on : RUSHB
# Working on : RUTH
# Working on : RVI
# Working on : RVNC
# Working on : RVP
# Working on : RVSB
# Working on : RWT
# Working on : RYAM
# Working on : RYI
# Working on : RYN
# Working on : RYTM
# Working on : SABR
# Working on : SACH
# Working on : SAFE
# Working on : SAFM
# Working on : SAFT
# Working on : SAGE
# Working on : SAH
# Working on : SAIA
# Working on : SAIC
# Working on : SAIL
# Working on : SAL
# Working on : SALM
# Working on : SAM
# Working on : SAMG
# Working on : SANM
# Working on : SANW
# Working on : SASR
# Working on : SATS
# Working on : SAVE
# Working on : SBAC
# Working on : SBCF
# Working on : SBFG
# Working on : SBGI
# Working on : SBH
# Working on : SBNY
# Working on : SBOW
# Working on : SBRA
# Working on : SBSI
# Working on : SBT
# Working on : SBUX
# Working on : SC
# Working on : SCHL
# Working on : SCHN
# Working on : SCHW
# Working on : SCI
# Working on : SCL
# Working on : SCOR
# Working on : SCPL
# Working on : SCS
# Working on : SCSC
# Working on : SCVL
# Working on : SCWX
# Working on : SCX
# Working on : SCYX
# Working on : SD
# Working on : SDPI
# Working on : SEAC
# Working on : SEAS
# Working on : SEB
# Working on : SEDG
# Working on : SEE
# Working on : SEIC
# Working on : SELB
# Working on : SELF
# Working on : SEM
# Working on : SENEA
# Working on : SENEB
# Working on : SENS
# Working on : SESN
# Working on : SF
# Working on : SFBC
# Working on : SFBS
# Working on : SFE
# Working on : SFIX
# Working on : SFM
# Working on : SFNC
# Working on : SFST
# Working on : SGA
# Working on : SGC
# Working on : SGEN
# Working on : SGH
# Working on : SGMA
# Working on : SGMO
# Working on : SGMS
# Working on : SGRP
# Working on : SGRY
# Working on : SHAK
# Working on : SHBI
# Working on : SHEN
# Working on : SHO
# Working on : SHOO
# Working on : SHW
# Working on : SIBN
# Working on : SIEB
# Working on : SIEN
# Working on : SIF
# Working on : SIG
# Working on : SIGA
# Working on : SIGI
# Working on : SILK
# Working on : SINT
# Working on : SIRI
# Working on : SITC
# Working on : SITE
# Working on : SIVB
# Working on : SIX
# Working on : SJI
# Working on : SJM
# Working on : SJW
# Working on : SKT
# Working on : SKX
# Working on : SKY
# Working on : SKYW
# Working on : SLAB
# Working on : SLB
# Working on : SLCA
# Working on : SLCT
# Working on : SLDB
# Working on : SLG
# Working on : SLGN
# Working on : SLM
# Working on : SLNO
# Working on : SLP
# Working on : SLS
# Working on : SM
# Working on : SMAR
# Working on : SMBC
# Working on : SMBK
# Working on : SMED
# Working on : SMG
# Working on : SMIT
# Working on : SMMF
# Working on : SMP
# Working on : SMPL
# Working on : SMRT
# Working on : SMSI
# Working on : SMTC
# Working on : SNA
# Working on : SNAP
# Working on : SNBR
# Working on : SNCR
# Working on : SND
# Working on : SNDR
# Working on : SNDX
# Working on : SNFCA
# Working on : SNOA
# Working on : SNPS
# Working on : SNV
# Working on : SNX
# Working on : SO
# Working on : SOHO
# Working on : SOI
# Working on : SOLY
# Working on : SON
# Working on : SONO
# Working on : SP
# Working on : SPB
# Working on : SPG
# Working on : SPGI
# Working on : SPLK
# Working on : SPNE
# Working on : SPOK
# Working on : SPPI
# Working on : SPR
# Working on : SPRO
# Working on : SPSC
# Working on : SPTN
# Working on : SPWH
# Working on : SPWR
# Working on : SPXC
# Working on : SQ
# Working on : SR
# Working on : SRC
# Working on : SRCE
# Working on : SRCL
# Working on : SRDX
# Working on : SRE
# Working on : SREV
# Working on : SRG
# Working on : SRI
# Working on : SRNE
# Working on : SRPT
# Working on : SRRK
# Working on : SRT
# Working on : SRTS
# Working on : SSB
# Working on : SSBI
# Working on : SSD
# Working on : SSKN
# Working on : SSNC
# Working on : SSP
# Working on : SSTI
# Working on : SSTK
# Working on : ST
# Working on : STAA
# Working on : STAG
# Working on : STAR
# Working on : STBA
# Working on : STC
# Working on : STCN
# Working on : STE
# Working on : STFC
# Working on : STIM
# Working on : STKS
# Working on : STL
# Working on : STLD
# Working on : STOR
# Working on : STRA
# Working on : STRL
# Working on : STRM
# Working on : STRS
# Working on : STRT
# Working on : STT
# Working on : STWD
# Working on : STX
# Working on : STXB
# Working on : STZ
# Working on : SUI
# Working on : SUM
# Working on : SUMR
# Working on : SUNW
# Working on : SUP
# Working on : SUPN
# Working on : SVBI
# Working on : SVRA
# Working on : SVT
# Working on : SWAV
# Working on : SWCH
# Working on : SWK
# Working on : SWKS
# Working on : SWM
# Working on : SWN
# Working on : SWX
# Working on : SXC
# Working on : SXI
# Working on : SXT
# Working on : SYBT
# Working on : SYBX
# Working on : SYF
# Working on : SYK
# Working on : SYN
# Working on : SYNA
# Working on : SYNH
# Working on : SYNL
# Working on : SYPR
# Working on : SYRS
# Working on : SYY
# Working on : T
# Working on : TACO
# Working on : TACT
# Working on : TAIT
# Working on : TALO
# Working on : TAP
# Working on : TAST
# Working on : TAYD
# Working on : TBBK
# Working on : TBI
# Working on : TBK
# Working on : TBNK
# Working on : TBPH
# Working on : TCBI
# Working on : TCBK
# Working on : TCDA
# Working on : TCFC
# Working on : TCI
# Working on : TCMD
# Working on : TCON
# Working on : TCS
# Working on : TDC
# Working on : TDG
# Working on : TDOC
# Working on : TDS
# Working on : TDW
# Working on : TDY
# Working on : TECH
# Working on : TEL
# Working on : TELL
# Working on : TEN
# Working on : TENB
# Working on : TENX
# Working on : TER
# Working on : TESS
# Working on : TEUM
# Working on : TEX
# Working on : TFSL
# Working on : TFX
# Working on : TG
# Working on : TGEN
# Working on : TGI
# Working on : TGLS
# Working on : TGNA
# Working on : TGT
# Working on : TGTX
# Working on : THC
# Working on : THFF
# Working on : THG
# Working on : THO
# Working on : THR
# Working on : THRM
# Working on : THS
# Working on : TILE
# Working on : TIPT
# Working on : TISI
# Working on : TITN
# Working on : TJX
# Working on : TKR
# Working on : TLGT
# Working on : TLYS
# Working on : TMDX
# Working on : TMHC
# Working on : TMO
# Working on : TMP
# Working on : TMST
# Working on : TMUS
# Working on : TNC
# Working on : TNDM
# Working on : TNET
# Working on : TNXP
# Working on : TOL
# Working on : TOWN
# Working on : TPB
# Working on : TPC
# Working on : TPH
# Working on : TPHS
# Working on : TPIC
# Working on : TPR
# Working on : TPTX
# Working on : TPX
# Working on : TR
# Working on : TRC
# Working on : TREC
# Working on : TREE
# Working on : TREX
# Working on : TRGP
# Working on : TRHC
# Working on : TRIP
# Working on : TRMB
# Working on : TRMK
# Working on : TRN
# Working on : TRNO
# Working on : TRNS
# Working on : TROW
# Working on : TROX
# Working on : TRS
# Working on : TRST
# Working on : TRT
# Working on : TRTN
# Working on : TRTX
# Working on : TRU
# Working on : TRUP
# Working on : TRV
# Working on : TRVN
# Working on : TSBK
# Working on : TSC
# Working on : TSCO
# Working on : TSE
# Working on : TSLA
# Working on : TSN
# Working on : TSQ
# Working on : TTC
# Working on : TTD
# Working on : TTEC
# Working on : TTEK
# Working on : TTGT
# Working on : TTI
# Working on : TTMI
# Working on : TTNP
# Working on : TTOO
# Working on : TTWO
# Working on : TUP
# Working on : TUSK
# Working on : TVTY
# Working on : TW
# Working on : TWI
# Working on : TWIN
# Working on : TWLO
# Working on : TWNK
# Working on : TWO
# Working on : TWOU
# Working on : TWST
# Working on : TWTR
# Working on : TXMD
# Working on : TXN
# Working on : TXRH
# Working on : TXT
# Working on : TYL
# Working on : TYME
# Working on : TZOO
# Working on : UA
# Working on : UAA
# Working on : UAL
# Working on : UAMY
# Working on : UBA
# Working on : UBCP
# Working on : UBER
# Working on : UBFO
# Working on : UBOH
# Working on : UBSI
# Working on : UCBI
# Working on : UCTT
# Working on : UDR
# Working on : UE
# Working on : UEC
# Working on : UEIC
# Working on : UFAB
# Working on : UFCS
# Working on : UFI
# Working on : UFPI
# Working on : UFPT
# Working on : UFS
# Working on : UG
# Working on : UGI
# Working on : UHAL
# Working on : UHS
# Working on : UHT
# Working on : UIHC
# Working on : UIS
# Working on : ULBI
# Working on : ULH
# Working on : ULTA
# Working on : UMBF
# Working on : UMH
# Working on : UMPQ
# Working on : UNAM
# Working on : UNB
# Working on : UNF
# Working on : UNFI
# Working on : UNH
# Working on : UNIT
# Working on : UNM
# Working on : UNP
# Working on : UNTY
# Working on : UNVR
# Working on : UONE
# Working on : UONEK
# Working on : UPLD
# Working on : UPS
# Working on : UPWK
# Working on : URBN
# Working on : URI
# Working on : USAK
# Working on : USAP
# Working on : USB
# Working on : USEG
# Working on : USFD
# Working on : USIO
# Working on : USLM
# Working on : USM
# Working on : USNA
# Working on : USPH
# Working on : USWS
# Working on : USX
# Working on : UTHR
# Working on : UTI
# Working on : UTL
# Working on : UTMD
# Working on : UUU
# Working on : UVE
# Working on : UVSP
# Working on : UVV
# Working on : V
# Working on : VAC
# Working on : VAL
# Working on : VALU
# Working on : VAPO
# Working on : VBFC
# Working on : VBIV
# Working on : VBTX
# Working on : VC
# Working on : VCEL
# Working on : VCRA
# Working on : VCTR
# Working on : VCYT
# Working on : VEC
# Working on : VECO
# Working on : VEEV
# Working on : VER
# Working on : VERI
# Working on : VERU
# Working on : VFC
# Working on : VG
# Working on : VGR
# Working on : VHC
# Working on : VIAV
# Working on : VICI
# Working on : VICL
# Working on : VICR
# Working on : VIRC
# Working on : VIRT
# Working on : VISI
# Working on : VISL
# Working on : VIVO
# Working on : VKTX
# Working on : VLGEA
# Working on : VLO
# Working on : VLY
# Working on : VMC
# Working on : VMI
# Working on : VMW
# Working on : VNCE
# Working on : VNDA
# Working on : VNE
# Working on : VNO
# Working on : VNRX
# Working on : VNTR
# Working on : VOXX
# Working on : VOYA
# Working on : VPG
# Working on : VRA
# Working on : VRAY
# Working on : VREX
# Working on : VRML
# Working on : VRNS
# Working on : VRNT
# Working on : VRRM
# Working on : VRS
# Working on : VRSK
# Working on : VRSN
# Working on : VRTS
# Working on : VRTV
# Working on : VRTX
# Working on : VSAT
# Working on : VSEC
# Working on : VSH
# Working on : VSI
# Working on : VST
# Working on : VSTM
# Working on : VSTO
# Working on : VTNR
# Working on : VTR
# Working on : VTVT
# Working on : VUZI
# Working on : VVI
# Working on : VVV
# Working on : VXRT
# Working on : VYGR
# Working on : VZ
# Working on : W
# Working on : WAB
# Working on : WABC
# Working on : WAFD
# Working on : WAIR
# Working on : WAL
# Working on : WASH
# Working on : WAT
# Working on : WATT
# Working on : WBA
# Working on : WBC
# Working on : WBS
# Working on : WBT
# Working on : WCC
# Working on : WCG
# Working on : WD
# Working on : WDAY
# Working on : WDC
# Working on : WDFC
# Working on : WEBK
# Working on : WEC
# Working on : WELL
# Working on : WEN
# Working on : WERN
# Working on : WETF
# Working on : WEX
# Working on : WEYS
# Working on : WFC
# Working on : WGO
# Working on : WH
# Working on : WHD
# Working on : WHG
# Working on : WHLM
# Working on : WHLR
# Working on : WHR
# Working on : WINA
# Working on : WING
# Working on : WIRE
# Working on : WK
# Working on : WKHS
# Working on : WLDN
# Working on : WLFC
# Working on : WLH
# Working on : WLK
# Working on : WLL
# Working on : WLTW
# Working on : WM
# Working on : WMB
# Working on : WMC
# Working on : WMK
# Working on : WMS
# Working on : WMT
# Working on : WNC
# Working on : WNEB
# Working on : WOR
# Working on : WOW
# Working on : WPC
# Working on : WRB
# Working on : WRE
# Working on : WRK
# Working on : WRLD
# Working on : WSBC
# Working on : WSBF
# Working on : WSC
# Working on : WSFS
# Working on : WSM
# Working on : WSO
# Working on : WSR
# Working on : WST
# Working on : WSTG
# Working on : WSTL
# Working on : WTBA
# Working on : WTFC
# Working on : WTI
# Working on : WTM
# Working on : WTRH
# Working on : WTS
# Working on : WTT
# Working on : WTTR
# Working on : WU
# Working on : WVE
# Working on : WVFC
# Working on : WVVI
# Working on : WW
# Working on : WWD
# Working on : WWE
# Working on : WWR
# Working on : WWW
# Working on : WY
# Working on : WYNN
# Working on : WYY
# Working on : X
# Working on : XBIT
# Working on : XEL
# Working on : XELA
# Working on : XELB
# Working on : XENT
# Working on : XERS
# Working on : XFOR
# Working on : XHR
# Working on : XLNX
# Working on : XLRN
# Working on : XNCR
# Working on : XOG
# Working on : XOM
# Working on : XOMA
# Working on : XONE
# Working on : XPER
# Working on : XPL
# Working on : XPO
# Working on : XRAY
# Working on : XRX
# Working on : XSPA
# Working on : XTNT
# Working on : XXII
# Working on : XYL
# Working on : Y
# Working on : YELP
# Working on : YETI
# Working on : YEXT
# Working on : YMAB
# Working on : YORW
# Working on : YTEN
# Working on : YUM
# Working on : YUMA
# Working on : Z
# Working on : ZAYO
# Working on : ZBH
# Working on : ZBRA
# Working on : ZDGE
# Working on : ZEN
# Working on : ZEUS
# Working on : ZFGN
# Working on : ZG
# Working on : ZGNX
# Working on : ZION
# Working on : ZIOP
# Working on : ZIXI
# Working on : ZM
# Working on : ZNGA
# Working on : ZS
# Working on : ZSAN
# Working on : ZTS
# Working on : ZUMZ
# Working on : ZUO
# Working on : ZVO
# Working on : ZYNE
# Working on : ZYXI
# Working on : ^GSPC

# %% [markdown]
# ## 11 Stock Market Sectors

# %% [markdown]
# We want to invest in stocks that are not correlated with other stocks. This means we want stocks that tend to go down when the others go up. Because all our stocks are expected to do well over the course of the year, this smoothes out the performance of our portfolio.
#
# One way to easily find stocks that are not correlated is to create portfolios using stocks from different sectors of the market.
#
# **Technology** : Manufacturing of electronics, software, or related to information technology
#
# **Health Care** : Biotech, hospitals, medical devices, drugs
#
# **Financials** : Banks, investment funds, and insurance
#
# **Real Estate** : Residential, industrial, and retail real estate
#
# **Energy** : Production and supply of energy
#
# **Materials** : Mining, refining, chemical, and forestry
#
# **Consumer Discretionary** : Retailers, apparel, media, durables and services
#
# **Industrials** : Construction, machinery, fabrication, manufacturing, defense, and aerospace
#
# **Utilities** : Direct providers of electric, gas, and water
#
# **Consumer Staples** : Food, beverage as well as products consumers deem essential
#
# **Telecommunication** : Cable, internet providers, wireless, and satellite

# %% [markdown]
# ## Get Sector Stocks

# %%
sec_df = pd.read_csv("D:/Python for Finance/stock_sectors.csv")
sec_df

indus_df = sec_df.loc[sec_df['Sector'] == "Industrials"]
health_df = sec_df.loc[sec_df['Sector'] == "Health Care"]
it_df = sec_df.loc[sec_df['Sector'] == "Information Technology"]
comm_df = sec_df.loc[sec_df['Sector'] == "Communication Services"]
staple_df = sec_df.loc[sec_df['Sector'] == "Consumer Staples"]
discretion_df = sec_df.loc[sec_df['Sector'] == "Consumer Discretionary"]
utility_df = sec_df.loc[sec_df['Sector'] == "Utilities"]
financial_df = sec_df.loc[sec_df['Sector'] == "Financials"]
material_df = sec_df.loc[sec_df['Sector'] == "Materials"]
restate_df = sec_df.loc[sec_df['Sector'] == "Real Estate"]
energy_df = sec_df.loc[sec_df['Sector'] == "Energy"]

# %% [markdown]
# ## Returns a DF with Cumulative Return for all Stocks

# %%
def get_cum_ret_for_stocks(stock_df):
    tickers = []
    cum_rets = []

    for index, row in stock_df.iterrows():
        df = get_stock_df_from_csv(row['Symbol'])
        if df is None:
            pass
        else:
            tickers.append(row['Symbol'])
            cum = df['cum_return'].iloc[-1]
            cum_rets.append(cum)
    return pd.DataFrame({'Ticker':tickers, 'CUM_RET':cum_rets})

# %%
industrial = get_cum_ret_for_stocks(indus_df)
health_care = get_cum_ret_for_stocks(health_df)
it = get_cum_ret_for_stocks(it_df)
commun = get_cum_ret_for_stocks(comm_df)
staple = get_cum_ret_for_stocks(staple_df)
discretion = get_cum_ret_for_stocks(discretion_df)
utility = get_cum_ret_for_stocks(utility_df)
finance = get_cum_ret_for_stocks(financial_df)
material = get_cum_ret_for_stocks(material_df)
restate = get_cum_ret_for_stocks(restate_df)
energy = get_cum_ret_for_stocks(energy_df)
# Out:
# File Doesn't Exist
# File Doesn't Exist
# File Doesn't Exist
# File Doesn't Exist
# File Doesn't Exist
# File Doesn't Exist
# File Doesn't Exist
# File Doesn't Exist
# File Doesn't Exist
# File Doesn't Exist
# File Doesn't Exist
# File Doesn't Exist
# File Doesn't Exist
# File Doesn't Exist
# File Doesn't Exist
# File Doesn't Exist
# File Doesn't Exist
# File Doesn't Exist
# File Doesn't Exist
# File Doesn't Exist
# File Doesn't Exist
# File Doesn't Exist
# File Doesn't Exist
# File Doesn't Exist

# %% [markdown]
# ## Ichimoku Kinko Hyo

# %% [markdown]
# The Ichimoku (One Look) is considered an all in one indicator. It provides information on momentum, support and resistance. It is made up of 5 lines. If you are a short term trader you create 1 minute or 6 hour. Long term traders focus on day or weekly data.
#
#  - Conversion Line (Tenkan-sen) : Represents support, resistance and reversals. Used to measure short term trends.
#  - Baseline (Kijun-sen) : Represents support, resistance and confirms trend changes. Allows you to evaluate the strength of medium term trends. Called the baseline because it lags the price.
#  - Leading Span A (Senkou A) : Used to identify future areas of support and resistance
#  - Leading Span B (Senkou B) : Other line used to identify suture support and resistance
#  - Lagging Span (Chikou) : Shows possible support and resistance. It is used to confirm signals obtained from other lines.
#  - Cloud (Kumo) : Space between Span A and B. Represents the divergence in price evolution.
#
# Formulas
#
#  - Lagging Span = Price shifted back 26 periods
#  - Base Line = (Highest Value in period + Lowest value in period)/2 (26 Sessions)
#  - Conversion Line = (Highest Value in period + Lowest value in period)/2 (9 Sessions)
#  - Leading Span A = (Conversion Value + Base Value)/2 (26 Sessions)
#  - Leading Span B = (Conversion Value + Base Value)/2 (52 Sessions)

# %% [markdown]
# ## Get Ichimoku Function

# %%
def get_fill_color(label):
    if label >= 1:
        return 'rgba(0,250,0,0.4)'
    else:
        return 'rgba(250,0,0,0.4)'

# %%
def get_Ichimoku(ticker):
    df = yf.download(tickers=ticker, period='1y', interval='1d')

    # Conversion
    hi_val = df['High'].rolling(window=9).max()
    low_val = df['Low'].rolling(window=9).min()
    df['Conversion'] = (hi_val + low_val) / 2

    # Baseline
    hi_val2 = df['High'].rolling(window=26).max()
    low_val2 = df['Low'].rolling(window=26).min()
    df['Baseline'] = (hi_val2 + low_val2) / 2

    # Spans
    df['SpanA'] = ((df['Conversion'] + df['Baseline']) / 2).shift(26)
    hi_val3 = df['High'].rolling(window=52).max()
    low_val3 = df['Low'].rolling(window=52).min()
    df['SpanB'] = ((hi_val3 + low_val3) / 2).shift(26)
    df['Lagging'] = df['Close'].shift(-26)

    candle = go.Candlestick(x=df.index, open=df['Open'],
    high=df['High'], low=df["Low"], close=df['Close'], name="Candlestick")

    df1 = df.copy()
    fig = go.Figure()
    df['label'] = np.where(df['SpanA'] > df['SpanB'], 1, 0)
    df['group'] = df['label'].ne(df['label'].shift()).cumsum()

    df = df.groupby('group')

    dfs = []
    for name, data in df:
        dfs.append(data)

    for df in dfs:
        fig.add_traces(go.Scatter(x=df.index, y=df.SpanA,
        line=dict(color='rgba(0,0,0,0)')))

        fig.add_traces(go.Scatter(x=df.index, y=df.SpanB,
        line=dict(color='rgba(0,0,0,0)'),
        fill='tonexty',
        fillcolor=get_fill_color(df['label'].iloc[0])))

    baseline = go.Scatter(x=df1.index, y=df1['Baseline'], 
    line=dict(color='pink', width=2), name="Baseline")

    conversion = go.Scatter(x=df1.index, y=df1['Conversion'], 
    line=dict(color='black', width=1), name="Conversion")

    lagging = go.Scatter(x=df1.index, y=df1['Lagging'], 
    line=dict(color='purple', width=2), name="Lagging")

    span_a = go.Scatter(x=df1.index, y=df1['SpanA'], 
    line=dict(color='green', width=2, dash='dot'), name="Span A")

    span_b = go.Scatter(x=df1.index, y=df1['SpanB'], 
    line=dict(color='red', width=1, dash='dot'), name="Span B")

    fig.add_trace(candle)
    fig.add_trace(baseline)
    fig.add_trace(conversion)
    fig.add_trace(lagging)
    fig.add_trace(span_a)
    fig.add_trace(span_b)
    
    fig.update_layout(height=1200, width=1800, showlegend=True)

    fig.show()

# %% [markdown]
# ## What the Lines Mean

# %% [markdown]
#  - Lagging Span : When above the price it is bullish and when below bearish. It is used with other indicators because it is mainly a filter.
#  - Baseline : When below price this is considered support. When above price this is considered resistance. We are in an uptrend when the slope increases and vice versa. The slope of the curve tells us the strength of the trend.
#  - Conversion : We focus on its position versus the Baseline. When the Conversion crosses above the Baseline we are in an upward trend and vice versa. This is considered a strong indicator when above the Cloud and weak when below.
#  - Cloud : The thicker the Cloud, the stronger the trend and vice versa. When the Spans cross many times we are in a range. When they cross this is a sign of a reversal of trend.

# %% [markdown]
# ## Top Industrials

# %%
industrial.sort_values(by=['CUM_RET'], ascending=False).head(10)
# Out:
#    Ticker   CUM_RET
# 24   GNRC  8.172729
# 26     GE  6.217026
# 42   ODFL  6.137047
# 10   CPRT  5.350906
# 16    ETN  4.727456
# 9    CTAS  4.009012
# 13     DE  3.816768
# 30   INFO  3.775151
# 35    KSU  3.709996
# 55    TDY  3.444655

# %% [markdown]
# ## Analyze Best Performers with Ichimoku

# %%
get_Ichimoku('ODFL')
# Out:
# [*********************100%***********************]  1 of 1 completed
# <div>                            <div id="bf138656-8c24-43f5-989b-452e40b5bbd7" class="plotly-graph-div" style="height:1200px; width:1800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bf138656-8c24-43f5-989b-452e40b5bbd7")) {                    Plotly.newPlot(                        "bf138656-8c24-43f5-989b-452e40b5bbd7",                        [{"line":{"color":"rgba(0,0,0,0)"},"type":"scatter","x":["2020-12-29T00:00:00","2020-12-30T00:00:00","2020-12-31T00:00:00","2021-01-04T00:00:00","2021-01-05T00:00:00","2021-01-06T00:00:00","2021-01-07T00:00:00","2021-01-08T00:00:00","2021-01-11T00:00:00","2021-01-12T00:00:00","2021-01-13T00:00:00","2021-01-14T00:00:00","2021-01-15T00:00:00","2021-01-19T00:00:00","2021-01-20T00:00:00","2021-01-21T00:00:00","2021-01-22T00:00:00","2021-01-25T00:00:00","2021-01-26T00:00:00","2021-01-27T00:00:00","2021-01-28T00:00:00","2021-01-29T00:00:00","2021-02-01T00:00:00","2021-02-02T00:00:00","2021-02-03T00:00:00","2021-02-04T00:00:00","2021-02-05T00:00:00","2021-02-08T00:00:00","2021-02-09T00:00:00","2021-02-10T00:00:00","2021-02-11T00:00:00","2021-02-12T00:00:00","2021-02-16T00:00:00","2021-02-17T00:00:00","2021-02-18T00:00:00","2021-02-19T00:00:00","2021-02-22T00:00:00","2021-02-23T00:00:00","2021-02-24T00:00:00","2021-02-25T00:00:00","2021-02-26T00:00:00","2021-03-01T00:00:00","2021-03-02T00:00:00","2021-03-03T00:00:00","2021-03-04T00:00:00","2021-03-05T00:00:00","2021-03-08T00:00:00","2021-03-09T00:00:00","2021-03-10T00:00:00","2021-03-11T00:00:00","2021-03-12T00:00:00","2021-03-15T00:00:00","2021-03-16T00:00:00","2021-03-17T00:00:00","2021-03-18T00:00:00","2021-03-19T00:00:00","2021-03-22T00:00:00","2021-03-23T00:00:00","2021-03-24T00:00:00","2021-03-25T00:00:00","2021-03-26T00:00:00","2021-03-29T00:00:00","2021-03-30T00:00:00","2021-03-31T00:00:00","2021-04-01T00:00:00","2021-04-05T00:00:00","2021-04-06T00:00:00","2021-04-07T00:00:00","2021-04-08T00:00:00","2021-04-09T00:00:00","2021-04-12T00:00:00","2021-04-13T00:00:00","2021-04-14T00:00:00","2021-04-15T00:00:00","2021-04-16T00:00:00","2021-04-19T00:00:00","2021-04-20T00:00:00"],"y":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,202.03999710083008,202.03999710083008,202.55249786376953,203.9474983215332,204.36749649047852,204.86249542236328,205.99999618530273,205.99999618530273,205.99999618530273,207.7349967956543,207.7349967956543,207.7349967956543,207.7349967956543,208.40500259399414,209.47999954223633,209.47999954223633,210.17999649047852,211.48999786376953,213.51499938964844,213.51499938964844,213.75500106811523,214.5374984741211,215.125,216.5974998474121,217.49250411987305,219.75750350952148]},{"fill":"tonexty","fillcolor":"rgba(250,0,0,0.4)","line":{"color":"rgba(0,0,0,0)"},"type":"scatter","x":["2020-12-29T00:00:00","2020-12-30T00:00:00","2020-12-31T00:00:00","2021-01-04T00:00:00","2021-01-05T00:00:00","2021-01-06T00:00:00","2021-01-07T00:00:00","2021-01-08T00:00:00","2021-01-11T00:00:00","2021-01-12T00:00:00","2021-01-13T00:00:00","2021-01-14T00:00:00","2021-01-15T00:00:00","2021-01-19T00:00:00","2021-01-20T00:00:00","2021-01-21T00:00:00","2021-01-22T00:00:00","2021-01-25T00:00:00","2021-01-26T00:00:00","2021-01-27T00:00:00","2021-01-28T00:00:00","2021-01-29T00:00:00","2021-02-01T00:00:00","2021-02-02T00:00:00","2021-02-03T00:00:00","2021-02-04T00:00:00","2021-02-05T00:00:00","2021-02-08T00:00:00","2021-02-09T00:00:00","2021-02-10T00:00:00","2021-02-11T00:00:00","2021-02-12T00:00:00","2021-02-16T00:00:00","2021-02-17T00:00:00","2021-02-18T00:00:00","2021-02-19T00:00:00","2021-02-22T00:00:00","2021-02-23T00:00:00","2021-02-24T00:00:00","2021-02-25T00 ...

# %% [markdown]
# ## Top Healthcare

# %%
health_care.sort_values(by=['CUM_RET'], ascending=False).head(10)
# Out:
#    Ticker   CUM_RET
# 25   DXCM  8.678003
# 4    ALGN  6.780879
# 59    WST  5.223830
# 33   IDXX  5.053621
# 16   CTLT  4.888889
# 19    CRL  4.766054
# 61    ZTS  4.687021
# 11   TECH  4.586297
# 54    TMO  4.488118
# 49    RMD  4.426924

# %% [markdown]
# ## Top Information Tech

# %%
it.sort_values(by=['CUM_RET'], ascending=False).head(10)
# Out:
#    Ticker     CUM_RET
# 21   ENPH  172.016003
# 2     AMD   12.785159
# 26   FTNT   11.098766
# 50   PAYC    9.118401
# 57    NOW    8.307653
# 70   ZBRA    7.422101
# 39   LRCX    7.366411
# 14   CDNS    7.123404
# 44   MPWR    6.569404
# 7    AAPL    6.523364

# %% [markdown]
# ## Top Communications

# %%
commun.sort_values(by=['CUM_RET'], ascending=False).head(10)
# Out:
#    Ticker   CUM_RET
# 15   NFLX  4.863241
# 14    LYV  4.160283
# 2    GOOG  3.723259
# 1   GOOGL  3.663857
# 20   TTWO  3.310014
# 10     FB  2.943717
# 22   TWTR  2.406762
# 4    CHTR  2.198079
# 19   TMUS  2.044718
# 16   NWSA  1.950593

# %% [markdown]
# ## Top Staples

# %%
staple.sort_values(by=['CUM_RET'], ascending=False).head(10)
# Out:
#    Ticker   CUM_RET
# 10     EL  4.850015
# 9    COST  3.904326
# 3     CHD  2.302912
# 30    WMT  2.189100
# 25     PG  2.105584
# 27    HSY  2.069291
# 22   MNST  2.022815
# 23    PEP  1.868988
# 18     LW  1.661314
# 4     CLX  1.647645

# %% [markdown]
# ## Top Discretionary

# %%
discretion.sort_values(by=['CUM_RET'], ascending=False).head(10)
# Out:
#    Ticker    CUM_RET
# 17   ETSY  18.495894
# 43   POOL   5.587690
# 7     CZR   5.561250
# 52   TSLA   5.285195
# 10    CMG   4.500627
# 1    AMZN   4.418258
# 11    DHI   3.989342
# 32    LOW   3.836499
# 51    TGT   3.567896
# 40    NVR   3.563927

# %% [markdown]
# ## Top Utilities

# %%
utility.sort_values(by=['CUM_RET'], ascending=False).head(10)
# Out:
#    Ticker   CUM_RET
# 20    NRG  3.344245
# 4     AWK  2.610672
# 0     AES  2.447139
# 2     AEE  1.951904
# 27    XEL  1.902183
# 26    WEC  1.879371
# 15     ES  1.864813
# 16    EXC  1.853503
# 1     LNT  1.839575
# 13    ETR  1.829929

# %% [markdown]
# ## Top Finance

# %%
finance.sort_values(by=['CUM_RET'], ascending=False).head(10)
# Out:
#    Ticker   CUM_RET
# 39   MSCI  8.216773
# 49   SPGI  4.377400
# 37    MCO  4.265219
# 51   SIVB  4.240737
# 6     AJG  3.696233
# 40   NDAQ  3.277685
# 45    PGR  3.157559
# 53   TROW  2.999332
# 4     AMP  2.910101
# 38     MS  2.774116

# %% [markdown]
# ## Top Materials

# %%
material.sort_values(by=['CUM_RET'], ascending=False).head(10)
# Out:
#    Ticker   CUM_RET
# 2     AVY  3.200383
# 1     ALB  3.093036
# 14    LIN  2.973870
# 11    FCX  2.594122
# 3     BLL  2.557432
# 5      CF  2.458485
# 10    FMC  2.295981
# 0     APD  2.235855
# 4      CE  2.148049
# 16    MLM  2.048859

# %% [markdown]
# ## Top Real Estate

# %%
restate.sort_values(by=['CUM_RET'], ascending=False).head(10)
# Out:
#    Ticker   CUM_RET
# 21   SBAC  3.659762
# 17    PLD  3.442297
# 11    EXR  3.331300
# 4    CBRE  3.205564
# 1     AMT  2.894263
# 7     DRE  2.720885
# 16    MAA  2.698131
# 5     CCI  2.652901
# 8    EQIX  2.448353
# 0     ARE  2.220472

# %% [markdown]
# ## Top Energy

# %%
energy.sort_values(by=['CUM_RET'], ascending=False).head(10)
# Out:
#    Ticker   CUM_RET
# 2     COP  1.632314
# 11    MPC  1.565467
# 14    OKE  1.515579
# 8     HES  1.382084
# 18    VLO  1.336799
# 1     CVX  1.262320
# 19    WMB  1.198860
# 4    FANG  1.131944
# 16    PXD  1.049206
# 3     DVN  1.035698
