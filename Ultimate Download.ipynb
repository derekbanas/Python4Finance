# %%
# Provides ways to work with large multidimensional arrays
import numpy as np 
# Allows for further data manipulation and analysis
import pandas as pd 
import matplotlib.pyplot as plt # Plotting
import matplotlib.dates as mdates # Styling dates
# %matplotlib inline

# pip install numpy
# conda install -c anaconda pandas
# conda install -c conda-forge matplotlib

import datetime as dt # For defining dates

import time

# In Powershell Prompt : conda install -c conda-forge multitasking
# pip install -i https://pypi.anaconda.org/ranaroussi/simple yfinance

import yfinance as yf

# To show all your output File -> Preferences -> Settings Search for Notebook
# Notebook Output Text Line Limit and set to 100

# Used for file handling like deleting files
import os

# conda install -c conda-forge cufflinks-py
# conda install -c plotly plotly
import cufflinks as cf
import plotly.express as px
import plotly.graph_objects as go

# Make Plotly work in your Jupyter Notebook
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Use Plotly locally
cf.go_offline()

from plotly.subplots import make_subplots

# New Imports
# Used to get data from a directory
import os
from os import listdir
from os.path import isfile, join

import warnings
warnings.simplefilter("ignore")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Constants

# %%
PATH = "D:/Python for Finance/Wilshire_Stocks/"

# Start end date defaults
S_DATE = "2017-02-01"
E_DATE = "2022-12-06"
S_DATE_DT = pd.to_datetime(S_DATE)
E_DATE_DT = pd.to_datetime(E_DATE)

# %% [markdown]
# ## Get Column Data from CSV

# %%
def get_column_from_csv(file, col_name):
    # Try to get the file and if it doesn't exist issue a warning
    try:
        df = pd.read_csv(file)
    except FileNotFoundError:
        print("File Doesn't Exist")
    else:
        return df[col_name]

# %% [markdown]
# ## Get Stock Tickers

# %%
tickers = get_column_from_csv("D:/Python for Finance/Wilshire-5000-Stocks.csv", "Ticker")
print(len(tickers))
# Out:
# 3481

# %% [markdown]
# ## Save Stock Data to CSV

# %%
# Function that gets a dataframe by providing a ticker and starting date
def save_to_csv_from_yahoo(folder, ticker):
    stock = yf.Ticker(ticker)
    
    try:
        print("Get Data for : ", ticker)
        # Get historical closing price data
        df = stock.history(period="5y")
    
        # Wait 2 seconds
        time.sleep(2)
        
        # Remove the period for saving the file name
        # Save data to a CSV file
        # File to save to 
        the_file = folder + ticker.replace(".", "_") + '.csv'
        print(the_file, " Saved")
        df.to_csv(the_file)
    except Exception as ex:
        print("Couldn't Get Data for :", ticker)

# %% [markdown]
# ## Download All Stocks

# %%
for x in range(0, 3481):
    save_to_csv_from_yahoo(PATH, tickers[x])
    print("Finished")
# Out:
# Get Data for :  A
# D:/Python for Finance/Wilshire_Stocks/A.csv  Saved
# Finished
# Get Data for :  AA
# D:/Python for Finance/Wilshire_Stocks/AA.csv  Saved
# Finished
# Get Data for :  AAL
# D:/Python for Finance/Wilshire_Stocks/AAL.csv  Saved
# Finished
# Get Data for :  AAME
# D:/Python for Finance/Wilshire_Stocks/AAME.csv  Saved
# Finished
# Get Data for :  AAN
# D:/Python for Finance/Wilshire_Stocks/AAN.csv  Saved
# Finished
# Get Data for :  AAOI
# D:/Python for Finance/Wilshire_Stocks/AAOI.csv  Saved
# Finished
# Get Data for :  AAON
# D:/Python for Finance/Wilshire_Stocks/AAON.csv  Saved
# Finished
# Get Data for :  AAP
# D:/Python for Finance/Wilshire_Stocks/AAP.csv  Saved
# Finished
# Get Data for :  AAPL
# D:/Python for Finance/Wilshire_Stocks/AAPL.csv  Saved
# Finished
# Get Data for :  AAT
# D:/Python for Finance/Wilshire_Stocks/AAT.csv  Saved
# Finished
# Get Data for :  AAWW
# D:/Python for Finance/Wilshire_Stocks/AAWW.csv  Saved
# Finished
# Get Data for :  AAXN
# - AAXN: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/AAXN.csv  Saved
# Finished
# Get Data for :  ABBV
# D:/Python for Finance/Wilshire_Stocks/ABBV.csv  Saved
# Finished
# Get Data for :  ABC
# D:/Python for Finance/Wilshire_Stocks/ABC.csv  Saved
# Finished
# Get Data for :  ABCB
# D:/Python for Finance/Wilshire_Stocks/ABCB.csv  Saved
# Finished
# Get Data for :  ABEO
# D:/Python for Finance/Wilshire_Stocks/ABEO.csv  Saved
# Finished
# Get Data for :  ABG
# D:/Python for Finance/Wilshire_Stocks/ABG.csv  Saved
# Finished
# Get Data for :  ABIO
# D:/Python for Finance/Wilshire_Stocks/ABIO.csv  Saved
# Finished
# Get Data for :  ABM
# D:/Python for Finance/Wilshire_Stocks/ABM.csv  Saved
# Finished
# Get Data for :  ABMD
# D:/Python for Finance/Wilshire_Stocks/ABMD.csv  Saved
# Finished
# Get Data for :  ABR
# D:/Python for Finance/Wilshire_Stocks/ABR.csv  Saved
# Finished
# Get Data for :  ABT
# D:/Python for Finance/Wilshire_Stocks/ABT.csv  Saved
# Finished
# Get Data for :  ABTX
# D:/Python for Finance/Wilshire_Stocks/ABTX.csv  Saved
# Finished
# Get Data for :  AC
# D:/Python for Finance/Wilshire_Stocks/AC.csv  Saved
# Finished
# Get Data for :  ACA
# D:/Python for Finance/Wilshire_Stocks/ACA.csv  Saved
# Finished
# Get Data for :  ACAD
# D:/Python for Finance/Wilshire_Stocks/ACAD.csv  Saved
# Finished
# Get Data for :  ACBI
# D:/Python for Finance/Wilshire_Stocks/ACBI.csv  Saved
# Finished
# Get Data for :  ACC
# D:/Python for Finance/Wilshire_Stocks/ACC.csv  Saved
# Finished
# Get Data for :  ACCO
# D:/Python for Finance/Wilshire_Stocks/ACCO.csv  Saved
# Finished
# Get Data for :  ACER
# D:/Python for Finance/Wilshire_Stocks/ACER.csv  Saved
# Finished
# Get Data for :  ACGL
# D:/Python for Finance/Wilshire_Stocks/ACGL.csv  Saved
# Finished
# Get Data for :  ACHC
# D:/Python for Finance/Wilshire_Stocks/ACHC.csv  Saved
# Finished
# Get Data for :  ACHV
# D:/Python for Finance/Wilshire_Stocks/ACHV.csv  Saved
# Finished
# Get Data for :  ACIA
# - ACIA: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/ACIA.csv  Saved
# Finished
# Get Data for :  ACIW
# D:/Python for Finance/Wilshire_Stocks/ACIW.csv  Saved
# Finished
# Get Data for :  ACLS
# D:/Python for Finance/Wilshire_Stocks/ACLS.csv  Saved
# Finished
# Get Data for :  ACM
# D:/Python for Finance/Wilshire_Stocks/ACM.csv  Saved
# Finished
# Get Data for :  ACMR
# D:/Python for Finance/Wilshire_Stocks/ACMR.csv  Saved
# Finished
# Get Data for :  ACN
# D:/Python for Finance/Wilshire_Stocks/ACN.csv  Saved
# Finished
# Get Data for :  ACNB
# D:/Python for Finance/Wilshire_Stocks/ACNB.csv  Saved
# Finished
# Get Data for :  ACOR
# D:/Python for Finance/Wilshire_Stocks/ACOR.csv  Saved
# Finished
# Get Data for :  ACRE
# D:/Python for Finance/Wilshire_Stocks/ACRE.csv  Saved
# Finished
# Get Data for :  ACRS
# D:/Python for Finance/Wilshire_Stocks/ACRS.csv  Saved
# Finished
# Get Data for :  ACRX
# D:/Python for Finance/Wilshire_Stocks/ACRX.csv  Saved
# Finished
# Get Data for :  ACTG
# D:/Python for Finance/Wilshire_Stocks/ACTG.csv  Saved
# Finished
# Get Data for :  ACU
# D:/Python for Finance/Wilshire_Stocks/ACU.csv  Saved
# Finished
# Get Data for :  ACY
# D:/Python for Finance/Wilshire_Stocks/ACY.csv  Saved
# Finished
# Get Data for :  ADBE
# D:/Python for Finance/Wilshire_Stocks/ADBE.csv  Saved
# Finished
# Get Data for :  ADC
# D:/Python for Finance/Wilshire_Stocks/ADC.csv  Saved
# Finished
# Get Data for :  ADES
# D:/Python for Finance/Wilshire_Stocks/ADES.csv  Saved
# Finished
# Get Data for :  ADI
# D:/Python for Finance/Wilshire_Stocks/ADI.csv  Saved
# Finished
# Get Data for :  ADM
# D:/Python for Finance/Wilshire_Stocks/ADM.csv  Saved
# Finished
# Get Data for :  ADMA
# D:/Python for Finance/Wilshire_Stocks/ADMA.csv  Saved
# Finished
# Get Data for :  ADMP
# D:/Python for Finance/Wilshire_Stocks/ADMP.csv  Saved
# Finished
# Get Data for :  ADMS
# D:/Python for Finance/Wilshire_Stocks/ADMS.csv  Saved
# Finished
# Get Data for :  ADNT
# D:/Python for Finance/Wilshire_Stocks/ADNT.csv  Saved
# Finished
# Get Data for :  ADP
# D:/Python for Finance/Wilshire_Stocks/ADP.csv  Saved
# Finished
# Get Data for :  ADRO
# - ADRO: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/ADRO.csv  Saved
# Finished
# Get Data for :  ADS
# D:/Python for Finance/Wilshire_Stocks/ADS.csv  Saved
# Finished
# Get Data for :  ADSK
# D:/Python for Finance/Wilshire_Stocks/ADSK.csv  Saved
# Finished
# Get Data for :  ADSW
# - ADSW: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/ADSW.csv  Saved
# Finished
# Get Data for :  ADT
# D:/Python for Finance/Wilshire_Stocks/ADT.csv  Saved
# Finished
# Get Data for :  ADTN
# D:/Python for Finance/Wilshire_Stocks/ADTN.csv  Saved
# Finished
# Get Data for :  ADUS
# D:/Python for Finance/Wilshire_Stocks/ADUS.csv  Saved
# Finished
# Get Data for :  ADVM
# D:/Python for Finance/Wilshire_Stocks/ADVM.csv  Saved
# Finished
# Get Data for :  ADXS
# D:/Python for Finance/Wilshire_Stocks/ADXS.csv  Saved
# Finished
# Get Data for :  AE
# D:/Python for Finance/Wilshire_Stocks/AE.csv  Saved
# Finished
# Get Data for :  AEE
# D:/Python for Finance/Wilshire_Stocks/AEE.csv  Saved
# Finished
# Get Data for :  AEGN
# - AEGN: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/AEGN.csv  Saved
# Finished
# Get Data for :  AEHR
# D:/Python for Finance/Wilshire_Stocks/AEHR.csv  Saved
# Finished
# Get Data for :  AEIS
# D:/Python for Finance/Wilshire_Stocks/AEIS.csv  Saved
# Finished
# Get Data for :  AEL
# D:/Python for Finance/Wilshire_Stocks/AEL.csv  Saved
# Finished
# Get Data for :  AEMD
# D:/Python for Finance/Wilshire_Stocks/AEMD.csv  Saved
# Finished
# Get Data for :  AEO
# D:/Python for Finance/Wilshire_Stocks/AEO.csv  Saved
# Finished
# Get Data for :  AEP
# D:/Python for Finance/Wilshire_Stocks/AEP.csv  Saved
# Finished
# Get Data for :  AERI
# D:/Python for Finance/Wilshire_Stocks/AERI.csv  Saved
# Finished
# Get Data for :  AES
# D:/Python for Finance/Wilshire_Stocks/AES.csv  Saved
# Finished
# Get Data for :  AEY
# D:/Python for Finance/Wilshire_Stocks/AEY.csv  Saved
# Finished
# Get Data for :  AFG
# D:/Python for Finance/Wilshire_Stocks/AFG.csv  Saved
# Finished
# Get Data for :  AFH
# - AFH: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/AFH.csv  Saved
# Finished
# Get Data for :  AFI
# D:/Python for Finance/Wilshire_Stocks/AFI.csv  Saved
# Finished
# Get Data for :  AFIN
# D:/Python for Finance/Wilshire_Stocks/AFIN.csv  Saved
# Finished
# Get Data for :  AFL
# D:/Python for Finance/Wilshire_Stocks/AFL.csv  Saved
# Finished
# Get Data for :  AGCO
# D:/Python for Finance/Wilshire_Stocks/AGCO.csv  Saved
# Finished
# Get Data for :  AGE
# D:/Python for Finance/Wilshire_Stocks/AGE.csv  Saved
# Finished
# Get Data for :  AGEN
# D:/Python for Finance/Wilshire_Stocks/AGEN.csv  Saved
# Finished
# Get Data for :  AGFS
# D:/Python for Finance/Wilshire_Stocks/AGFS.csv  Saved
# Finished
# Get Data for :  AGIO
# D:/Python for Finance/Wilshire_Stocks/AGIO.csv  Saved
# Finished
# Get Data for :  AGLE
# D:/Python for Finance/Wilshire_Stocks/AGLE.csv  Saved
# Finished
# Get Data for :  AGM
# D:/Python for Finance/Wilshire_Stocks/AGM.csv  Saved
# Finished
# Get Data for :  AGNC
# D:/Python for Finance/Wilshire_Stocks/AGNC.csv  Saved
# Finished
# Get Data for :  AGO
# D:/Python for Finance/Wilshire_Stocks/AGO.csv  Saved
# Finished
# Get Data for :  AGR
# D:/Python for Finance/Wilshire_Stocks/AGR.csv  Saved
# Finished
# Get Data for :  AGRX
# D:/Python for Finance/Wilshire_Stocks/AGRX.csv  Saved
# Finished
# Get Data for :  AGS
# D:/Python for Finance/Wilshire_Stocks/AGS.csv  Saved
# Finished
# Get Data for :  AGTC
# D:/Python for Finance/Wilshire_Stocks/AGTC.csv  Saved
# Finished
# Get Data for :  AGX
# D:/Python for Finance/Wilshire_Stocks/AGX.csv  Saved
# Finished
# Get Data for :  AGYS
# D:/Python for Finance/Wilshire_Stocks/AGYS.csv  Saved
# Finished
# Get Data for :  AHC
# - AHC: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/AHC.csv  Saved
# Finished
# Get Data for :  AHH
# D:/Python for Finance/Wilshire_Stocks/AHH.csv  Saved
# Finished
# Get Data for :  AHT
# D:/Python for Finance/Wilshire_Stocks/AHT.csv  Saved
# Finished
# Get Data for :  AIG
# D:/Python for Finance/Wilshire_Stocks/AIG.csv  Saved
# Finished
# Get Data for :  AIMC
# D:/Python for Finance/Wilshire_Stocks/AIMC.csv  Saved
# Finished
# Get Data for :  AIMT
# - AIMT: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/AIMT.csv  Saved
# Finished
# Get Data for :  AIN
# D:/Python for Finance/Wilshire_Stocks/AIN.csv  Saved
# Finished
# Get Data for :  AINC
# D:/Python for Finance/Wilshire_Stocks/AINC.csv  Saved
# Finished
# Get Data for :  AIR
# D:/Python for Finance/Wilshire_Stocks/AIR.csv  Saved
# Finished
# Get Data for :  AIRG
# D:/Python for Finance/Wilshire_Stocks/AIRG.csv  Saved
# Finished
# Get Data for :  AIRI
# D:/Python for Finance/Wilshire_Stocks/AIRI.csv  Saved
# Finished
# Get Data for :  AIRT
# D:/Python for Finance/Wilshire_Stocks/AIRT.csv  Saved
# Finished
# Get Data for :  AIT
# D:/Python for Finance/Wilshire_Stocks/AIT.csv  Saved
# Finished
# Get Data for :  AIV
# D:/Python for Finance/Wilshire_Stocks/AIV.csv  Saved
# Finished
# Get Data for :  AIZ
# D:/Python for Finance/Wilshire_Stocks/AIZ.csv  Saved
# Finished
# Get Data for :  AJG
# D:/Python for Finance/Wilshire_Stocks/AJG.csv  Saved
# Finished
# Get Data for :  AJRD
# D:/Python for Finance/Wilshire_Stocks/AJRD.csv  Saved
# Finished
# Get Data for :  AJX
# D:/Python for Finance/Wilshire_Stocks/AJX.csv  Saved
# Finished
# Get Data for :  AKAM
# D:/Python for Finance/Wilshire_Stocks/AKAM.csv  Saved
# Finished
# Get Data for :  AKBA
# D:/Python for Finance/Wilshire_Stocks/AKBA.csv  Saved
# Finished
# Get Data for :  AKCA
# - AKCA: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/AKCA.csv  Saved
# Finished
# Get Data for :  AKER
# - AKER: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/AKER.csv  Saved
# Finished
# Get Data for :  AKR
# D:/Python for Finance/Wilshire_Stocks/AKR.csv  Saved
# Finished
# Get Data for :  AKTS
# D:/Python for Finance/Wilshire_Stocks/AKTS.csv  Saved
# Finished
# Get Data for :  AL
# D:/Python for Finance/Wilshire_Stocks/AL.csv  Saved
# Finished
# Get Data for :  ALB
# D:/Python for Finance/Wilshire_Stocks/ALB.csv  Saved
# Finished
# Get Data for :  ALBO
# D:/Python for Finance/Wilshire_Stocks/ALBO.csv  Saved
# Finished
# Get Data for :  ALCO
# D:/Python for Finance/Wilshire_Stocks/ALCO.csv  Saved
# Finished
# Get Data for :  ALDX
# D:/Python for Finance/Wilshire_Stocks/ALDX.csv  Saved
# Finished
# Get Data for :  ALE
# D:/Python for Finance/Wilshire_Stocks/ALE.csv  Saved
# Finished
# Get Data for :  ALEC
# D:/Python for Finance/Wilshire_Stocks/ALEC.csv  Saved
# Finished
# Get Data for :  ALEX
# D:/Python for Finance/Wilshire_Stocks/ALEX.csv  Saved
# Finished
# Get Data for :  ALG
# D:/Python for Finance/Wilshire_Stocks/ALG.csv  Saved
# Finished
# Get Data for :  ALGN
# D:/Python for Finance/Wilshire_Stocks/ALGN.csv  Saved
# Finished
# Get Data for :  ALGT
# D:/Python for Finance/Wilshire_Stocks/ALGT.csv  Saved
# Finished
# Get Data for :  ALIM
# D:/Python for Finance/Wilshire_Stocks/ALIM.csv  Saved
# Finished
# Get Data for :  ALJJ
# D:/Python for Finance/Wilshire_Stocks/ALJJ.csv  Saved
# Finished
# Get Data for :  ALK
# D:/Python for Finance/Wilshire_Stocks/ALK.csv  Saved
# Finished
# Get Data for :  ALKS
# D:/Python for Finance/Wilshire_Stocks/ALKS.csv  Saved
# Finished
# Get Data for :  ALL
# D:/Python for Finance/Wilshire_Stocks/ALL.csv  Saved
# Finished
# Get Data for :  ALLE
# D:/Python for Finance/Wilshire_Stocks/ALLE.csv  Saved
# Finished
# Get Data for :  ALLK
# D:/Python for Finance/Wilshire_Stocks/ALLK.csv  Saved
# Finished
# Get Data for :  ALLO
# D:/Python for Finance/Wilshire_Stocks/ALLO.csv  Saved
# Finished
# Get Data for :  ALLY
# D:/Python for Finance/Wilshire_Stocks/ALLY.csv  Saved
# Finished
# Get Data for :  ALNA
# D:/Python for Finance/Wilshire_Stocks/ALNA.csv  Saved
# Finished
# Get Data for :  ALNY
# D:/Python for Finance/Wilshire_Stocks/ALNY.csv  Saved
# Finished
# Get Data for :  ALOT
# D:/Python for Finance/Wilshire_Stocks/ALOT.csv  Saved
# Finished
# Get Data for :  ALPN
# D:/Python for Finance/Wilshire_Stocks/ALPN.csv  Saved
# Finished
# Get Data for :  ALRM
# D:/Python for Finance/Wilshire_Stocks/ALRM.csv  Saved
# Finished
# Get Data for :  ALSK
# - ALSK: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/ALSK.csv  Saved
# Finished
# Get Data for :  ALSN
# D:/Python for Finance/Wilshire_Stocks/ALSN.csv  Saved
# Finished
# Get Data for :  ALT
# D:/Python for Finance/Wilshire_Stocks/ALT.csv  Saved
# Finished
# Get Data for :  ALTM
# D:/Python for Finance/Wilshire_Stocks/ALTM.csv  Saved
# Finished
# Get Data for :  ALTR
# D:/Python for Finance/Wilshire_Stocks/ALTR.csv  Saved
# Finished
# Get Data for :  ALV
# D:/Python for Finance/Wilshire_Stocks/ALV.csv  Saved
# Finished
# Get Data for :  ALX
# D:/Python for Finance/Wilshire_Stocks/ALX.csv  Saved
# Finished
# Get Data for :  ALXN
# - ALXN: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/ALXN.csv  Saved
# Finished
# Get Data for :  AM
# D:/Python for Finance/Wilshire_Stocks/AM.csv  Saved
# Finished
# Get Data for :  AMAG
# - AMAG: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/AMAG.csv  Saved
# Finished
# Get Data for :  AMAL
# D:/Python for Finance/Wilshire_Stocks/AMAL.csv  Saved
# Finished
# Get Data for :  AMAT
# D:/Python for Finance/Wilshire_Stocks/AMAT.csv  Saved
# Finished
# Get Data for :  AMBC
# D:/Python for Finance/Wilshire_Stocks/AMBC.csv  Saved
# Finished
# Get Data for :  AMC
# D:/Python for Finance/Wilshire_Stocks/AMC.csv  Saved
# Finished
# Get Data for :  AMCX
# D:/Python for Finance/Wilshire_Stocks/AMCX.csv  Saved
# Finished
# Get Data for :  AMD
# D:/Python for Finance/Wilshire_Stocks/AMD.csv  Saved
# Finished
# Get Data for :  AME
# D:/Python for Finance/Wilshire_Stocks/AME.csv  Saved
# Finished
# Get Data for :  AMED
# D:/Python for Finance/Wilshire_Stocks/AMED.csv  Saved
# Finished
# Get Data for :  AMG
# D:/Python for Finance/Wilshire_Stocks/AMG.csv  Saved
# Finished
# Get Data for :  AMGN
# D:/Python for Finance/Wilshire_Stocks/AMGN.csv  Saved
# Finished
# Get Data for :  AMH
# D:/Python for Finance/Wilshire_Stocks/AMH.csv  Saved
# Finished
# Get Data for :  AMKR
# D:/Python for Finance/Wilshire_Stocks/AMKR.csv  Saved
# Finished
# Get Data for :  AMN
# D:/Python for Finance/Wilshire_Stocks/AMN.csv  Saved
# Finished
# Get Data for :  AMNB
# D:/Python for Finance/Wilshire_Stocks/AMNB.csv  Saved
# Finished
# Get Data for :  AMOT
# D:/Python for Finance/Wilshire_Stocks/AMOT.csv  Saved
# Finished
# Get Data for :  AMP
# D:/Python for Finance/Wilshire_Stocks/AMP.csv  Saved
# Finished
# Get Data for :  AMPE
# D:/Python for Finance/Wilshire_Stocks/AMPE.csv  Saved
# Finished
# Get Data for :  AMPH
# D:/Python for Finance/Wilshire_Stocks/AMPH.csv  Saved
# Finished
# Get Data for :  AMRB
# - AMRB: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/AMRB.csv  Saved
# Finished
# Get Data for :  AMRC
# D:/Python for Finance/Wilshire_Stocks/AMRC.csv  Saved
# Finished
# Get Data for :  AMRK
# D:/Python for Finance/Wilshire_Stocks/AMRK.csv  Saved
# Finished
# Get Data for :  AMRS
# D:/Python for Finance/Wilshire_Stocks/AMRS.csv  Saved
# Finished
# Get Data for :  AMRX
# D:/Python for Finance/Wilshire_Stocks/AMRX.csv  Saved
# Finished
# Get Data for :  AMS
# D:/Python for Finance/Wilshire_Stocks/AMS.csv  Saved
# Finished
# Get Data for :  AMSC
# D:/Python for Finance/Wilshire_Stocks/AMSC.csv  Saved
# Finished
# Get Data for :  AMSF
# D:/Python for Finance/Wilshire_Stocks/AMSF.csv  Saved
# Finished
# Get Data for :  AMSWA
# D:/Python for Finance/Wilshire_Stocks/AMSWA.csv  Saved
# Finished
# Get Data for :  AMT
# D:/Python for Finance/Wilshire_Stocks/AMT.csv  Saved
# Finished
# Get Data for :  AMTD
# - AMTD: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/AMTD.csv  Saved
# Finished
# Get Data for :  AMTX
# D:/Python for Finance/Wilshire_Stocks/AMTX.csv  Saved
# Finished
# Get Data for :  AMWD
# D:/Python for Finance/Wilshire_Stocks/AMWD.csv  Saved
# Finished
# Get Data for :  AMZN
# D:/Python for Finance/Wilshire_Stocks/AMZN.csv  Saved
# Finished
# Get Data for :  AN
# D:/Python for Finance/Wilshire_Stocks/AN.csv  Saved
# Finished
# Get Data for :  ANAB
# D:/Python for Finance/Wilshire_Stocks/ANAB.csv  Saved
# Finished
# Get Data for :  ANAT
# D:/Python for Finance/Wilshire_Stocks/ANAT.csv  Saved
# Finished
# Get Data for :  ANDE
# D:/Python for Finance/Wilshire_Stocks/ANDE.csv  Saved
# Finished
# Get Data for :  ANET
# D:/Python for Finance/Wilshire_Stocks/ANET.csv  Saved
# Finished
# Get Data for :  ANF
# D:/Python for Finance/Wilshire_Stocks/ANF.csv  Saved
# Finished
# Get Data for :  ANGI
# D:/Python for Finance/Wilshire_Stocks/ANGI.csv  Saved
# Finished
# Get Data for :  ANGO
# D:/Python for Finance/Wilshire_Stocks/ANGO.csv  Saved
# Finished
# Get Data for :  ANH
# - ANH: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/ANH.csv  Saved
# Finished
# Get Data for :  ANIK
# D:/Python for Finance/Wilshire_Stocks/ANIK.csv  Saved
# Finished
# Get Data for :  ANIP
# D:/Python for Finance/Wilshire_Stocks/ANIP.csv  Saved
# Finished
# Get Data for :  ANIX
# D:/Python for Finance/Wilshire_Stocks/ANIX.csv  Saved
# Finished
# Get Data for :  ANSS
# D:/Python for Finance/Wilshire_Stocks/ANSS.csv  Saved
# Finished
# Get Data for :  ANTM
# D:/Python for Finance/Wilshire_Stocks/ANTM.csv  Saved
# Finished
# Get Data for :  AON
# D:/Python for Finance/Wilshire_Stocks/AON.csv  Saved
# Finished
# Get Data for :  AOS
# D:/Python for Finance/Wilshire_Stocks/AOS.csv  Saved
# Finished
# Get Data for :  AOSL
# D:/Python for Finance/Wilshire_Stocks/AOSL.csv  Saved
# Finished
# Get Data for :  AP
# D:/Python for Finance/Wilshire_Stocks/AP.csv  Saved
# Finished
# Get Data for :  APA
# D:/Python for Finance/Wilshire_Stocks/APA.csv  Saved
# Finished
# Get Data for :  APAM
# D:/Python for Finance/Wilshire_Stocks/APAM.csv  Saved
# Finished
# Get Data for :  APD
# D:/Python for Finance/Wilshire_Stocks/APD.csv  Saved
# Finished
# Get Data for :  APDN
# D:/Python for Finance/Wilshire_Stocks/APDN.csv  Saved
# Finished
# Get Data for :  APEI
# D:/Python for Finance/Wilshire_Stocks/APEI.csv  Saved
# Finished
# Get Data for :  APEN
# D:/Python for Finance/Wilshire_Stocks/APEN.csv  Saved
# Finished
# Get Data for :  APH
# D:/Python for Finance/Wilshire_Stocks/APH.csv  Saved
# Finished
# Get Data for :  APLE
# D:/Python for Finance/Wilshire_Stocks/APLE.csv  Saved
# Finished
# Get Data for :  APLS
# D:/Python for Finance/Wilshire_Stocks/APLS.csv  Saved
# Finished
# Get Data for :  APOG
# D:/Python for Finance/Wilshire_Stocks/APOG.csv  Saved
# Finished
# Get Data for :  APPF
# D:/Python for Finance/Wilshire_Stocks/APPF.csv  Saved
# Finished
# Get Data for :  APPN
# D:/Python for Finance/Wilshire_Stocks/APPN.csv  Saved
# Finished
# Get Data for :  APPS
# D:/Python for Finance/Wilshire_Stocks/APPS.csv  Saved
# Finished
# Get Data for :  APRN
# D:/Python for Finance/Wilshire_Stocks/APRN.csv  Saved
# Finished
# Get Data for :  APT
# D:/Python for Finance/Wilshire_Stocks/APT.csv  Saved
# Finished
# Get Data for :  APTS
# D:/Python for Finance/Wilshire_Stocks/APTS.csv  Saved
# Finished
# Get Data for :  APTV
# D:/Python for Finance/Wilshire_Stocks/APTV.csv  Saved
# Finished
# Get Data for :  APVO
# D:/Python for Finance/Wilshire_Stocks/APVO.csv  Saved
# Finished
# Get Data for :  APYX
# D:/Python for Finance/Wilshire_Stocks/APYX.csv  Saved
# Finished
# Get Data for :  AQB
# D:/Python for Finance/Wilshire_Stocks/AQB.csv  Saved
# Finished
# Get Data for :  AQMS
# D:/Python for Finance/Wilshire_Stocks/AQMS.csv  Saved
# Finished
# Get Data for :  AQUA
# D:/Python for Finance/Wilshire_Stocks/AQUA.csv  Saved
# Finished
# Get Data for :  AR
# D:/Python for Finance/Wilshire_Stocks/AR.csv  Saved
# Finished
# Get Data for :  ARA
# - ARA: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/ARA.csv  Saved
# Finished
# Get Data for :  ARAV
# D:/Python for Finance/Wilshire_Stocks/ARAV.csv  Saved
# Finished
# Get Data for :  ARAY
# D:/Python for Finance/Wilshire_Stocks/ARAY.csv  Saved
# Finished
# Get Data for :  ARC
# D:/Python for Finance/Wilshire_Stocks/ARC.csv  Saved
# Finished
# Get Data for :  ARCB
# D:/Python for Finance/Wilshire_Stocks/ARCB.csv  Saved
# Finished
# Get Data for :  ARCH
# D:/Python for Finance/Wilshire_Stocks/ARCH.csv  Saved
# Finished
# Get Data for :  ARDX
# D:/Python for Finance/Wilshire_Stocks/ARDX.csv  Saved
# Finished
# Get Data for :  ARE
# D:/Python for Finance/Wilshire_Stocks/ARE.csv  Saved
# Finished
# Get Data for :  ARES
# D:/Python for Finance/Wilshire_Stocks/ARES.csv  Saved
# Finished
# Get Data for :  ARGO
# D:/Python for Finance/Wilshire_Stocks/ARGO.csv  Saved
# Finished
# Get Data for :  ARI
# D:/Python for Finance/Wilshire_Stocks/ARI.csv  Saved
# Finished
# Get Data for :  ARKR
# D:/Python for Finance/Wilshire_Stocks/ARKR.csv  Saved
# Finished
# Get Data for :  ARL
# D:/Python for Finance/Wilshire_Stocks/ARL.csv  Saved
# Finished
# Get Data for :  ARLO
# D:/Python for Finance/Wilshire_Stocks/ARLO.csv  Saved
# Finished
# Get Data for :  ARMK
# D:/Python for Finance/Wilshire_Stocks/ARMK.csv  Saved
# Finished
# Get Data for :  ARNA
# D:/Python for Finance/Wilshire_Stocks/ARNA.csv  Saved
# Finished
# Get Data for :  ARNC
# D:/Python for Finance/Wilshire_Stocks/ARNC.csv  Saved
# Finished
# Get Data for :  AROC
# D:/Python for Finance/Wilshire_Stocks/AROC.csv  Saved
# Finished
# Get Data for :  AROW
# D:/Python for Finance/Wilshire_Stocks/AROW.csv  Saved
# Finished
# Get Data for :  ARPO
# - ARPO: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/ARPO.csv  Saved
# Finished
# Get Data for :  ARR
# D:/Python for Finance/Wilshire_Stocks/ARR.csv  Saved
# Finished
# Get Data for :  ARTNA
# D:/Python for Finance/Wilshire_Stocks/ARTNA.csv  Saved
# Finished
# Get Data for :  ARTW
# D:/Python for Finance/Wilshire_Stocks/ARTW.csv  Saved
# Finished
# Get Data for :  ARVN
# D:/Python for Finance/Wilshire_Stocks/ARVN.csv  Saved
# Finished
# Get Data for :  ARW
# D:/Python for Finance/Wilshire_Stocks/ARW.csv  Saved
# Finished
# Get Data for :  ARWR
# D:/Python for Finance/Wilshire_Stocks/ARWR.csv  Saved
# Finished
# Get Data for :  ASB
# D:/Python for Finance/Wilshire_Stocks/ASB.csv  Saved
# Finished
# Get Data for :  ASFI
# - ASFI: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/ASFI.csv  Saved
# Finished
# Get Data for :  ASGN
# D:/Python for Finance/Wilshire_Stocks/ASGN.csv  Saved
# Finished
# Get Data for :  ASH
# D:/Python for Finance/Wilshire_Stocks/ASH.csv  Saved
# Finished
# Get Data for :  ASIX
# D:/Python for Finance/Wilshire_Stocks/ASIX.csv  Saved
# Finished
# Get Data for :  ASMB
# D:/Python for Finance/Wilshire_Stocks/ASMB.csv  Saved
# Finished
# Get Data for :  ASNA
# - ASNA: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/ASNA.csv  Saved
# Finished
# Get Data for :  ASPN
# D:/Python for Finance/Wilshire_Stocks/ASPN.csv  Saved
# Finished
# Get Data for :  ASPS
# D:/Python for Finance/Wilshire_Stocks/ASPS.csv  Saved
# Finished
# Get Data for :  ASRT
# D:/Python for Finance/Wilshire_Stocks/ASRT.csv  Saved
# Finished
# Get Data for :  ASRV
# D:/Python for Finance/Wilshire_Stocks/ASRV.csv  Saved
# Finished
# Get Data for :  ASTC
# D:/Python for Finance/Wilshire_Stocks/ASTC.csv  Saved
# Finished
# Get Data for :  ASTE
# D:/Python for Finance/Wilshire_Stocks/ASTE.csv  Saved
# Finished
# Get Data for :  ASUR
# D:/Python for Finance/Wilshire_Stocks/ASUR.csv  Saved
# Finished
# Get Data for :  ASYS
# D:/Python for Finance/Wilshire_Stocks/ASYS.csv  Saved
# Finished
# Get Data for :  ATEC
# D:/Python for Finance/Wilshire_Stocks/ATEC.csv  Saved
# Finished
# Get Data for :  ATEN
# D:/Python for Finance/Wilshire_Stocks/ATEN.csv  Saved
# Finished
# Get Data for :  ATGE
# D:/Python for Finance/Wilshire_Stocks/ATGE.csv  Saved
# Finished
# Get Data for :  ATH
# D:/Python for Finance/Wilshire_Stocks/ATH.csv  Saved
# Finished
# Get Data for :  ATHX
# D:/Python for Finance/Wilshire_Stocks/ATHX.csv  Saved
# Finished
# Get Data for :  ATI
# D:/Python for Finance/Wilshire_Stocks/ATI.csv  Saved
# Finished
# Get Data for :  ATKR
# D:/Python for Finance/Wilshire_Stocks/ATKR.csv  Saved
# Finished
# Get Data for :  ATLC
# D:/Python for Finance/Wilshire_Stocks/ATLC.csv  Saved
# Finished
# Get Data for :  ATLO
# D:/Python for Finance/Wilshire_Stocks/ATLO.csv  Saved
# Finished
# Get Data for :  ATNI
# D:/Python for Finance/Wilshire_Stocks/ATNI.csv  Saved
# Finished
# Get Data for :  ATNM
# D:/Python for Finance/Wilshire_Stocks/ATNM.csv  Saved
# Finished
# Get Data for :  ATNX
# D:/Python for Finance/Wilshire_Stocks/ATNX.csv  Saved
# Finished
# Get Data for :  ATO
# D:/Python for Finance/Wilshire_Stocks/ATO.csv  Saved
# Finished
# Get Data for :  ATOS
# D:/Python for Finance/Wilshire_Stocks/ATOS.csv  Saved
# Finished
# Get Data for :  ATR
# D:/Python for Finance/Wilshire_Stocks/ATR.csv  Saved
# Finished
# Get Data for :  ATRA
# D:/Python for Finance/Wilshire_Stocks/ATRA.csv  Saved
# Finished
# Get Data for :  ATRC
# D:/Python for Finance/Wilshire_Stocks/ATRC.csv  Saved
# Finished
# Get Data for :  ATRI
# D:/Python for Finance/Wilshire_Stocks/ATRI.csv  Saved
# Finished
# Get Data for :  ATRO
# D:/Python for Finance/Wilshire_Stocks/ATRO.csv  Saved
# Finished
# Get Data for :  ATRS
# D:/Python for Finance/Wilshire_Stocks/ATRS.csv  Saved
# Finished
# Get Data for :  ATSG
# D:/Python for Finance/Wilshire_Stocks/ATSG.csv  Saved
# Finished
# Get Data for :  ATUS
# D:/Python for Finance/Wilshire_Stocks/ATUS.csv  Saved
# Finished
# Get Data for :  ATVI
# D:/Python for Finance/Wilshire_Stocks/ATVI.csv  Saved
# Finished
# Get Data for :  AUBN
# D:/Python for Finance/Wilshire_Stocks/AUBN.csv  Saved
# Finished
# Get Data for :  AUMN
# D:/Python for Finance/Wilshire_Stocks/AUMN.csv  Saved
# Finished
# Get Data for :  AUTO
# D:/Python for Finance/Wilshire_Stocks/AUTO.csv  Saved
# Finished
# Get Data for :  AVA
# D:/Python for Finance/Wilshire_Stocks/AVA.csv  Saved
# Finished
# Get Data for :  AVAV
# D:/Python for Finance/Wilshire_Stocks/AVAV.csv  Saved
# Finished
# Get Data for :  AVB
# D:/Python for Finance/Wilshire_Stocks/AVB.csv  Saved
# Finished
# Get Data for :  AVD
# D:/Python for Finance/Wilshire_Stocks/AVD.csv  Saved
# Finished
# Get Data for :  AVEO
# D:/Python for Finance/Wilshire_Stocks/AVEO.csv  Saved
# Finished
# Get Data for :  AVGO
# D:/Python for Finance/Wilshire_Stocks/AVGO.csv  Saved
# Finished
# Get Data for :  AVGR
# D:/Python for Finance/Wilshire_Stocks/AVGR.csv  Saved
# Finished
# Get Data for :  AVID
# D:/Python for Finance/Wilshire_Stocks/AVID.csv  Saved
# Finished
# Get Data for :  AVLR
# D:/Python for Finance/Wilshire_Stocks/AVLR.csv  Saved
# Finished
# Get Data for :  AVNS
# D:/Python for Finance/Wilshire_Stocks/AVNS.csv  Saved
# Finished
# Get Data for :  AVNW
# D:/Python for Finance/Wilshire_Stocks/AVNW.csv  Saved
# Finished
# Get Data for :  AVRO
# D:/Python for Finance/Wilshire_Stocks/AVRO.csv  Saved
# Finished
# Get Data for :  AVT
# D:/Python for Finance/Wilshire_Stocks/AVT.csv  Saved
# Finished
# Get Data for :  AVTR
# D:/Python for Finance/Wilshire_Stocks/AVTR.csv  Saved
# Finished
# Get Data for :  AVXL
# D:/Python for Finance/Wilshire_Stocks/AVXL.csv  Saved
# Finished
# Get Data for :  AVY
# D:/Python for Finance/Wilshire_Stocks/AVY.csv  Saved
# Finished
# Get Data for :  AVYA
# D:/Python for Finance/Wilshire_Stocks/AVYA.csv  Saved
# Finished
# Get Data for :  AWI
# D:/Python for Finance/Wilshire_Stocks/AWI.csv  Saved
# Finished
# Get Data for :  AWK
# D:/Python for Finance/Wilshire_Stocks/AWK.csv  Saved
# Finished
# Get Data for :  AWR
# D:/Python for Finance/Wilshire_Stocks/AWR.csv  Saved
# Finished
# Get Data for :  AWRE
# D:/Python for Finance/Wilshire_Stocks/AWRE.csv  Saved
# Finished
# Get Data for :  AWSM
# - AWSM: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/AWSM.csv  Saved
# Finished
# Get Data for :  AX
# D:/Python for Finance/Wilshire_Stocks/AX.csv  Saved
# Finished
# Get Data for :  AXAS
# D:/Python for Finance/Wilshire_Stocks/AXAS.csv  Saved
# Finished
# Get Data for :  AXDX
# D:/Python for Finance/Wilshire_Stocks/AXDX.csv  Saved
# Finished
# Get Data for :  AXE
# - AXE: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/AXE.csv  Saved
# Finished
# Get Data for :  AXGN
# D:/Python for Finance/Wilshire_Stocks/AXGN.csv  Saved
# Finished
# Get Data for :  AXL
# D:/Python for Finance/Wilshire_Stocks/AXL.csv  Saved
# Finished
# Get Data for :  AXNX
# D:/Python for Finance/Wilshire_Stocks/AXNX.csv  Saved
# Finished
# Get Data for :  AXP
# D:/Python for Finance/Wilshire_Stocks/AXP.csv  Saved
# Finished
# Get Data for :  AXR
# D:/Python for Finance/Wilshire_Stocks/AXR.csv  Saved
# Finished
# Get Data for :  AXS
# D:/Python for Finance/Wilshire_Stocks/AXS.csv  Saved
# Finished
# Get Data for :  AXSM
# D:/Python for Finance/Wilshire_Stocks/AXSM.csv  Saved
# Finished
# Get Data for :  AXTA
# D:/Python for Finance/Wilshire_Stocks/AXTA.csv  Saved
# Finished
# Get Data for :  AXTI
# D:/Python for Finance/Wilshire_Stocks/AXTI.csv  Saved
# Finished
# Get Data for :  AYI
# D:/Python for Finance/Wilshire_Stocks/AYI.csv  Saved
# Finished
# Get Data for :  AYX
# D:/Python for Finance/Wilshire_Stocks/AYX.csv  Saved
# Finished
# Get Data for :  AZO
# D:/Python for Finance/Wilshire_Stocks/AZO.csv  Saved
# Finished
# Get Data for :  AZPN
# D:/Python for Finance/Wilshire_Stocks/AZPN.csv  Saved
# Finished
# Get Data for :  AZZ
# D:/Python for Finance/Wilshire_Stocks/AZZ.csv  Saved
# Finished
# Get Data for :  B
# D:/Python for Finance/Wilshire_Stocks/B.csv  Saved
# Finished
# Get Data for :  BA
# D:/Python for Finance/Wilshire_Stocks/BA.csv  Saved
# Finished
# Get Data for :  BAC
# D:/Python for Finance/Wilshire_Stocks/BAC.csv  Saved
# Finished
# Get Data for :  BAH
# D:/Python for Finance/Wilshire_Stocks/BAH.csv  Saved
# Finished
# Get Data for :  BANC
# D:/Python for Finance/Wilshire_Stocks/BANC.csv  Saved
# Finished
# Get Data for :  BAND
# D:/Python for Finance/Wilshire_Stocks/BAND.csv  Saved
# Finished
# Get Data for :  BANF
# D:/Python for Finance/Wilshire_Stocks/BANF.csv  Saved
# Finished
# Get Data for :  BANR
# D:/Python for Finance/Wilshire_Stocks/BANR.csv  Saved
# Finished
# Get Data for :  BASI
# - BASI: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/BASI.csv  Saved
# Finished
# Get Data for :  BATRA
# D:/Python for Finance/Wilshire_Stocks/BATRA.csv  Saved
# Finished
# Get Data for :  BATRK
# D:/Python for Finance/Wilshire_Stocks/BATRK.csv  Saved
# Finished
# Get Data for :  BAX
# D:/Python for Finance/Wilshire_Stocks/BAX.csv  Saved
# Finished
# Get Data for :  BBBY
# D:/Python for Finance/Wilshire_Stocks/BBBY.csv  Saved
# Finished
# Get Data for :  BBCP
# D:/Python for Finance/Wilshire_Stocks/BBCP.csv  Saved
# Finished
# Get Data for :  BBGI
# D:/Python for Finance/Wilshire_Stocks/BBGI.csv  Saved
# Finished
# Get Data for :  BBSI
# D:/Python for Finance/Wilshire_Stocks/BBSI.csv  Saved
# Finished
# Get Data for :  BBW
# D:/Python for Finance/Wilshire_Stocks/BBW.csv  Saved
# Finished
# Get Data for :  BBY
# D:/Python for Finance/Wilshire_Stocks/BBY.csv  Saved
# Finished
# Get Data for :  BC
# D:/Python for Finance/Wilshire_Stocks/BC.csv  Saved
# Finished
# Get Data for :  BCBP
# D:/Python for Finance/Wilshire_Stocks/BCBP.csv  Saved
# Finished
# Get Data for :  BCC
# D:/Python for Finance/Wilshire_Stocks/BCC.csv  Saved
# Finished
# Get Data for :  BCEI
# - BCEI: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/BCEI.csv  Saved
# Finished
# Get Data for :  BCLI
# D:/Python for Finance/Wilshire_Stocks/BCLI.csv  Saved
# Finished
# Get Data for :  BCO
# D:/Python for Finance/Wilshire_Stocks/BCO.csv  Saved
# Finished
# Get Data for :  BCOR
# D:/Python for Finance/Wilshire_Stocks/BCOR.csv  Saved
# Finished
# Get Data for :  BCOV
# D:/Python for Finance/Wilshire_Stocks/BCOV.csv  Saved
# Finished
# Get Data for :  BCPC
# D:/Python for Finance/Wilshire_Stocks/BCPC.csv  Saved
# Finished
# Get Data for :  BCRX
# D:/Python for Finance/Wilshire_Stocks/BCRX.csv  Saved
# Finished
# Get Data for :  BDC
# D:/Python for Finance/Wilshire_Stocks/BDC.csv  Saved
# Finished
# Get Data for :  BDGE
# - BDGE: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/BDGE.csv  Saved
# Finished
# Get Data for :  BDL
# D:/Python for Finance/Wilshire_Stocks/BDL.csv  Saved
# Finished
# Get Data for :  BDN
# D:/Python for Finance/Wilshire_Stocks/BDN.csv  Saved
# Finished
# Get Data for :  BDSI
# D:/Python for Finance/Wilshire_Stocks/BDSI.csv  Saved
# Finished
# Get Data for :  BDX
# D:/Python for Finance/Wilshire_Stocks/BDX.csv  Saved
# Finished
# Get Data for :  BE
# D:/Python for Finance/Wilshire_Stocks/BE.csv  Saved
# Finished
# Get Data for :  BEAT
# D:/Python for Finance/Wilshire_Stocks/BEAT.csv  Saved
# Finished
# Get Data for :  BECN
# D:/Python for Finance/Wilshire_Stocks/BECN.csv  Saved
# Finished
# Get Data for :  BELFA
# D:/Python for Finance/Wilshire_Stocks/BELFA.csv  Saved
# Finished
# Get Data for :  BELFB
# D:/Python for Finance/Wilshire_Stocks/BELFB.csv  Saved
# Finished
# Get Data for :  BEN
# D:/Python for Finance/Wilshire_Stocks/BEN.csv  Saved
# Finished
# Get Data for :  BERY
# D:/Python for Finance/Wilshire_Stocks/BERY.csv  Saved
# Finished
# Get Data for :  BFAM
# D:/Python for Finance/Wilshire_Stocks/BFAM.csv  Saved
# Finished
# Get Data for :  BFIN
# D:/Python for Finance/Wilshire_Stocks/BFIN.csv  Saved
# Finished
# Get Data for :  BFS
# D:/Python for Finance/Wilshire_Stocks/BFS.csv  Saved
# Finished
# Get Data for :  BFST
# D:/Python for Finance/Wilshire_Stocks/BFST.csv  Saved
# Finished
# Get Data for :  BG
# D:/Python for Finance/Wilshire_Stocks/BG.csv  Saved
# Finished
# Get Data for :  BGCP
# D:/Python for Finance/Wilshire_Stocks/BGCP.csv  Saved
# Finished
# Get Data for :  BGFV
# D:/Python for Finance/Wilshire_Stocks/BGFV.csv  Saved
# Finished
# Get Data for :  BGS
# D:/Python for Finance/Wilshire_Stocks/BGS.csv  Saved
# Finished
# Get Data for :  BGSF
# D:/Python for Finance/Wilshire_Stocks/BGSF.csv  Saved
# Finished
# Get Data for :  BH
# D:/Python for Finance/Wilshire_Stocks/BH.csv  Saved
# Finished
# Get Data for :  BHB
# D:/Python for Finance/Wilshire_Stocks/BHB.csv  Saved
# Finished
# Get Data for :  BHE
# D:/Python for Finance/Wilshire_Stocks/BHE.csv  Saved
# Finished
# Get Data for :  BHF
# D:/Python for Finance/Wilshire_Stocks/BHF.csv  Saved
# Finished
# Get Data for :  BHLB
# D:/Python for Finance/Wilshire_Stocks/BHLB.csv  Saved
# Finished
# Get Data for :  BHR
# D:/Python for Finance/Wilshire_Stocks/BHR.csv  Saved
# Finished
# Get Data for :  BHVN
# D:/Python for Finance/Wilshire_Stocks/BHVN.csv  Saved
# Finished
# Get Data for :  BIG
# D:/Python for Finance/Wilshire_Stocks/BIG.csv  Saved
# Finished
# Get Data for :  BIIB
# D:/Python for Finance/Wilshire_Stocks/BIIB.csv  Saved
# Finished
# Get Data for :  BIO
# D:/Python for Finance/Wilshire_Stocks/BIO.csv  Saved
# Finished
# Get Data for :  BIOC
# D:/Python for Finance/Wilshire_Stocks/BIOC.csv  Saved
# Finished
# Get Data for :  BIOL
# D:/Python for Finance/Wilshire_Stocks/BIOL.csv  Saved
# Finished
# Get Data for :  BJ
# D:/Python for Finance/Wilshire_Stocks/BJ.csv  Saved
# Finished
# Get Data for :  BJRI
# D:/Python for Finance/Wilshire_Stocks/BJRI.csv  Saved
# Finished
# Get Data for :  BK
# D:/Python for Finance/Wilshire_Stocks/BK.csv  Saved
# Finished
# Get Data for :  BKD
# D:/Python for Finance/Wilshire_Stocks/BKD.csv  Saved
# Finished
# Get Data for :  BKE
# D:/Python for Finance/Wilshire_Stocks/BKE.csv  Saved
# Finished
# Get Data for :  BKH
# D:/Python for Finance/Wilshire_Stocks/BKH.csv  Saved
# Finished
# Get Data for :  BKI
# D:/Python for Finance/Wilshire_Stocks/BKI.csv  Saved
# Finished
# Get Data for :  BKNG
# D:/Python for Finance/Wilshire_Stocks/BKNG.csv  Saved
# Finished
# Get Data for :  BKSC
# D:/Python for Finance/Wilshire_Stocks/BKSC.csv  Saved
# Finished
# Get Data for :  BKTI
# D:/Python for Finance/Wilshire_Stocks/BKTI.csv  Saved
# Finished
# Get Data for :  BKU
# D:/Python for Finance/Wilshire_Stocks/BKU.csv  Saved
# Finished
# Get Data for :  BL
# D:/Python for Finance/Wilshire_Stocks/BL.csv  Saved
# Finished
# Get Data for :  BLBD
# D:/Python for Finance/Wilshire_Stocks/BLBD.csv  Saved
# Finished
# Get Data for :  BLCM
# D:/Python for Finance/Wilshire_Stocks/BLCM.csv  Saved
# Finished
# Get Data for :  BLD
# D:/Python for Finance/Wilshire_Stocks/BLD.csv  Saved
# Finished
# Get Data for :  BLDR
# D:/Python for Finance/Wilshire_Stocks/BLDR.csv  Saved
# Finished
# Get Data for :  BLFS
# D:/Python for Finance/Wilshire_Stocks/BLFS.csv  Saved
# Finished
# Get Data for :  BLK
# D:/Python for Finance/Wilshire_Stocks/BLK.csv  Saved
# Finished
# Get Data for :  BLKB
# D:/Python for Finance/Wilshire_Stocks/BLKB.csv  Saved
# Finished
# Get Data for :  BLL
# D:/Python for Finance/Wilshire_Stocks/BLL.csv  Saved
# Finished
# Get Data for :  BLMN
# D:/Python for Finance/Wilshire_Stocks/BLMN.csv  Saved
# Finished
# Get Data for :  BLUE
# D:/Python for Finance/Wilshire_Stocks/BLUE.csv  Saved
# Finished
# Get Data for :  BMCH
# - BMCH: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/BMCH.csv  Saved
# Finished
# Get Data for :  BMI
# D:/Python for Finance/Wilshire_Stocks/BMI.csv  Saved
# Finished
# Get Data for :  BMRC
# D:/Python for Finance/Wilshire_Stocks/BMRC.csv  Saved
# Finished
# Get Data for :  BMRN
# D:/Python for Finance/Wilshire_Stocks/BMRN.csv  Saved
# Finished
# Get Data for :  BMTC
# D:/Python for Finance/Wilshire_Stocks/BMTC.csv  Saved
# Finished
# Get Data for :  BMY
# D:/Python for Finance/Wilshire_Stocks/BMY.csv  Saved
# Finished
# Get Data for :  BNED
# D:/Python for Finance/Wilshire_Stocks/BNED.csv  Saved
# Finished
# Get Data for :  BNFT
# D:/Python for Finance/Wilshire_Stocks/BNFT.csv  Saved
# Finished
# Get Data for :  BOCH
# - BOCH: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/BOCH.csv  Saved
# Finished
# Get Data for :  BOH
# D:/Python for Finance/Wilshire_Stocks/BOH.csv  Saved
# Finished
# Get Data for :  BOKF
# D:/Python for Finance/Wilshire_Stocks/BOKF.csv  Saved
# Finished
# Get Data for :  BOMN
# D:/Python for Finance/Wilshire_Stocks/BOMN.csv  Saved
# Finished
# Get Data for :  BOOM
# D:/Python for Finance/Wilshire_Stocks/BOOM.csv  Saved
# Finished
# Get Data for :  BOOT
# D:/Python for Finance/Wilshire_Stocks/BOOT.csv  Saved
# Finished
# Get Data for :  BOTJ
# D:/Python for Finance/Wilshire_Stocks/BOTJ.csv  Saved
# Finished
# Get Data for :  BOX
# D:/Python for Finance/Wilshire_Stocks/BOX.csv  Saved
# Finished
# Get Data for :  BPFH
# - BPFH: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/BPFH.csv  Saved
# Finished
# Get Data for :  BPMC
# D:/Python for Finance/Wilshire_Stocks/BPMC.csv  Saved
# Finished
# Get Data for :  BPOP
# D:/Python for Finance/Wilshire_Stocks/BPOP.csv  Saved
# Finished
# Get Data for :  BPRN
# D:/Python for Finance/Wilshire_Stocks/BPRN.csv  Saved
# Finished
# Get Data for :  BPTH
# D:/Python for Finance/Wilshire_Stocks/BPTH.csv  Saved
# Finished
# Get Data for :  BR
# D:/Python for Finance/Wilshire_Stocks/BR.csv  Saved
# Finished
# Get Data for :  BRC
# D:/Python for Finance/Wilshire_Stocks/BRC.csv  Saved
# Finished
# Get Data for :  BREW
# - BREW: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/BREW.csv  Saved
# Finished
# Get Data for :  BRG
# D:/Python for Finance/Wilshire_Stocks/BRG.csv  Saved
# Finished
# Get Data for :  BRID
# D:/Python for Finance/Wilshire_Stocks/BRID.csv  Saved
# Finished
# Get Data for :  BRKL
# D:/Python for Finance/Wilshire_Stocks/BRKL.csv  Saved
# Finished
# Get Data for :  BRKR
# D:/Python for Finance/Wilshire_Stocks/BRKR.csv  Saved
# Finished
# Get Data for :  BRKS
# D:/Python for Finance/Wilshire_Stocks/BRKS.csv  Saved
# Finished
# Get Data for :  BRN
# D:/Python for Finance/Wilshire_Stocks/BRN.csv  Saved
# Finished
# Get Data for :  BRO
# D:/Python for Finance/Wilshire_Stocks/BRO.csv  Saved
# Finished
# Get Data for :  BRT
# D:/Python for Finance/Wilshire_Stocks/BRT.csv  Saved
# Finished
# Get Data for :  BRX
# D:/Python for Finance/Wilshire_Stocks/BRX.csv  Saved
# Finished
# Get Data for :  BRY
# D:/Python for Finance/Wilshire_Stocks/BRY.csv  Saved
# Finished
# Get Data for :  BSET
# D:/Python for Finance/Wilshire_Stocks/BSET.csv  Saved
# Finished
# Get Data for :  BSGM
# D:/Python for Finance/Wilshire_Stocks/BSGM.csv  Saved
# Finished
# Get Data for :  BSQR
# D:/Python for Finance/Wilshire_Stocks/BSQR.csv  Saved
# Finished
# Get Data for :  BSRR
# D:/Python for Finance/Wilshire_Stocks/BSRR.csv  Saved
# Finished
# Get Data for :  BSTC
# - BSTC: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/BSTC.csv  Saved
# Finished
# Get Data for :  BSX
# D:/Python for Finance/Wilshire_Stocks/BSX.csv  Saved
# Finished
# Get Data for :  BTN
# D:/Python for Finance/Wilshire_Stocks/BTN.csv  Saved
# Finished
# Get Data for :  BTU
# D:/Python for Finance/Wilshire_Stocks/BTU.csv  Saved
# Finished
# Get Data for :  BURL
# D:/Python for Finance/Wilshire_Stocks/BURL.csv  Saved
# Finished
# Get Data for :  BUSE
# D:/Python for Finance/Wilshire_Stocks/BUSE.csv  Saved
# Finished
# Get Data for :  BV
# D:/Python for Finance/Wilshire_Stocks/BV.csv  Saved
# Finished
# Get Data for :  BW
# D:/Python for Finance/Wilshire_Stocks/BW.csv  Saved
# Finished
# Get Data for :  BWA
# D:/Python for Finance/Wilshire_Stocks/BWA.csv  Saved
# Finished
# Get Data for :  BWEN
# D:/Python for Finance/Wilshire_Stocks/BWEN.csv  Saved
# Finished
# Get Data for :  BWFG
# D:/Python for Finance/Wilshire_Stocks/BWFG.csv  Saved
# Finished
# Get Data for :  BWXT
# D:/Python for Finance/Wilshire_Stocks/BWXT.csv  Saved
# Finished
# Get Data for :  BXC
# D:/Python for Finance/Wilshire_Stocks/BXC.csv  Saved
# Finished
# Get Data for :  BXMT
# D:/Python for Finance/Wilshire_Stocks/BXMT.csv  Saved
# Finished
# Get Data for :  BXP
# D:/Python for Finance/Wilshire_Stocks/BXP.csv  Saved
# Finished
# Get Data for :  BXS
# - BXS: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/BXS.csv  Saved
# Finished
# Get Data for :  BY
# D:/Python for Finance/Wilshire_Stocks/BY.csv  Saved
# Finished
# Get Data for :  BYD
# D:/Python for Finance/Wilshire_Stocks/BYD.csv  Saved
# Finished
# Get Data for :  BYFC
# D:/Python for Finance/Wilshire_Stocks/BYFC.csv  Saved
# Finished
# Get Data for :  BYND
# D:/Python for Finance/Wilshire_Stocks/BYND.csv  Saved
# Finished
# Get Data for :  BZH
# D:/Python for Finance/Wilshire_Stocks/BZH.csv  Saved
# Finished
# Get Data for :  C
# D:/Python for Finance/Wilshire_Stocks/C.csv  Saved
# Finished
# Get Data for :  CABO
# D:/Python for Finance/Wilshire_Stocks/CABO.csv  Saved
# Finished
# Get Data for :  CAC
# D:/Python for Finance/Wilshire_Stocks/CAC.csv  Saved
# Finished
# Get Data for :  CACC
# D:/Python for Finance/Wilshire_Stocks/CACC.csv  Saved
# Finished
# Get Data for :  CACI
# D:/Python for Finance/Wilshire_Stocks/CACI.csv  Saved
# Finished
# Get Data for :  CADE
# D:/Python for Finance/Wilshire_Stocks/CADE.csv  Saved
# Finished
# Get Data for :  CAG
# D:/Python for Finance/Wilshire_Stocks/CAG.csv  Saved
# Finished
# Get Data for :  CAH
# D:/Python for Finance/Wilshire_Stocks/CAH.csv  Saved
# Finished
# Get Data for :  CAI
# D:/Python for Finance/Wilshire_Stocks/CAI.csv  Saved
# Finished
# Get Data for :  CAKE
# D:/Python for Finance/Wilshire_Stocks/CAKE.csv  Saved
# Finished
# Get Data for :  CAL
# D:/Python for Finance/Wilshire_Stocks/CAL.csv  Saved
# Finished
# Get Data for :  CALA
# D:/Python for Finance/Wilshire_Stocks/CALA.csv  Saved
# Finished
# Get Data for :  CALM
# D:/Python for Finance/Wilshire_Stocks/CALM.csv  Saved
# Finished
# Get Data for :  CALX
# D:/Python for Finance/Wilshire_Stocks/CALX.csv  Saved
# Finished
# Get Data for :  CAMP
# D:/Python for Finance/Wilshire_Stocks/CAMP.csv  Saved
# Finished
# Get Data for :  CAPR
# D:/Python for Finance/Wilshire_Stocks/CAPR.csv  Saved
# Finished
# Get Data for :  CAR
# D:/Python for Finance/Wilshire_Stocks/CAR.csv  Saved
# Finished
# Get Data for :  CARA
# D:/Python for Finance/Wilshire_Stocks/CARA.csv  Saved
# Finished
# Get Data for :  CARG
# D:/Python for Finance/Wilshire_Stocks/CARG.csv  Saved
# Finished
# Get Data for :  CARS
# D:/Python for Finance/Wilshire_Stocks/CARS.csv  Saved
# Finished
# Get Data for :  CASA
# D:/Python for Finance/Wilshire_Stocks/CASA.csv  Saved
# Finished
# Get Data for :  CASH
# D:/Python for Finance/Wilshire_Stocks/CASH.csv  Saved
# Finished
# Get Data for :  CASI
# D:/Python for Finance/Wilshire_Stocks/CASI.csv  Saved
# Finished
# Get Data for :  CASS
# D:/Python for Finance/Wilshire_Stocks/CASS.csv  Saved
# Finished
# Get Data for :  CASY
# D:/Python for Finance/Wilshire_Stocks/CASY.csv  Saved
# Finished
# Get Data for :  CAT
# D:/Python for Finance/Wilshire_Stocks/CAT.csv  Saved
# Finished
# Get Data for :  CATB
# - CATB: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/CATB.csv  Saved
# Finished
# Get Data for :  CATC
# D:/Python for Finance/Wilshire_Stocks/CATC.csv  Saved
# Finished
# Get Data for :  CATM
# - CATM: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/CATM.csv  Saved
# Finished
# Get Data for :  CATO
# D:/Python for Finance/Wilshire_Stocks/CATO.csv  Saved
# Finished
# Get Data for :  CATS
# - CATS: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/CATS.csv  Saved
# Finished
# Get Data for :  CATY
# D:/Python for Finance/Wilshire_Stocks/CATY.csv  Saved
# Finished
# Get Data for :  CB
# D:/Python for Finance/Wilshire_Stocks/CB.csv  Saved
# Finished
# Get Data for :  CBAN
# D:/Python for Finance/Wilshire_Stocks/CBAN.csv  Saved
# Finished
# Get Data for :  CBAY
# D:/Python for Finance/Wilshire_Stocks/CBAY.csv  Saved
# Finished
# Get Data for :  CBB
# - CBB: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/CBB.csv  Saved
# Finished
# Get Data for :  CBFV
# D:/Python for Finance/Wilshire_Stocks/CBFV.csv  Saved
# Finished
# Get Data for :  CBIO
# D:/Python for Finance/Wilshire_Stocks/CBIO.csv  Saved
# Finished
# Get Data for :  CBLI
# - CBLI: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/CBLI.csv  Saved
# Finished
# Get Data for :  CBMG
# - CBMG: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/CBMG.csv  Saved
# Finished
# Get Data for :  CBOE
# D:/Python for Finance/Wilshire_Stocks/CBOE.csv  Saved
# Finished
# Get Data for :  CBRE
# D:/Python for Finance/Wilshire_Stocks/CBRE.csv  Saved
# Finished
# Get Data for :  CBRL
# D:/Python for Finance/Wilshire_Stocks/CBRL.csv  Saved
# Finished
# Get Data for :  CBSH
# D:/Python for Finance/Wilshire_Stocks/CBSH.csv  Saved
# Finished
# Get Data for :  CBT
# D:/Python for Finance/Wilshire_Stocks/CBT.csv  Saved
# Finished
# Get Data for :  CBTX
# D:/Python for Finance/Wilshire_Stocks/CBTX.csv  Saved
# Finished
# Get Data for :  CBU
# D:/Python for Finance/Wilshire_Stocks/CBU.csv  Saved
# Finished
# Get Data for :  CBZ
# D:/Python for Finance/Wilshire_Stocks/CBZ.csv  Saved
# Finished
# Get Data for :  CC
# D:/Python for Finance/Wilshire_Stocks/CC.csv  Saved
# Finished
# Get Data for :  CCBG
# D:/Python for Finance/Wilshire_Stocks/CCBG.csv  Saved
# Finished
# Get Data for :  CCF
# D:/Python for Finance/Wilshire_Stocks/CCF.csv  Saved
# Finished
# Get Data for :  CCI
# D:/Python for Finance/Wilshire_Stocks/CCI.csv  Saved
# Finished
# Get Data for :  CCK
# D:/Python for Finance/Wilshire_Stocks/CCK.csv  Saved
# Finished
# Get Data for :  CCL
# D:/Python for Finance/Wilshire_Stocks/CCL.csv  Saved
# Finished
# Get Data for :  CCMP
# D:/Python for Finance/Wilshire_Stocks/CCMP.csv  Saved
# Finished
# Get Data for :  CCNE
# D:/Python for Finance/Wilshire_Stocks/CCNE.csv  Saved
# Finished
# Get Data for :  CCO
# D:/Python for Finance/Wilshire_Stocks/CCO.csv  Saved
# Finished
# Get Data for :  CCOI
# D:/Python for Finance/Wilshire_Stocks/CCOI.csv  Saved
# Finished
# Get Data for :  CCRN
# D:/Python for Finance/Wilshire_Stocks/CCRN.csv  Saved
# Finished
# Get Data for :  CCS
# D:/Python for Finance/Wilshire_Stocks/CCS.csv  Saved
# Finished
# Get Data for :  CCXI
# D:/Python for Finance/Wilshire_Stocks/CCXI.csv  Saved
# Finished
# Get Data for :  CDAY
# D:/Python for Finance/Wilshire_Stocks/CDAY.csv  Saved
# Finished
# Get Data for :  CDE
# D:/Python for Finance/Wilshire_Stocks/CDE.csv  Saved
# Finished
# Get Data for :  CDEV
# D:/Python for Finance/Wilshire_Stocks/CDEV.csv  Saved
# Finished
# Get Data for :  CDK
# D:/Python for Finance/Wilshire_Stocks/CDK.csv  Saved
# Finished
# Get Data for :  CDLX
# D:/Python for Finance/Wilshire_Stocks/CDLX.csv  Saved
# Finished
# Get Data for :  CDMO
# D:/Python for Finance/Wilshire_Stocks/CDMO.csv  Saved
# Finished
# Get Data for :  CDNA
# D:/Python for Finance/Wilshire_Stocks/CDNA.csv  Saved
# Finished
# Get Data for :  CDNS
# D:/Python for Finance/Wilshire_Stocks/CDNS.csv  Saved
# Finished
# Get Data for :  CDR
# D:/Python for Finance/Wilshire_Stocks/CDR.csv  Saved
# Finished
# Get Data for :  CDTX
# D:/Python for Finance/Wilshire_Stocks/CDTX.csv  Saved
# Finished
# Get Data for :  CDW
# D:/Python for Finance/Wilshire_Stocks/CDW.csv  Saved
# Finished
# Get Data for :  CDXC
# D:/Python for Finance/Wilshire_Stocks/CDXC.csv  Saved
# Finished
# Get Data for :  CDXS
# D:/Python for Finance/Wilshire_Stocks/CDXS.csv  Saved
# Finished
# Get Data for :  CDZI
# D:/Python for Finance/Wilshire_Stocks/CDZI.csv  Saved
# Finished
# Get Data for :  CE
# D:/Python for Finance/Wilshire_Stocks/CE.csv  Saved
# Finished
# Get Data for :  CECE
# ...
# D:/Python for Finance/Wilshire_Stocks/VICL.csv  Saved
# Finished
# Get Data for :  VICI
# D:/Python for Finance/Wilshire_Stocks/VICI.csv  Saved
# Finished
# Get Data for :  VICR
# D:/Python for Finance/Wilshire_Stocks/VICR.csv  Saved
# Finished
# Get Data for :  VCTR
# D:/Python for Finance/Wilshire_Stocks/VCTR.csv  Saved
# Finished
# Get Data for :  VRAY
# D:/Python for Finance/Wilshire_Stocks/VRAY.csv  Saved
# Finished
# Get Data for :  VKTX
# D:/Python for Finance/Wilshire_Stocks/VKTX.csv  Saved
# Finished
# Get Data for :  VBFC
# D:/Python for Finance/Wilshire_Stocks/VBFC.csv  Saved
# Finished
# Get Data for :  VLGEA
# D:/Python for Finance/Wilshire_Stocks/VLGEA.csv  Saved
# Finished
# Get Data for :  VNCE
# D:/Python for Finance/Wilshire_Stocks/VNCE.csv  Saved
# Finished
# Get Data for :  VIRC
# D:/Python for Finance/Wilshire_Stocks/VIRC.csv  Saved
# Finished
# Get Data for :  VHC
# D:/Python for Finance/Wilshire_Stocks/VHC.csv  Saved
# Finished
# Get Data for :  VIRT
# D:/Python for Finance/Wilshire_Stocks/VIRT.csv  Saved
# Finished
# Get Data for :  VRTS
# D:/Python for Finance/Wilshire_Stocks/VRTS.csv  Saved
# Finished
# Get Data for :  VRTU
# - VRTU: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/VRTU.csv  Saved
# Finished
# Get Data for :  V
# D:/Python for Finance/Wilshire_Stocks/V.csv  Saved
# Finished
# Get Data for :  VSH
# D:/Python for Finance/Wilshire_Stocks/VSH.csv  Saved
# Finished
# Get Data for :  VPG
# D:/Python for Finance/Wilshire_Stocks/VPG.csv  Saved
# Finished
# Get Data for :  VISL
# D:/Python for Finance/Wilshire_Stocks/VISL.csv  Saved
# Finished
# Get Data for :  VSTO
# D:/Python for Finance/Wilshire_Stocks/VSTO.csv  Saved
# Finished
# Get Data for :  VC
# D:/Python for Finance/Wilshire_Stocks/VC.csv  Saved
# Finished
# Get Data for :  VST
# D:/Python for Finance/Wilshire_Stocks/VST.csv  Saved
# Finished
# Get Data for :  VSI
# - VSI: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/VSI.csv  Saved
# Finished
# Get Data for :  VSLR
# - VSLR: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/VSLR.csv  Saved
# Finished
# Get Data for :  VVUS
# - VVUS: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/VVUS.csv  Saved
# Finished
# Get Data for :  VMW
# D:/Python for Finance/Wilshire_Stocks/VMW.csv  Saved
# Finished
# Get Data for :  VCRA
# D:/Python for Finance/Wilshire_Stocks/VCRA.csv  Saved
# Finished
# Get Data for :  VNRX
# D:/Python for Finance/Wilshire_Stocks/VNRX.csv  Saved
# Finished
# Get Data for :  VISI
# - VISI: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/VISI.csv  Saved
# Finished
# Get Data for :  VG
# D:/Python for Finance/Wilshire_Stocks/VG.csv  Saved
# Finished
# Get Data for :  VNO
# D:/Python for Finance/Wilshire_Stocks/VNO.csv  Saved
# Finished
# Get Data for :  VOXX
# D:/Python for Finance/Wilshire_Stocks/VOXX.csv  Saved
# Finished
# Get Data for :  VOYA
# D:/Python for Finance/Wilshire_Stocks/VOYA.csv  Saved
# Finished
# Get Data for :  VYGR
# D:/Python for Finance/Wilshire_Stocks/VYGR.csv  Saved
# Finished
# Get Data for :  VSEC
# D:/Python for Finance/Wilshire_Stocks/VSEC.csv  Saved
# Finished
# Get Data for :  VTVT
# D:/Python for Finance/Wilshire_Stocks/VTVT.csv  Saved
# Finished
# Get Data for :  VMC
# D:/Python for Finance/Wilshire_Stocks/VMC.csv  Saved
# Finished
# Get Data for :  VUZI
# D:/Python for Finance/Wilshire_Stocks/VUZI.csv  Saved
# Finished
# Get Data for :  WTI
# D:/Python for Finance/Wilshire_Stocks/WTI.csv  Saved
# Finished
# Get Data for :  WPC
# D:/Python for Finance/Wilshire_Stocks/WPC.csv  Saved
# Finished
# Get Data for :  WRB
# D:/Python for Finance/Wilshire_Stocks/WRB.csv  Saved
# Finished
# Get Data for :  GRA
# - GRA: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/GRA.csv  Saved
# Finished
# Get Data for :  GWW
# D:/Python for Finance/Wilshire_Stocks/GWW.csv  Saved
# Finished
# Get Data for :  WNC
# D:/Python for Finance/Wilshire_Stocks/WNC.csv  Saved
# Finished
# Get Data for :  WBC
# - WBC: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/WBC.csv  Saved
# Finished
# Get Data for :  WDR
# - WDR: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/WDR.csv  Saved
# Finished
# Get Data for :  WTRH
# D:/Python for Finance/Wilshire_Stocks/WTRH.csv  Saved
# Finished
# Get Data for :  WBA
# D:/Python for Finance/Wilshire_Stocks/WBA.csv  Saved
# Finished
# Get Data for :  WD
# D:/Python for Finance/Wilshire_Stocks/WD.csv  Saved
# Finished
# Get Data for :  WMT
# D:/Python for Finance/Wilshire_Stocks/WMT.csv  Saved
# Finished
# Get Data for :  HCC
# D:/Python for Finance/Wilshire_Stocks/HCC.csv  Saved
# Finished
# Get Data for :  WAFD
# D:/Python for Finance/Wilshire_Stocks/WAFD.csv  Saved
# Finished
# Get Data for :  WPG
# - WPG: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/WPG.csv  Saved
# Finished
# Get Data for :  WRE
# D:/Python for Finance/Wilshire_Stocks/WRE.csv  Saved
# Finished
# Get Data for :  WASH
# D:/Python for Finance/Wilshire_Stocks/WASH.csv  Saved
# Finished
# Get Data for :  WM
# D:/Python for Finance/Wilshire_Stocks/WM.csv  Saved
# Finished
# Get Data for :  WAT
# D:/Python for Finance/Wilshire_Stocks/WAT.csv  Saved
# Finished
# Get Data for :  WSBF
# D:/Python for Finance/Wilshire_Stocks/WSBF.csv  Saved
# Finished
# Get Data for :  WSO
# D:/Python for Finance/Wilshire_Stocks/WSO.csv  Saved
# Finished
# Get Data for :  WTS
# D:/Python for Finance/Wilshire_Stocks/WTS.csv  Saved
# Finished
# Get Data for :  WVE
# D:/Python for Finance/Wilshire_Stocks/WVE.csv  Saved
# Finished
# Get Data for :  W
# D:/Python for Finance/Wilshire_Stocks/W.csv  Saved
# Finished
# Get Data for :  WSTG
# D:/Python for Finance/Wilshire_Stocks/WSTG.csv  Saved
# Finished
# Get Data for :  WDFC
# D:/Python for Finance/Wilshire_Stocks/WDFC.csv  Saved
# Finished
# Get Data for :  WBS
# D:/Python for Finance/Wilshire_Stocks/WBS.csv  Saved
# Finished
# Get Data for :  WEC
# D:/Python for Finance/Wilshire_Stocks/WEC.csv  Saved
# Finished
# Get Data for :  WRI
# - WRI: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/WRI.csv  Saved
# Finished
# Get Data for :  WMK
# D:/Python for Finance/Wilshire_Stocks/WMK.csv  Saved
# Finished
# Get Data for :  WBT
# D:/Python for Finance/Wilshire_Stocks/WBT.csv  Saved
# Finished
# Get Data for :  WCG
# - WCG: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/WCG.csv  Saved
# Finished
# Get Data for :  WEBK
# - WEBK: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/WEBK.csv  Saved
# Finished
# Get Data for :  WFC
# D:/Python for Finance/Wilshire_Stocks/WFC.csv  Saved
# Finished
# Get Data for :  WELL
# D:/Python for Finance/Wilshire_Stocks/WELL.csv  Saved
# Finished
# Get Data for :  WERN
# D:/Python for Finance/Wilshire_Stocks/WERN.csv  Saved
# Finished
# Get Data for :  WSBC
# D:/Python for Finance/Wilshire_Stocks/WSBC.csv  Saved
# Finished
# Get Data for :  WAIR
# - WAIR: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/WAIR.csv  Saved
# Finished
# Get Data for :  WCC
# D:/Python for Finance/Wilshire_Stocks/WCC.csv  Saved
# Finished
# Get Data for :  WTBA
# D:/Python for Finance/Wilshire_Stocks/WTBA.csv  Saved
# Finished
# Get Data for :  WST
# D:/Python for Finance/Wilshire_Stocks/WST.csv  Saved
# Finished
# Get Data for :  WABC
# D:/Python for Finance/Wilshire_Stocks/WABC.csv  Saved
# Finished
# Get Data for :  WSTL
# D:/Python for Finance/Wilshire_Stocks/WSTL.csv  Saved
# Finished
# Get Data for :  WAL
# D:/Python for Finance/Wilshire_Stocks/WAL.csv  Saved
# Finished
# Get Data for :  WMC
# D:/Python for Finance/Wilshire_Stocks/WMC.csv  Saved
# Finished
# Get Data for :  WDC
# D:/Python for Finance/Wilshire_Stocks/WDC.csv  Saved
# Finished
# Get Data for :  WNEB
# D:/Python for Finance/Wilshire_Stocks/WNEB.csv  Saved
# Finished
# Get Data for :  WAB
# D:/Python for Finance/Wilshire_Stocks/WAB.csv  Saved
# Finished
# Get Data for :  WLK
# D:/Python for Finance/Wilshire_Stocks/WLK.csv  Saved
# Finished
# Get Data for :  WRK
# D:/Python for Finance/Wilshire_Stocks/WRK.csv  Saved
# Finished
# Get Data for :  WWR
# D:/Python for Finance/Wilshire_Stocks/WWR.csv  Saved
# Finished
# Get Data for :  WHG
# D:/Python for Finance/Wilshire_Stocks/WHG.csv  Saved
# Finished
# Get Data for :  WEX
# D:/Python for Finance/Wilshire_Stocks/WEX.csv  Saved
# Finished
# Get Data for :  WEYS
# D:/Python for Finance/Wilshire_Stocks/WEYS.csv  Saved
# Finished
# Get Data for :  WY
# D:/Python for Finance/Wilshire_Stocks/WY.csv  Saved
# Finished
# Get Data for :  WHLR
# D:/Python for Finance/Wilshire_Stocks/WHLR.csv  Saved
# Finished
# Get Data for :  WHR
# D:/Python for Finance/Wilshire_Stocks/WHR.csv  Saved
# Finished
# Get Data for :  WTM
# D:/Python for Finance/Wilshire_Stocks/WTM.csv  Saved
# Finished
# Get Data for :  WSR
# D:/Python for Finance/Wilshire_Stocks/WSR.csv  Saved
# Finished
# Get Data for :  WLL
# D:/Python for Finance/Wilshire_Stocks/WLL.csv  Saved
# Finished
# Get Data for :  WOW
# D:/Python for Finance/Wilshire_Stocks/WOW.csv  Saved
# Finished
# Get Data for :  WYY
# D:/Python for Finance/Wilshire_Stocks/WYY.csv  Saved
# Finished
# Get Data for :  WHLM
# D:/Python for Finance/Wilshire_Stocks/WHLM.csv  Saved
# Finished
# Get Data for :  WVVI
# D:/Python for Finance/Wilshire_Stocks/WVVI.csv  Saved
# Finished
# Get Data for :  WLDN
# D:/Python for Finance/Wilshire_Stocks/WLDN.csv  Saved
# Finished
# Get Data for :  WLH
# - WLH: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/WLH.csv  Saved
# Finished
# Get Data for :  WSM
# D:/Python for Finance/Wilshire_Stocks/WSM.csv  Saved
# Finished
# Get Data for :  WLFC
# D:/Python for Finance/Wilshire_Stocks/WLFC.csv  Saved
# Finished
# Get Data for :  WLTW
# D:/Python for Finance/Wilshire_Stocks/WLTW.csv  Saved
# Finished
# Get Data for :  WSC
# D:/Python for Finance/Wilshire_Stocks/WSC.csv  Saved
# Finished
# Get Data for :  WING
# D:/Python for Finance/Wilshire_Stocks/WING.csv  Saved
# Finished
# Get Data for :  WINA
# D:/Python for Finance/Wilshire_Stocks/WINA.csv  Saved
# Finished
# Get Data for :  WGO
# D:/Python for Finance/Wilshire_Stocks/WGO.csv  Saved
# Finished
# Get Data for :  WTFC
# D:/Python for Finance/Wilshire_Stocks/WTFC.csv  Saved
# Finished
# Get Data for :  WTT
# D:/Python for Finance/Wilshire_Stocks/WTT.csv  Saved
# Finished
# Get Data for :  WETF
# D:/Python for Finance/Wilshire_Stocks/WETF.csv  Saved
# Finished
# Get Data for :  WWW
# D:/Python for Finance/Wilshire_Stocks/WWW.csv  Saved
# Finished
# Get Data for :  WWD
# D:/Python for Finance/Wilshire_Stocks/WWD.csv  Saved
# Finished
# Get Data for :  WDAY
# D:/Python for Finance/Wilshire_Stocks/WDAY.csv  Saved
# Finished
# Get Data for :  WKHS
# D:/Python for Finance/Wilshire_Stocks/WKHS.csv  Saved
# Finished
# Get Data for :  WK
# D:/Python for Finance/Wilshire_Stocks/WK.csv  Saved
# Finished
# Get Data for :  WRLD
# D:/Python for Finance/Wilshire_Stocks/WRLD.csv  Saved
# Finished
# Get Data for :  INT
# D:/Python for Finance/Wilshire_Stocks/INT.csv  Saved
# Finished
# Get Data for :  WWE
# D:/Python for Finance/Wilshire_Stocks/WWE.csv  Saved
# Finished
# Get Data for :  WOR
# D:/Python for Finance/Wilshire_Stocks/WOR.csv  Saved
# Finished
# Get Data for :  WPX
# - WPX: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/WPX.csv  Saved
# Finished
# Get Data for :  WRTC
# - WRTC: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/WRTC.csv  Saved
# Finished
# Get Data for :  WMGI
# - WMGI: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/WMGI.csv  Saved
# Finished
# Get Data for :  WSFS
# D:/Python for Finance/Wilshire_Stocks/WSFS.csv  Saved
# Finished
# Get Data for :  WVFC
# D:/Python for Finance/Wilshire_Stocks/WVFC.csv  Saved
# Finished
# Get Data for :  WW
# D:/Python for Finance/Wilshire_Stocks/WW.csv  Saved
# Finished
# Get Data for :  WYND
# - WYND: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/WYND.csv  Saved
# Finished
# Get Data for :  WH
# D:/Python for Finance/Wilshire_Stocks/WH.csv  Saved
# Finished
# Get Data for :  WYNN
# D:/Python for Finance/Wilshire_Stocks/WYNN.csv  Saved
# Finished
# Get Data for :  XFOR
# D:/Python for Finance/Wilshire_Stocks/XFOR.csv  Saved
# Finished
# Get Data for :  XBIT
# D:/Python for Finance/Wilshire_Stocks/XBIT.csv  Saved
# Finished
# Get Data for :  XELB
# D:/Python for Finance/Wilshire_Stocks/XELB.csv  Saved
# Finished
# Get Data for :  XEL
# D:/Python for Finance/Wilshire_Stocks/XEL.csv  Saved
# Finished
# Get Data for :  XNCR
# D:/Python for Finance/Wilshire_Stocks/XNCR.csv  Saved
# Finished
# Get Data for :  XHR
# D:/Python for Finance/Wilshire_Stocks/XHR.csv  Saved
# Finished
# Get Data for :  XERS
# D:/Python for Finance/Wilshire_Stocks/XERS.csv  Saved
# Finished
# Get Data for :  XRX
# D:/Python for Finance/Wilshire_Stocks/XRX.csv  Saved
# Finished
# Get Data for :  XLNX
# D:/Python for Finance/Wilshire_Stocks/XLNX.csv  Saved
# Finished
# Get Data for :  XOMA
# D:/Python for Finance/Wilshire_Stocks/XOMA.csv  Saved
# Finished
# Get Data for :  XPER
# D:/Python for Finance/Wilshire_Stocks/XPER.csv  Saved
# Finished
# Get Data for :  XPO
# D:/Python for Finance/Wilshire_Stocks/XPO.csv  Saved
# Finished
# Get Data for :  XSPA
# D:/Python for Finance/Wilshire_Stocks/XSPA.csv  Saved
# Finished
# Get Data for :  XTNT
# D:/Python for Finance/Wilshire_Stocks/XTNT.csv  Saved
# Finished
# Get Data for :  XYL
# D:/Python for Finance/Wilshire_Stocks/XYL.csv  Saved
# Finished
# Get Data for :  YELP
# D:/Python for Finance/Wilshire_Stocks/YELP.csv  Saved
# Finished
# Get Data for :  YETI
# D:/Python for Finance/Wilshire_Stocks/YETI.csv  Saved
# Finished
# Get Data for :  YEXT
# D:/Python for Finance/Wilshire_Stocks/YEXT.csv  Saved
# Finished
# Get Data for :  YTEN
# D:/Python for Finance/Wilshire_Stocks/YTEN.csv  Saved
# Finished
# Get Data for :  YMAB
# D:/Python for Finance/Wilshire_Stocks/YMAB.csv  Saved
# Finished
# Get Data for :  YORW
# D:/Python for Finance/Wilshire_Stocks/YORW.csv  Saved
# Finished
# Get Data for :  YRCW
# - YRCW: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/YRCW.csv  Saved
# Finished
# Get Data for :  YUM
# D:/Python for Finance/Wilshire_Stocks/YUM.csv  Saved
# Finished
# Get Data for :  YUMA
# - YUMA: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/YUMA.csv  Saved
# Finished
# Get Data for :  CTIB
# D:/Python for Finance/Wilshire_Stocks/CTIB.csv  Saved
# Finished
# Get Data for :  ZFGN
# - ZFGN: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/ZFGN.csv  Saved
# Finished
# Get Data for :  ZAGG
# - ZAGG: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/ZAGG.csv  Saved
# Finished
# Get Data for :  ZAYO
# - ZAYO: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/ZAYO.csv  Saved
# Finished
# Get Data for :  ZBRA
# D:/Python for Finance/Wilshire_Stocks/ZBRA.csv  Saved
# Finished
# Get Data for :  ZDGE
# D:/Python for Finance/Wilshire_Stocks/ZDGE.csv  Saved
# Finished
# Get Data for :  ZEN
# D:/Python for Finance/Wilshire_Stocks/ZEN.csv  Saved
# Finished
# Get Data for :  Z
# D:/Python for Finance/Wilshire_Stocks/Z.csv  Saved
# Finished
# Get Data for :  ZG
# D:/Python for Finance/Wilshire_Stocks/ZG.csv  Saved
# Finished
# Get Data for :  ZBH
# D:/Python for Finance/Wilshire_Stocks/ZBH.csv  Saved
# Finished
# Get Data for :  ZN
# - ZN: No data found, symbol may be delisted
# D:/Python for Finance/Wilshire_Stocks/ZN.csv  Saved
# Finished
# Get Data for :  ZION
# D:/Python for Finance/Wilshire_Stocks/ZION.csv  Saved
# Finished
# Get Data for :  ZIOP
# D:/Python for Finance/Wilshire_Stocks/ZIOP.csv  Saved
# Finished
# Get Data for :  ZIXI
# D:/Python for Finance/Wilshire_Stocks/ZIXI.csv  Saved
# Finished
# Get Data for :  ZTS
# D:/Python for Finance/Wilshire_Stocks/ZTS.csv  Saved
# Finished
# Get Data for :  ZGNX
# D:/Python for Finance/Wilshire_Stocks/ZGNX.csv  Saved
# Finished
# Get Data for :  ZM
# D:/Python for Finance/Wilshire_Stocks/ZM.csv  Saved
# Finished
# Get Data for :  ZSAN
# D:/Python for Finance/Wilshire_Stocks/ZSAN.csv  Saved
# Finished
# Get Data for :  ZVO
# D:/Python for Finance/Wilshire_Stocks/ZVO.csv  Saved
# Finished
# Get Data for :  ZS
# D:/Python for Finance/Wilshire_Stocks/ZS.csv  Saved
# Finished
# Get Data for :  ZUMZ
# D:/Python for Finance/Wilshire_Stocks/ZUMZ.csv  Saved
# Finished
# Get Data for :  ZUO
# D:/Python for Finance/Wilshire_Stocks/ZUO.csv  Saved
# Finished
# Get Data for :  ZYNE
# D:/Python for Finance/Wilshire_Stocks/ZYNE.csv  Saved
# Finished
# Get Data for :  ZYXI
# D:/Python for Finance/Wilshire_Stocks/ZYXI.csv  Saved
# Finished
# Get Data for :  ZNGA
# D:/Python for Finance/Wilshire_Stocks/ZNGA.csv  Saved
# Finished
