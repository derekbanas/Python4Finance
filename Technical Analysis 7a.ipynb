# %% [markdown]
# # Stock market technical analysis

# %% [markdown]
# ## Downloads all Stock Data from a Given Index for 5 Years

# %%
# Provides ways to work with large multidimensional arrays
import numpy as np 
# Allows for further data manipulation and analysis
import pandas as pd 
import matplotlib.pyplot as plt # Plotting
import matplotlib.dates as mdates # Styling dates
# %matplotlib inline

# pip install numpy
# conda install -c anaconda pandas
# conda install -c conda-forge matplotlib

import datetime as dt # For defining dates
from dateutil.relativedelta import relativedelta
import time

# In Powershell Prompt : conda install -c conda-forge multitasking
# pip install -i https://pypi.anaconda.org/ranaroussi/simple yfinance

import yfinance as yf

# To show all your output File -> Preferences -> Settings Search for Notebook
# Notebook Output Text Line Limit and set to 100

# Used for file handling like deleting files
import os
import shutil

# conda install -c conda-forge cufflinks-py
# conda install -c plotly plotly
import cufflinks as cf
import plotly.express as px
import plotly.graph_objects as go

import plotly.io as pio
# This ensures Plotly output works in multiple places:
# plotly_mimetype: VS Code notebook UI
# notebook: "Jupyter: Export to HTML" command in VS Code
# See https://plotly.com/python/renderers/#multiple-renderers
pio.renderers.default = "plotly_mimetype+notebook"

# Make Plotly work in your Jupyter Notebook
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Use Plotly locally
cf.go_offline()

from plotly.subplots import make_subplots

# New Imports
# Used to get data from a directory
import os
from os import listdir
from os.path import isfile, join

from IPython.display import Markdown as md
from IPython.display import display

from multiprocessing.pool import ThreadPool
from functools import partial

import warnings
warnings.simplefilter("ignore")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Constants

# %%
PATH = "../PythonFinance/Australia/"
STOCK_SECTORS = "./stock_sectors_au.csv"

# Start end date defaults
# S_DATE = (dt.datetime.today() - relativedelta(years=5)).strftime("%Y-%m-%d")
# E_DATE = dt.datetime.today().strftime("%Y-%m-%d")
# S_DATE_DT = pd.to_datetime(S_DATE)
# E_DATE_DT = pd.to_datetime(E_DATE)
THREADS = 8

# %% [markdown]
# ## Holds Stocks Not Downloaded

# %%
stocks_not_downloaded = []
missing_stocks = []

# %% [markdown]
# ## Function that Returns a Stock Dataframe from a CSV

# %%
# Reads a dataframe from the CSV file, changes index to date and returns it
def get_stock_df_from_csv(ticker):
    # Try to get the file and if it doesn't exist issue a warning
    try:
        df = pd.read_csv(PATH + ticker + '.csv', index_col=0)
    except FileNotFoundError:
        print("File Doesn't Exist")
    else:
        return df

# %% [markdown]
# ## Returns a Named Columns Data from a CSV

# %%
def get_column_from_csv(file, col_name):
    # Try to get the file and if it doesn't exist issue a warning
    try:
        df = pd.read_csv(file)
    except FileNotFoundError:
        print("File Doesn't Exist")
    else:
        return df[col_name]

# %% [markdown]
# ## Get Stock Tickers

# %%
tickers = get_column_from_csv(STOCK_SECTORS, "Symbol")
print(f"Number of stocks: {len(tickers)}")
# Out:
# Number of stocks: 2210

# %% [markdown]
# ## Function that Saves Stock Data to CSV

# %%
# Function that gets a dataframe by providing a ticker and starting date
def save_to_csv_from_yahoo(folder, ticker):
    
    stock = yf.Ticker(ticker)
    
    try:
        # print(f"Downloading: {ticker}")
        # Get historical closing price data
        df = stock.history(period="5y")
           
        if df.empty:
            stocks_not_downloaded.append(ticker)
        
        # Remove the period for saving the file name
        # Save data to a CSV file
        # File to save to 
        the_file = folder + ticker.replace(".", "_") + '.csv'
        # print(f"Saved: {the_file}")
        df.to_csv(the_file)
    except Exception as ex:
        stocks_not_downloaded.append(ticker)
        print(f"Couldn't Get Data for: {ticker}")

# %% [markdown]
# ## Delete old data

# %%
folder = PATH
for filename in os.scandir(folder):
    try:
        if os.path.isfile(filename) or os.path.islink(filename):
            os.unlink(filename)
        elif os.path.isdir(filename):
            shutil.rmtree(filename)
    except Exception as e:
        print('Failed to delete %s. Reason: %s' % (filename, e))

# %% [markdown]
# ## Get 5 Years of Data for Stocks

# %%
folder = PATH

save_csv = partial(save_to_csv_from_yahoo, folder)
with ThreadPool(THREADS) as p:
  p.map(save_csv, tickers)
print("Finished")
# Out:
# - AHY.AX: No data found, symbol may be delisted- CDH.AX: No data found, symbol may be delisted
#
# - 5GN.AX: No data found, symbol may be delisted
# - CDV.AX: No data found, symbol may be delisted
# - CDY.AX: No data found, symbol may be delisted
# - ABW.AX: No data found, symbol may be delisted
# - BCL.AX: No data found, symbol may be delisted
# - ANA.AX: No data found, symbol may be delisted
# - 8EC.AX: No data found, symbol may be delisted
# - BD1.AX: No data found, symbol may be delisted
# - CFE.AX: No data found, symbol may be delisted
# - CP1.AX: No data found, symbol may be delisted
# - BDA.AX: No data found, symbol may be delisted
# - BSM.AX: No data found, symbol may be delisted
# - BDI.AX: No data found, symbol may be delisted
# - ABL.AX: No data found, symbol may be delisted
# - ABT.AX: No data found, symbol may be delisted
# - AU8.AX: No data found, symbol may be delisted
# - CGL.AX: No data found, symbol may be delisted
# - CGM.AX: No data found, symbol may be delisted
# - AGM.AX: No data found, symbol may be delisted
# - CGR.AX: No data found, symbol may be delisted
# - BUG.AX: No data found, symbol may be delisted
# - AOP.AX: No data found, symbol may be delisted
# - AUL.AX: No data found, symbol may be delisted
# - AOW.AX: No data found, symbol may be delisted
# - CSD.AX: No data found, symbol may be delisted
# - 4CE.AX: No data found, symbol may be delisted
# - APD.AX: No data found, symbol may be delisted
# - CIE.AX: No data found, symbol may be delisted
# - BWR.AX: No data found, symbol may be delisted
# - 1AL.AX: No data found, symbol may be delisted
# - APH.AX: No data found, symbol may be delisted
# - APL.AX: No data found, symbol may be delisted
# - APT.AX: No data found, symbol may be delisted
# - AHZ.AX: No data found, symbol may be delisted
# - BIN.AX: No data found, symbol may be delisted
# - ADJ.AX: No data found, symbol may be delisted
# - CA8.AX: No data found, symbol may be delisted
# - AIY.AX: No data found, symbol may be delisted
# - AJC.AX: No data found, symbol may be delisted
# - CTX.AX: No data found, symbol may be delisted
# - AQG.AX: No data found, symbol may be delisted
# - AEB.AX: No data found, symbol may be delisted
# - AFR.AX: No data found, symbol may be delisted
# - AQR.AX: No data found, symbol may be delisted
# - AJM.AX: No data found, symbol may be delisted
# - AVQ.AX: No data found, symbol may be delisted
# - CLF.AX: No data found, symbol may be delisted
# - CUX.AX: No data found, symbol may be delisted
# - AWN.AX: No data found, symbol may be delisted
# - BLA.AX: No data found, symbol may be delisted
# - AWY.AX: No data found, symbol may be delisted
# - CLQ.AX: No data found, symbol may be delisted
# - AHL.AX: No data found, symbol may be delisted
# - CAP.AX: No data found, symbol may be delisted
# - CVF.AX: No data found, symbol may be delisted
# - BLK.AX: No data found, symbol may be delisted
# - A40.AX: No data found, symbol may be delisted
# - BLV.AX: No data found, symbol may be delisted
# - CVS.AX: No data found, symbol may be delisted
# - AXT.AX: No data found, symbol may be delisted
# - AYF.AX: No data found, symbol may be delisted
# - ALF.AX: No data found, symbol may be delisted
# - CM1.AX: No data found, symbol may be delisted
# - AYR.AX: No data found, symbol may be delisted
# - CMC.AX: No data found, symbol may be delisted
# - AYS.AX: No data found, symbol may be delisted
# - ARM.AX: No data found, symbol may be delisted
# - ARQ.AX: No data found, symbol may be delisted
# - ARS.AX: No data found, symbol may be delisted
# - CWZ.AX: No data found, symbol may be delisted- AZT.AX: No data found, symbol may be delisted
#
# - AZV.AX: No data found, symbol may be delisted
# - B2Y.AX: No data found, symbol may be delisted
# - BAF.AX: No data found, symbol may be delisted
# - BAR.AX: No data found, symbol may be delisted
# - CCL.AX: No data found, symbol may be delisted
# - ADI.AX: No data found, symbol may be delisted
# - AMB.AX: No data found, symbol may be delisted
# - CZI.AX: No data found, symbol may be delisted
# - AMG.AX: No data found, symbol may be delisted
# - EAS.AX: No data found, symbol may be delisted
# - EPD.AX: No data found, symbol may be delisted
# - FIG.AX: No data found, symbol may be delisted
# - BPL.AX: No data found, symbol may be delisted
# - IFN.AX: No data found, symbol may be delisted
# - HIP.AX: No data found, symbol may be delisted
# - GLIN.AX: No data found, symbol may be delisted
# - DAU.AX: No data found, symbol may be delisted
# - DAV.AX: No data found, symbol may be delisted
# - IGE.AX: No data found, symbol may be delisted
# - GMC.AX: No data found, symbol may be delisted
# - ERX.AX: No data found, symbol may be delisted
# - ESE.AX: No data found, symbol may be delisted
# - FNP.AX: No data found, symbol may be delisted
# - ED1.AX: No data found, symbol may be delisted
# - GMV.AX: No data found, symbol may be delisted
# - FPL.AX: No data found, symbol may be delisted
# - DFM.AX: No data found, symbol may be delisted
# - EFF.AX: No data found, symbol may be delisted
# - FRN.AX: No data found, symbol may be delisted
# - EGF.AX: No data found, symbol may be delisted
# - HOT.AX: No data found, symbol may be delisted
# - EUC.AX: No data found, symbol may be delisted
# - GOO.AX: No data found, symbol may be delisted
# - DHR.AX: No data found, symbol may be delisted
# - JCI.AX: No data found, symbol may be delisted
# - EGI.AX: No data found, symbol may be delisted
# - JDR.AX: No data found, symbol may be delisted
# - JHC.AX: No data found, symbol may be delisted
# - EGO.AX: No data found, symbol may be delisted
# - JHL.AX: No data found, symbol may be delisted
# - FTT.AX: No data found, symbol may be delisted
# - FUN.AX: No data found, symbol may be delisted
# - EHH.AX: No data found, symbol may be delisted
# - DMG.AX: No data found, symbol may be delisted
# - JJF.AX: No data found, symbol may be delisted
# - GPX.AX: No data found, symbol may be delisted
# - DMKT.AX: No data found, symbol may be delisted
# - GRB.AX: No data found, symbol may be delisted
# - EHX.AX: No data found, symbol may be delisted
# - FXL.AX: No data found, symbol may be delisted
# - EXO.AX: No data found, symbol may be delisted
# - HUO.AX: No data found, symbol may be delisted
# - ELX.AX: No data found, symbol may be delisted
# - HWH.AX: No data found, symbol may be delisted
# - HWK.AX: No data found, symbol may be delisted
# - GSW.AX: No data found, symbol may be delisted
# - FAM.AX: No data found, symbol may be delisted
# - GBM.AX: No data found, symbol may be delisted
# - GBP.AX: No data found, symbol may be delisted
# - KAS.AX: No data found, symbol may be delisted
# - DTS.AX: No data found, symbol may be delisted
# - FDM.AX: No data found, symbol may be delisted
# - GXY.AX: No data found, symbol may be delisted
# - FEI.AX: No data found, symbol may be delisted
# - FEL.AX: No data found, symbol may be delisted
# - EMUCA.AX: No data found for this date range, symbol may be delisted
# - DWS.AX: No data found, symbol may be delisted
# - IP1.AX: No data found, symbol may be delisted
# - KIS.AX: No data found, symbol may be delisted
# - ENB.AX: No data found, symbol may be delisted
# - ENE.AX: No data found, symbol may be delisted
# - GFI.AX: No data found, symbol may be delisted
# - KKL.AX: No data found, symbol may be delisted
# - FFL.AX: No data found, symbol may be delisted
# - FFR.AX: No data found, symbol may be delisted
# - ICU.AX: No data found, symbol may be delisted
# - FGO.AX: No data found, symbol may be delisted
# - EAF.AX: No data found, symbol may be delisted
# - GID.AX: No data found, symbol may be delisted
# - IDZ.AX: No data found, symbol may be delisted
# - HGM.AX: No data found, symbol may be delisted
# - KPT.AX: No data found, symbol may be delisted
# - KNH.AX: No data found, symbol may be delisted
# - NTM.AX: No data found, symbol may be delisted
# - ISD.AX: No data found, symbol may be delisted
# - KRS.AX: No data found, symbol may be delisted
# - IEQ.AX: No data found, symbol may be delisted
# - MJC.AX: No data found, symbol may be delisted
# - MLL.AX: No data found, symbol may be delisted
# - ISX.AX: No data found, symbol may be delisted
# - KPC.AX: No data found, symbol may be delisted
# - KPE.AX: No data found, symbol may be delisted
# - ITG.AX: No data found, symbol may be delisted
# - NUS.AX: No data found, symbol may be delisted
# - MLT.AX: No data found, symbol may be delisted
# - MA1.AX: No data found, symbol may be delisted- NVO.AX: No data found, symbol may be delisted
#
# - KTD.AX: No data found, symbol may be delisted
# - KTE.AX: No data found, symbol may be delisted
# - OSH.AX: No data found, symbol may be delisted
# - IVQ.AX: No data found, symbol may be delisted
# - MWR.AX: No data found, symbol may be delisted
# - MAI.AX: No data found, symbol may be delisted
# - PLX.AX: No data found, symbol may be delisted
# - PM1.AX: No data found, symbol may be delisted
# - PM8.AX: No data found, symbol may be delisted
# - OVH.AX: No data found, symbol may be delisted
# - QFY.AX: No data found, symbol may be delisted
# - LAA.AX: No data found, symbol may be delisted
# - PMY.AX: No data found, symbol may be delisted
# - MNF.AX: No data found, symbol may be delisted
# - NXE.AX: No data found, symbol may be delisted
# - MYQ.AX: No data found, symbol may be delisted
# - MBM.AX: No data found, symbol may be delisted
# - LCD.AX: No data found, symbol may be delisted
# - MNW.AX: No data found, symbol may be delisted
# - P2P.AX: No data found, symbol may be delisted
# - MCB.AX: No data found, symbol may be delisted
# - PNW.AX: No data found, symbol may be delisted
# - QPR.AX: No data found, symbol may be delisted
# - MZI.AX: No data found, symbol may be delisted
# - LCM.AX: No data found, symbol may be delisted
# - MOC.AX: No data found, symbol may be delisted
# - MOE.AX: No data found, symbol may be delisted
# - QSS.AX: No data found, symbol may be delisted
# - LEP.AX: No data found, symbol may be delisted
# - OBJ.AX: No data found, symbol may be delisted
# - MOY.AX: No data found, symbol may be delisted
# - LGR.AX: No data found, symbol may be delisted
# - LHB.AX: No data found, symbol may be delisted
# - MPH.AX: No data found, symbol may be delisted
# - LI3.AX: No data found, symbol may be delisted
# - PCH.AX: No data found, symbol may be delisted
# - MPW.AX: No data found, symbol may be delisted
# - OGA.AX: No data found, symbol may be delisted
# - PDZ.AX: No data found, symbol may be delisted
# - MEQ.AX: No data found for this date range, symbol may be delisted
# - OGX.AX: No data found, symbol may be delisted
# - LNG.AX: No data found, symbol may be delisted
# - MEY.AX: No data found, symbol may be delisted
# - MRV.AX: No data found, symbol may be delisted
# - LON.AX: No data found, symbol may be delisted
# - PRZ.AX: No data found, symbol may be delisted
# - MSE.AX: No data found, symbol may be delisted
# - MGC.AX: No data found, symbol may be delisted
# - MGE.AX: No data found, symbol may be delisted- OLV.AX: No data found, symbol may be delisted
#
# - MGG.AX: No data found, symbol may be delisted
# - LPDRC.AX: No data found, symbol may be delisted
# - RDC.AX: No data found, symbol may be delisted
# - MSM.AX: No data found, symbol may be delisted
# - RDF.AX: No data found, symbol may be delisted
# - MSR.AX: No data found, symbol may be delisted
# - PSZ.AX: No data found, symbol may be delisted
# - ONT.AX: No data found, symbol may be delisted
# - RDH.AX: No data found, symbol may be delisted
# - ONX.AX: No data found, symbol may be delisted
# - LRM.AX: No data found, symbol may be delisted
# - OPC.AX: No data found, symbol may be delisted
# - MGZ.AX: No data found, symbol may be delisted
# - MTL.AX: No data found, symbol may be delisted
# - PGI.AX: No data found, symbol may be delisted
# - NIU.AX: No data found, symbol may be delisted
# - LSH.AX: No data found, symbol may be delisted
# - RE1.AX: No data found, symbol may be delisted
# - PGR.AX: No data found, symbol may be delisted
# - PGX.AX: No data found, symbol may be delisted
# - MHH.AX: No data found, symbol may be delisted
# - SBI.AX: No data found, symbol may be delisted
# - NNT.AX: No data found, symbol may be delisted
# - ORE.AX: No data found, symbol may be delisted
# - REF.AX: No data found, symbol may be delisted
# - SBU.AX: No data found, symbol may be delisted
# - SL1.AX: No data found, symbol may be delisted
# - PWG.AX: No data found, symbol may be delisted
# - PIN.AX: No data found, symbol may be delisted
# - PIO.AX: No data found, symbol may be delisted
# - SCI.AX: No data found, symbol may be delisted
# - RENT.AX: No data found, symbol may be delisted
# - SLK.AX: No data found, symbol may be delisted
# - PWNCA.AX: No data found, symbol may be delisted
# - RHP.AX: No data found, symbol may be delisted
# - REV.AX: No data found, symbol may be delisted
# - PKS.AX: No data found, symbol may be delisted
# - SMC.AX: No data found, symbol may be delisted- SXA.AX: No data found, symbol may be delisted
#
# - SDA.AX: No data found, symbol may be delisted
# - SXX.AX: No data found, symbol may be delisted
# - RFN.AX: No data found, symbol may be delisted
# - TNK.AX: No data found, symbol may be delisted
# - VAH.AX: No data found, symbol may be delisted
# - SDX.AX: No data found, symbol may be delisted
# - RLE.AX: No data found, symbol may be delisted
# - VTH.AX: No data found, symbol may be delisted
# - XCD.AX: No data found, symbol may be delisted
# - SEI.AX: No data found, symbol may be delisted
# - TOM.AX: No data found, symbol may be delisted
# - XPD.AX: No data found, symbol may be delisted
# - XPE.AX: No data found, symbol may be delisted
# - XPL.AX: No data found, symbol may be delisted
# - RMG.AX: No data found, symbol may be delisted
# - VVR.AX: No data found, symbol may be delisted
# - VXR.AX: No data found, symbol may be delisted
# - TAO.AX: No data found, symbol may be delisted
# - RMP.AX: No data found, symbol may be delisted
# - XTD.AX: No data found, symbol may be delisted
# - TAP.AX: No data found, symbol may be delisted
# - SF1.AX: No data found, symbol may be delisted
# - TPM.AX: No data found, symbol may be delisted
# - TBL.AX: No data found, symbol may be delisted
# - TPS.AX: No data found, symbol may be delisted
# - TCN.AX: No data found, symbol may be delisted
# - TRL.AX: No data found, symbol may be delisted
# - VEC.AX: No data found, symbol may be delisted
# - TDI.AX: No data found, symbol may be delisted
# - TDL.AX: No data found, symbol may be delisted
# - RNY.AX: No data found, symbol may be delisted
# - TDY.AX: No data found, symbol may be delisted
# - Z3RO.AX: No data found, symbol may be delisted
# - ZEN.AX: No data found, symbol may be delisted
# - SGO.AX: No data found, symbol may be delisted
# - ZIP.AX: No data found, symbol may be delisted
# - TTL.AX: No data found, symbol may be delisted
# - TGG.AX: No data found, symbol may be delisted
# - ZMICA.AX: No data found, symbol may be delisted
# - TV2.AX: No data found, symbol may be delisted
# - TGO.AX: No data found, symbol may be delisted
# - SHK.AX: No data found, symbol may be delisted
# - THC.AX: No data found, symbol may be delisted
# - THD.AX: No data found, symbol may be delisted
# - ZYB.AX: No data found, symbol may be delisted
# - WHA.AX: No data found, symbol may be delisted
# - WHFPA.AX: No data found, symbol may be delisted
# - VIC.AX: No data found, symbol may be delisted
# - TIN.AX: No data found, symbol may be delisted
# - WJA.AX: No data found, symbol may be delisted
# - SIL.AX: No data found, symbol may be delisted
# - VII.AX: No data found, symbol may be delisted
# - RXP.AX: No data found, symbol may be delisted
# - WLC.AX: No data found, symbol may be delisted
# - STC.AX: No data found, symbol may be delisted
# - VIV.AX: No data found, symbol may be delisted
# - WLF.AX: No data found, symbol may be delisted
# - TLT.AX: No data found, symbol may be delisted
# - SAM.AX: No data found, symbol may be delisted- VLT.AX: No data found, symbol may be delisted
#
# - WND.AX: No data found, symbol may be delisted
# - UCW.AX: No data found, symbol may be delisted
# - SAR.AX: No data found, symbol may be delisted
# - SAS.AX: No data found, symbol may be delisted
# - SUD.AX: No data found, symbol may be delisted
# - UNL.AX: No data found, symbol may be delisted
# - SKI.AX: No data found, symbol may be delisted
# - SAVE.AX: No data found, symbol may be delisted
# - UNV.AX: No data found, symbol may be delisted
# - SUP.AX: No data found, symbol may be delisted
# - SVA.AX: No data found, symbol may be delisted
# - VMX.AX: No data found, symbol may be delisted
# - WPP.AX: No data found, symbol may be delisted
# - SVD.AX: No data found, symbol may be delisted
# - SVH.AX: No data found, symbol may be delisted
# - VOC.AX: No data found, symbol may be delisted
# - UTR.AX: No data found, symbol may be delisted
# - VP7.AX: No data found, symbol may be delisted
# - VPC.AX: No data found, symbol may be delisted
# - VRL.AX: No data found, symbol may be delisted
# Finished

# %% [markdown]
# ## Delete Empty Files

# %%
try:
  for x in missing_stocks:
    os.remove(PATH + x + ".csv")
except FileNotFoundError:
  print("Couldn't Find " + x)
print("Finished")
# Out:
# Finished

# %% [markdown]
# ## Daily Returns

# %% [markdown]
# For single stocks to find the daily return we subtract opening price from the closing price. Then you could multiply by the number of shares owned.
#
# We calculate a percentage rate of return for each day to compare investments.
# Simple Rate of Return = (End Price - Beginning Price) / Beginning Price OR (EP / BP) - 1

# %%
# Shift provides the value from the previous day
# NaN is displayed because there was no previous day price for the 1st calculation
def add_daily_return_to_df(df, ticker):
    df['daily_return'] = (df['Close'] / df['Close'].shift(1)) - 1
    # Save data to a CSV file
    df.to_csv(PATH + ticker + '.csv')
    return df

# %% [markdown]
# ## Get Cumulative Return

# %%
def add_cum_return_to_df(df, ticker):
    df['cum_return'] = (1 + df['daily_return']).cumprod()
    df.to_csv(PATH + ticker + '.csv')
    return df

# %% [markdown]
# ## Get Stock File Names in a List

# %%
files = [x for x in listdir(PATH) if isfile(join(PATH, x))]
tickers = [os.path.splitext(x)[0] for x in files]
tickers
try:
    tickers.remove('.ds_Store')
except Exception as e:
    pass
tickers.sort()

# %% [markdown]
# ## Add Daily & Cumulative Return to All Stock Data

# %%
for x in tickers:
    try:
        # print("Working on :", x)
        new_df = get_stock_df_from_csv(x)
        new_df = add_daily_return_to_df(new_df, x)
        new_df = add_cum_return_to_df(new_df, x)
        new_df.to_csv(PATH + x + '.csv')
    except Exception as ex:
        print(ex)

# %% [markdown]
# ## 11 Stock Market Sectors

# %% [markdown]
# We want to invest in stocks that are not correlated with other stocks. This means we want stocks that tend to go down when the others go up. Because all our stocks are expected to do well over the course of the year, this smoothes out the performance of our portfolio.
#
# One way to easily find stocks that are not correlated is to create portfolios using stocks from different sectors of the market.
#
# **Technology** : Manufacturing of electronics, software, or related to information technology
#
# **Health Care** : Biotech, hospitals, medical devices, drugs
#
# **Financials** : Banks, investment funds, and insurance
#
# **Real Estate** : Residential, industrial, and retail real estate
#
# **Energy** : Production and supply of energy
#
# **Materials** : Mining, refining, chemical, and forestry
#
# **Consumer Discretionary** : Retailers, apparel, media, durables and services
#
# **Industrials** : Construction, machinery, fabrication, manufacturing, defense, and aerospace
#
# **Utilities** : Direct providers of electric, gas, and water
#
# **Consumer Staples** : Food, beverage as well as products consumers deem essential
#
# **Telecommunication** : Cable, internet providers, wireless, and satellite

# %% [markdown]
# ## Get Sector Stocks

# %%
sec_df = pd.read_csv(STOCK_SECTORS)

indus_df = sec_df.loc[sec_df['Sector'] == "Industrials"]
health_df = sec_df.loc[sec_df['Sector'] == "Health Care"]
it_df = sec_df.loc[sec_df['Sector'] == "Information Technology"]
comm_df = sec_df.loc[sec_df['Sector'] == "Communication Services"]
staple_df = sec_df.loc[sec_df['Sector'] == "Consumer Staples"]
discretion_df = sec_df.loc[sec_df['Sector'] == "Consumer Discretionary"]
utility_df = sec_df.loc[sec_df['Sector'] == "Utilities"]
financial_df = sec_df.loc[sec_df['Sector'] == "Financials"]
material_df = sec_df.loc[sec_df['Sector'] == "Materials"]
restate_df = sec_df.loc[sec_df['Sector'] == "Real Estate"]
energy_df = sec_df.loc[sec_df['Sector'] == "Energy"]

# %% [markdown]
# ## Returns a DF with Cumulative Return for all Stocks

# %%
def get_cum_ret_for_stocks(stock_df):
    tickers = []
    cum_rets = []

    for index, row in stock_df.iterrows():
        df = get_stock_df_from_csv(row['Symbol'].replace(".", "_"))
        if df is None:
            pass
        elif len(df.index) == 0:
            pass
        else:
            tickers.append(row['Symbol'].replace(".", "_"))
            cum = df['cum_return'].iloc[-1]
            cum_rets.append(cum)
    return pd.DataFrame({'Ticker':tickers, 'CUM_RET':cum_rets})

# %%
industrial = get_cum_ret_for_stocks(indus_df)
health_care = get_cum_ret_for_stocks(health_df)
it = get_cum_ret_for_stocks(it_df)
commun = get_cum_ret_for_stocks(comm_df)
staple = get_cum_ret_for_stocks(staple_df)
discretion = get_cum_ret_for_stocks(discretion_df)
utility = get_cum_ret_for_stocks(utility_df)
finance = get_cum_ret_for_stocks(financial_df)
material = get_cum_ret_for_stocks(material_df)
restate = get_cum_ret_for_stocks(restate_df)
energy = get_cum_ret_for_stocks(energy_df)

# %% [markdown]
# # Ichimoku Kinko Hyo

# %% [markdown]
# The Ichimoku (One Look) is considered an all in one indicator. It provides information on momentum, support and resistance. It is made up of 5 lines. If you are a short term trader you create 1 minute or 6 hour. Long term traders focus on day or weekly data.
#
#  - Conversion Line (Tenkan-sen) : Represents support, resistance and reversals. Used to measure short term trends.
#  - Baseline (Kijun-sen) : Represents support, resistance and confirms trend changes. Allows you to evaluate the strength of medium term trends. Called the baseline because it lags the price.
#  - Leading Span A (Senkou A) : Used to identify future areas of support and resistance
#  - Leading Span B (Senkou B) : Other line used to identify suture support and resistance
#  - Lagging Span (Chikou) : Shows possible support and resistance. It is used to confirm signals obtained from other lines.
#  - Cloud (Kumo) : Space between Span A and B. Represents the divergence in price evolution.
#
# Formulas
#
#  - Lagging Span = Price shifted back 26 periods
#  - Base Line = (Highest Value in period + Lowest value in period)/2 (26 Sessions)
#  - Conversion Line = (Highest Value in period + Lowest value in period)/2 (9 Sessions)
#  - Leading Span A = (Conversion Value + Base Value)/2 (26 Sessions)
#  - Leading Span B = (Conversion Value + Base Value)/2 (52 Sessions)

# %% [markdown]
# ## Get Ichimoku Function

# %%
def get_fill_color(label):
    if label >= 1:
        return 'rgba(0,250,0,0.4)'
    else:
        return 'rgba(250,0,0,0.4)'

# %%
def get_Ichimoku(tickers):
    dataframe = yf.download(tickers=tickers, period='3mo', interval='1h', group_by="ticker", threads=THREADS)
    for ticker in tickers:
        df = dataframe[ticker].copy()
        display(md(f"#### {ticker}"))
        # Conversion
        hi_val = df['High'].rolling(window=9).max()
        low_val = df['Low'].rolling(window=9).min()
        df['Conversion'] = (hi_val + low_val) / 2

        # Baseline
        hi_val2 = df['High'].rolling(window=26).max()
        low_val2 = df['Low'].rolling(window=26).min()
        df['Baseline'] = (hi_val2 + low_val2) / 2

        # Spans
        df['SpanA'] = ((df['Conversion'] + df['Baseline']) / 2).shift(26)
        hi_val3 = df['High'].rolling(window=52).max()
        low_val3 = df['Low'].rolling(window=52).min()
        df['SpanB'] = ((hi_val3 + low_val3) / 2).shift(26)
        df['Lagging'] = df['Close'].shift(-26)

        candle = go.Candlestick(x=df.index, open=df['Open'],
        high=df['High'], low=df["Low"], close=df['Close'], name="Candlestick")

        df1 = df.copy()
        fig = go.Figure()
        df['label'] = np.where(df['SpanA'] > df['SpanB'], 1, 0)
        df['group'] = df['label'].ne(df['label'].shift()).cumsum()

        df = df.groupby('group')

        dfs = []
        for name, data in df:
            dfs.append(data)

        for df in dfs:
            fig.add_traces(go.Scatter(x=df.index, y=df.SpanA,
            line=dict(color='rgba(0,0,0,0)')))

            fig.add_traces(go.Scatter(x=df.index, y=df.SpanB,
            line=dict(color='rgba(0,0,0,0)'),
            fill='tonexty',
            fillcolor=get_fill_color(df['label'].iloc[0])))

        baseline = go.Scatter(x=df1.index, y=df1['Baseline'], 
        line=dict(color='pink', width=2), name="Baseline")

        conversion = go.Scatter(x=df1.index, y=df1['Conversion'], 
        line=dict(color='black', width=1), name="Conversion")

        lagging = go.Scatter(x=df1.index, y=df1['Lagging'], 
        line=dict(color='purple', width=2), name="Lagging")

        span_a = go.Scatter(x=df1.index, y=df1['SpanA'], 
        line=dict(color='green', width=2, dash='dot'), name="Span A")

        span_b = go.Scatter(x=df1.index, y=df1['SpanB'], 
        line=dict(color='red', width=1, dash='dot'), name="Span B")

        fig.add_trace(candle)
        fig.add_trace(baseline)
        fig.add_trace(conversion)
        fig.add_trace(lagging)
        fig.add_trace(span_a)
        fig.add_trace(span_b)
        
        fig.update_layout(height=600, width=1200, showlegend=True)

        fig.show()

# %% [markdown]
# ## What the Lines Mean

# %% [markdown]
#  - Lagging Span : When above the price it is bullish and when below bearish. It is used with other indicators because it is mainly a filter.
#  - Baseline : When below price this is considered support. When above price this is considered resistance. We are in an uptrend when the slope increases and vice versa. The slope of the curve tells us the strength of the trend.
#  - Conversion : We focus on its position versus the Baseline. When the Conversion crosses above the Baseline we are in an upward trend and vice versa. This is considered a strong indicator when above the Cloud and weak when below.
#  - Cloud : The thicker the Cloud, the stronger the trend and vice versa. When the Spans cross many times we are in a range. When they cross this is a sign of a reversal of trend.

# %%
def plot_Ichimoku(header, df, len):
    display(md(f"### Top {len} {header}"))
    top = [x.replace("_", ".") for x in df.head(len)["Ticker"].to_list()]
    get_Ichimoku(top)

# %% [markdown]
# ## Analyze Best Performers with Ichimoku

# %%
# plot_Ichimoku("Industrial", industrial.sort_values(by=['CUM_RET'], ascending=False), 10)

# %%
# plot_Ichimoku("Communications", commun.sort_values(by=['CUM_RET'], ascending=False), 10)

# %%
# plot_Ichimoku("Staple", staple.sort_values(by=['CUM_RET'], ascending=False), 10)

# %%
# plot_Ichimoku("Discretionary spending", discretion.sort_values(by=['CUM_RET'], ascending=False), 10)

# %%
# plot_Ichimoku("Utilities", utility.sort_values(by=['CUM_RET'], ascending=False), 10)

# %%
plot_Ichimoku("Finance", finance.sort_values(by=['CUM_RET'], ascending=False), 5)
# Out:
# ### Top 5 Finance
# [*********************100%***********************]  5 of 5 completed
# #### AEF.AX
# <div>                            <div id="b6c3ee41-258b-4463-8292-5f9e4b27ecfc" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b6c3ee41-258b-4463-8292-5f9e4b27ecfc")) {                    Plotly.newPlot(                        "b6c3ee41-258b-4463-8292-5f9e4b27ecfc",                        [{"line":{"color":"rgba(0,0,0,0)"},"type":"scatter","x":["2022-01-04T10:00:00+11:00","2022-01-04T11:00:00+11:00","2022-01-04T12:00:00+11:00","2022-01-04T13:00:00+11:00","2022-01-04T14:00:00+11:00","2022-01-04T15:00:00+11:00","2022-01-04T16:00:00+11:00","2022-01-05T10:00:00+11:00","2022-01-05T11:00:00+11:00","2022-01-05T12:00:00+11:00","2022-01-05T13:00:00+11:00","2022-01-05T14:00:00+11:00","2022-01-05T15:00:00+11:00","2022-01-05T16:00:00+11:00","2022-01-06T10:00:00+11:00","2022-01-06T11:00:00+11:00","2022-01-06T12:00:00+11:00","2022-01-06T13:00:00+11:00","2022-01-06T14:00:00+11:00","2022-01-06T15:00:00+11:00","2022-01-06T16:00:00+11:00","2022-01-07T10:00:00+11:00","2022-01-07T11:00:00+11:00","2022-01-07T12:00:00+11:00","2022-01-07T13:00:00+11:00","2022-01-07T14:00:00+11:00","2022-01-07T15:00:00+11:00","2022-01-07T16:00:00+11:00","2022-01-10T10:00:00+11:00","2022-01-10T11:00:00+11:00","2022-01-10T12:00:00+11:00","2022-01-10T13:00:00+11:00","2022-01-10T14:00:00+11:00","2022-01-10T15:00:00+11:00","2022-01-10T16:00:00+11:00","2022-01-11T10:00:00+11:00","2022-01-11T11:00:00+11:00","2022-01-11T12:00:00+11:00","2022-01-11T13:00:00+11:00","2022-01-11T14:00:00+11:00","2022-01-11T15:00:00+11:00","2022-01-11T16:00:00+11:00","2022-01-17T10:00:00+11:00","2022-01-17T11:00:00+11:00","2022-01-17T12:00:00+11:00","2022-01-17T13:00:00+11:00","2022-01-17T14:00:00+11:00","2022-01-17T15:00:00+11:00","2022-01-17T16:00:00+11:00","2022-01-18T10:00:00+11:00","2022-01-18T11:00:00+11:00","2022-01-18T12:00:00+11:00","2022-01-18T13:00:00+11:00","2022-01-18T14:00:00+11:00","2022-01-18T15:00:00+11:00","2022-01-18T16:00:00+11:00","2022-01-19T10:00:00+11:00","2022-01-19T11:00:00+11:00","2022-01-19T12:00:00+11:00","2022-01-19T13:00:00+11:00","2022-01-19T14:00:00+11:00","2022-01-19T15:00:00+11:00","2022-01-19T16:00:00+11:00","2022-01-20T10:00:00+11:00","2022-01-20T11:00:00+11:00","2022-01-20T12:00:00+11:00","2022-01-20T13:00:00+11:00","2022-01-20T14:00:00+11:00","2022-01-20T15:00:00+11:00","2022-01-20T16:00:00+11:00","2022-01-21T10:00:00+11:00","2022-01-21T11:00:00+11:00","2022-01-21T12:00:00+11:00","2022-01-21T13:00:00+11:00","2022-01-21T14:00:00+11:00","2022-01-21T15:00:00+11:00","2022-01-21T16:00:00+11:00","2022-01-25T15:00:00+11:00","2022-01-25T16:00:00+11:00","2022-01-27T10:00:00+11:00","2022-01-27T11:00:00+11:00","2022-01-27T12:00:00+11:00","2022-01-27T13:00:00+11:00","2022-01-27T14:00:00+11:00","2022-01-27T15:00:00+11:00","2022-01-27T16:00:00+11:00","2022-01-28T10:00:00+11:00","2022-01-28T11:00:00+11:00","2022-01-28T12:00:00+11:00","2022-01-28T13:00:00+11:00","2022-01-28T14:00:00+11:00","2022-01-28T15:00:00+11:00","2022-01-31T10:00:00+11:00","2022-01-31T11:00:00+11:00","2022-01-31T12:00:00+11:00","2022-01-31T13:00:00+11:00","2022-01-31T14:00:00+11:00","2022-01-31T15:00:00+11:00","2022-01-31T16:00:00+11:00","2022-02-01T10:00:00+11:00","2022-02-01T11:00:00+11:00","2022-02-01T12:00:00+11:00","2022-02-01T13:00:00+11:00","2022-02-01T14:00:00+11:00","2022-02-01T15:00:00+11:00","2022-02-01T16:00:00+11:00","2022-02-02T10:00:00+11:00","2022-02-02T11:00:00+11:00","2022-02-02T12:00:00+11:00","2022-02-02T13:00:00+11:00","2022-02-02T14:00:00+11:00","2022-02-02T15:00:00+11:00","2022-02-02T16:00:00+11:00","2022-02-03T10:00:00+11:00","2022-02-03T11:00:00+11:00","2022-02-03T12:00:00+11:00","2022-02-03T13:00:00+11:00","2022-02-03T14:00:00+11:00","2022-02-03T15:00:00+11:00","2022-02-03T16:00:00+11:00","2022-02-08T12:00:00+11:00","2022-02-08T13:00:00+11 ...
# #### HUB.AX
# <div>                            <div id="9902a29f-08da-414d-b6e5-3122f0ad9635" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9902a29f-08da-414d-b6e5-3122f0ad9635")) {                    Plotly.newPlot(                        "9902a29f-08da-414d-b6e5-3122f0ad9635",                        [{"line":{"color":"rgba(0,0,0,0)"},"type":"scatter","x":["2022-01-04T10:00:00+11:00","2022-01-04T11:00:00+11:00","2022-01-04T12:00:00+11:00","2022-01-04T13:00:00+11:00","2022-01-04T14:00:00+11:00","2022-01-04T15:00:00+11:00","2022-01-04T16:00:00+11:00","2022-01-05T10:00:00+11:00","2022-01-05T11:00:00+11:00","2022-01-05T12:00:00+11:00","2022-01-05T13:00:00+11:00","2022-01-05T14:00:00+11:00","2022-01-05T15:00:00+11:00","2022-01-05T16:00:00+11:00","2022-01-06T10:00:00+11:00","2022-01-06T11:00:00+11:00","2022-01-06T12:00:00+11:00","2022-01-06T13:00:00+11:00","2022-01-06T14:00:00+11:00","2022-01-06T15:00:00+11:00","2022-01-06T16:00:00+11:00","2022-01-07T10:00:00+11:00","2022-01-07T11:00:00+11:00","2022-01-07T12:00:00+11:00","2022-01-07T13:00:00+11:00","2022-01-07T14:00:00+11:00","2022-01-07T15:00:00+11:00","2022-01-07T16:00:00+11:00","2022-01-10T10:00:00+11:00","2022-01-10T11:00:00+11:00","2022-01-10T12:00:00+11:00","2022-01-10T13:00:00+11:00","2022-01-10T14:00:00+11:00","2022-01-10T15:00:00+11:00","2022-01-10T16:00:00+11:00","2022-01-11T10:00:00+11:00","2022-01-11T11:00:00+11:00","2022-01-11T12:00:00+11:00","2022-01-11T13:00:00+11:00","2022-01-11T14:00:00+11:00","2022-01-11T15:00:00+11:00","2022-01-11T16:00:00+11:00","2022-01-17T10:00:00+11:00","2022-01-17T11:00:00+11:00","2022-01-17T12:00:00+11:00","2022-01-17T13:00:00+11:00","2022-01-17T14:00:00+11:00","2022-01-17T15:00:00+11:00","2022-01-17T16:00:00+11:00","2022-01-18T10:00:00+11:00","2022-01-18T11:00:00+11:00","2022-01-18T12:00:00+11:00","2022-01-18T13:00:00+11:00","2022-01-18T14:00:00+11:00","2022-01-18T15:00:00+11:00","2022-01-18T16:00:00+11:00","2022-01-19T10:00:00+11:00","2022-01-19T11:00:00+11:00","2022-01-19T12:00:00+11:00","2022-01-19T13:00:00+11:00","2022-01-19T14:00:00+11:00","2022-01-19T15:00:00+11:00","2022-01-19T16:00:00+11:00","2022-01-20T10:00:00+11:00","2022-01-20T11:00:00+11:00","2022-01-20T12:00:00+11:00","2022-01-20T13:00:00+11:00","2022-01-20T14:00:00+11:00","2022-01-20T15:00:00+11:00","2022-01-20T16:00:00+11:00","2022-01-21T10:00:00+11:00","2022-01-21T11:00:00+11:00","2022-01-21T12:00:00+11:00","2022-01-21T13:00:00+11:00","2022-01-21T14:00:00+11:00","2022-01-21T15:00:00+11:00","2022-01-21T16:00:00+11:00","2022-01-25T15:00:00+11:00","2022-01-25T16:00:00+11:00","2022-01-27T10:00:00+11:00","2022-01-27T11:00:00+11:00","2022-01-27T12:00:00+11:00","2022-01-27T13:00:00+11:00","2022-01-27T14:00:00+11:00","2022-01-27T15:00:00+11:00","2022-01-27T16:00:00+11:00","2022-01-28T10:00:00+11:00","2022-01-28T11:00:00+11:00","2022-01-28T12:00:00+11:00","2022-01-28T13:00:00+11:00","2022-01-28T14:00:00+11:00","2022-01-28T15:00:00+11:00","2022-01-31T10:00:00+11:00","2022-01-31T11:00:00+11:00","2022-01-31T12:00:00+11:00","2022-01-31T13:00:00+11:00","2022-01-31T14:00:00+11:00","2022-01-31T15:00:00+11:00","2022-01-31T16:00:00+11:00","2022-02-01T10:00:00+11:00","2022-02-01T11:00:00+11:00","2022-02-01T12:00:00+11:00","2022-02-01T13:00:00+11:00","2022-02-01T14:00:00+11:00","2022-02-01T15:00:00+11:00","2022-02-01T16:00:00+11:00","2022-02-02T10:00:00+11:00","2022-02-02T11:00:00+11:00","2022-02-02T12:00:00+11:00","2022-02-02T13:00:00+11:00","2022-02-02T14:00:00+11:00","2022-02-02T15:00:00+11:00","2022-02-02T16:00:00+11:00","2022-02-03T10:00:00+11:00","2022-02-03T11:00:00+11:00","2022-02-03T12:00:00+11:00","2022-02-03T13:00:00+11:00","2022-02-03T14:00:00+11:00","2022-02-03T15:00:00+11:00","2022-02-03T16:00:00+11:00","2022-02-08T12:00:00+11:00","2022-02-08T13:00:00+11 ...
# #### PNI.AX
# <div>                            <div id="aaeb629c-1b61-4110-b30a-3040e5e9c65f" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aaeb629c-1b61-4110-b30a-3040e5e9c65f")) {                    Plotly.newPlot(                        "aaeb629c-1b61-4110-b30a-3040e5e9c65f",                        [{"line":{"color":"rgba(0,0,0,0)"},"type":"scatter","x":["2022-01-04T10:00:00+11:00","2022-01-04T11:00:00+11:00","2022-01-04T12:00:00+11:00","2022-01-04T13:00:00+11:00","2022-01-04T14:00:00+11:00","2022-01-04T15:00:00+11:00","2022-01-04T16:00:00+11:00","2022-01-05T10:00:00+11:00","2022-01-05T11:00:00+11:00","2022-01-05T12:00:00+11:00","2022-01-05T13:00:00+11:00","2022-01-05T14:00:00+11:00","2022-01-05T15:00:00+11:00","2022-01-05T16:00:00+11:00","2022-01-06T10:00:00+11:00","2022-01-06T11:00:00+11:00","2022-01-06T12:00:00+11:00","2022-01-06T13:00:00+11:00","2022-01-06T14:00:00+11:00","2022-01-06T15:00:00+11:00","2022-01-06T16:00:00+11:00","2022-01-07T10:00:00+11:00","2022-01-07T11:00:00+11:00","2022-01-07T12:00:00+11:00","2022-01-07T13:00:00+11:00","2022-01-07T14:00:00+11:00","2022-01-07T15:00:00+11:00","2022-01-07T16:00:00+11:00","2022-01-10T10:00:00+11:00","2022-01-10T11:00:00+11:00","2022-01-10T12:00:00+11:00","2022-01-10T13:00:00+11:00","2022-01-10T14:00:00+11:00","2022-01-10T15:00:00+11:00","2022-01-10T16:00:00+11:00","2022-01-11T10:00:00+11:00","2022-01-11T11:00:00+11:00","2022-01-11T12:00:00+11:00","2022-01-11T13:00:00+11:00","2022-01-11T14:00:00+11:00","2022-01-11T15:00:00+11:00","2022-01-11T16:00:00+11:00","2022-01-17T10:00:00+11:00","2022-01-17T11:00:00+11:00","2022-01-17T12:00:00+11:00","2022-01-17T13:00:00+11:00","2022-01-17T14:00:00+11:00","2022-01-17T15:00:00+11:00","2022-01-17T16:00:00+11:00","2022-01-18T10:00:00+11:00","2022-01-18T11:00:00+11:00","2022-01-18T12:00:00+11:00","2022-01-18T13:00:00+11:00","2022-01-18T14:00:00+11:00","2022-01-18T15:00:00+11:00","2022-01-18T16:00:00+11:00","2022-01-19T10:00:00+11:00","2022-01-19T11:00:00+11:00","2022-01-19T12:00:00+11:00","2022-01-19T13:00:00+11:00","2022-01-19T14:00:00+11:00","2022-01-19T15:00:00+11:00","2022-01-19T16:00:00+11:00","2022-01-20T10:00:00+11:00","2022-01-20T11:00:00+11:00","2022-01-20T12:00:00+11:00","2022-01-20T13:00:00+11:00","2022-01-20T14:00:00+11:00","2022-01-20T15:00:00+11:00","2022-01-20T16:00:00+11:00","2022-01-21T10:00:00+11:00","2022-01-21T11:00:00+11:00","2022-01-21T12:00:00+11:00","2022-01-21T13:00:00+11:00","2022-01-21T14:00:00+11:00","2022-01-21T15:00:00+11:00","2022-01-21T16:00:00+11:00","2022-01-25T15:00:00+11:00","2022-01-25T16:00:00+11:00","2022-01-27T10:00:00+11:00","2022-01-27T11:00:00+11:00","2022-01-27T12:00:00+11:00","2022-01-27T13:00:00+11:00","2022-01-27T14:00:00+11:00","2022-01-27T15:00:00+11:00","2022-01-27T16:00:00+11:00","2022-01-28T10:00:00+11:00","2022-01-28T11:00:00+11:00","2022-01-28T12:00:00+11:00","2022-01-28T13:00:00+11:00","2022-01-28T14:00:00+11:00","2022-01-28T15:00:00+11:00","2022-01-31T10:00:00+11:00","2022-01-31T11:00:00+11:00","2022-01-31T12:00:00+11:00","2022-01-31T13:00:00+11:00","2022-01-31T14:00:00+11:00","2022-01-31T15:00:00+11:00","2022-01-31T16:00:00+11:00","2022-02-01T10:00:00+11:00","2022-02-01T11:00:00+11:00","2022-02-01T12:00:00+11:00","2022-02-01T13:00:00+11:00","2022-02-01T14:00:00+11:00","2022-02-01T15:00:00+11:00","2022-02-01T16:00:00+11:00","2022-02-02T10:00:00+11:00","2022-02-02T11:00:00+11:00","2022-02-02T12:00:00+11:00","2022-02-02T13:00:00+11:00","2022-02-02T14:00:00+11:00","2022-02-02T15:00:00+11:00","2022-02-02T16:00:00+11:00","2022-02-03T10:00:00+11:00","2022-02-03T11:00:00+11:00","2022-02-03T12:00:00+11:00","2022-02-03T13:00:00+11:00","2022-02-03T14:00:00+11:00","2022-02-03T15:00:00+11:00","2022-02-03T16:00:00+11:00","2022-02-08T12:00:00+11:00","2022-02-08T13:00:00+11 ...
# #### RMC.AX
# <div>                            <div id="a046dfdb-6d76-4631-9226-db515680e736" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a046dfdb-6d76-4631-9226-db515680e736")) {                    Plotly.newPlot(                        "a046dfdb-6d76-4631-9226-db515680e736",                        [{"line":{"color":"rgba(0,0,0,0)"},"type":"scatter","x":["2022-01-04T10:00:00+11:00","2022-01-04T11:00:00+11:00","2022-01-04T12:00:00+11:00","2022-01-04T13:00:00+11:00","2022-01-04T14:00:00+11:00","2022-01-04T15:00:00+11:00","2022-01-04T16:00:00+11:00","2022-01-05T10:00:00+11:00","2022-01-05T11:00:00+11:00","2022-01-05T12:00:00+11:00","2022-01-05T13:00:00+11:00","2022-01-05T14:00:00+11:00","2022-01-05T15:00:00+11:00","2022-01-05T16:00:00+11:00","2022-01-06T10:00:00+11:00","2022-01-06T11:00:00+11:00","2022-01-06T12:00:00+11:00","2022-01-06T13:00:00+11:00","2022-01-06T14:00:00+11:00","2022-01-06T15:00:00+11:00","2022-01-06T16:00:00+11:00","2022-01-07T10:00:00+11:00","2022-01-07T11:00:00+11:00","2022-01-07T12:00:00+11:00","2022-01-07T13:00:00+11:00","2022-01-07T14:00:00+11:00","2022-01-07T15:00:00+11:00","2022-01-07T16:00:00+11:00","2022-01-10T10:00:00+11:00","2022-01-10T11:00:00+11:00","2022-01-10T12:00:00+11:00","2022-01-10T13:00:00+11:00","2022-01-10T14:00:00+11:00","2022-01-10T15:00:00+11:00","2022-01-10T16:00:00+11:00","2022-01-11T10:00:00+11:00","2022-01-11T11:00:00+11:00","2022-01-11T12:00:00+11:00","2022-01-11T13:00:00+11:00","2022-01-11T14:00:00+11:00","2022-01-11T15:00:00+11:00","2022-01-11T16:00:00+11:00","2022-01-17T10:00:00+11:00","2022-01-17T11:00:00+11:00","2022-01-17T12:00:00+11:00","2022-01-17T13:00:00+11:00","2022-01-17T14:00:00+11:00","2022-01-17T15:00:00+11:00","2022-01-17T16:00:00+11:00","2022-01-18T10:00:00+11:00","2022-01-18T11:00:00+11:00","2022-01-18T12:00:00+11:00","2022-01-18T13:00:00+11:00","2022-01-18T14:00:00+11:00","2022-01-18T15:00:00+11:00","2022-01-18T16:00:00+11:00","2022-01-19T10:00:00+11:00","2022-01-19T11:00:00+11:00","2022-01-19T12:00:00+11:00","2022-01-19T13:00:00+11:00","2022-01-19T14:00:00+11:00","2022-01-19T15:00:00+11:00","2022-01-19T16:00:00+11:00","2022-01-20T10:00:00+11:00","2022-01-20T11:00:00+11:00","2022-01-20T12:00:00+11:00","2022-01-20T13:00:00+11:00","2022-01-20T14:00:00+11:00","2022-01-20T15:00:00+11:00","2022-01-20T16:00:00+11:00","2022-01-21T10:00:00+11:00","2022-01-21T11:00:00+11:00","2022-01-21T12:00:00+11:00","2022-01-21T13:00:00+11:00","2022-01-21T14:00:00+11:00","2022-01-21T15:00:00+11:00","2022-01-21T16:00:00+11:00","2022-01-25T15:00:00+11:00","2022-01-25T16:00:00+11:00","2022-01-27T10:00:00+11:00","2022-01-27T11:00:00+11:00","2022-01-27T12:00:00+11:00","2022-01-27T13:00:00+11:00","2022-01-27T14:00:00+11:00","2022-01-27T15:00:00+11:00","2022-01-27T16:00:00+11:00","2022-01-28T10:00:00+11:00","2022-01-28T11:00:00+11:00","2022-01-28T12:00:00+11:00","2022-01-28T13:00:00+11:00","2022-01-28T14:00:00+11:00","2022-01-28T15:00:00+11:00","2022-01-31T10:00:00+11:00","2022-01-31T11:00:00+11:00","2022-01-31T12:00:00+11:00","2022-01-31T13:00:00+11:00","2022-01-31T14:00:00+11:00","2022-01-31T15:00:00+11:00","2022-01-31T16:00:00+11:00","2022-02-01T10:00:00+11:00","2022-02-01T11:00:00+11:00","2022-02-01T12:00:00+11:00","2022-02-01T13:00:00+11:00","2022-02-01T14:00:00+11:00","2022-02-01T15:00:00+11:00","2022-02-01T16:00:00+11:00","2022-02-02T10:00:00+11:00","2022-02-02T11:00:00+11:00","2022-02-02T12:00:00+11:00","2022-02-02T13:00:00+11:00","2022-02-02T14:00:00+11:00","2022-02-02T15:00:00+11:00","2022-02-02T16:00:00+11:00","2022-02-03T10:00:00+11:00","2022-02-03T11:00:00+11:00","2022-02-03T12:00:00+11:00","2022-02-03T13:00:00+11:00","2022-02-03T14:00:00+11:00","2022-02-03T15:00:00+11:00","2022-02-03T16:00:00+11:00","2022-02-08T12:00:00+11:00","2022-02-08T13:00:00+11 ...
# #### ASW.AX
# <div>                            <div id="175a226a-de09-41ee-aee6-fb41723e556d" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("175a226a-de09-41ee-aee6-fb41723e556d")) {                    Plotly.newPlot(                        "175a226a-de09-41ee-aee6-fb41723e556d",                        [{"line":{"color":"rgba(0,0,0,0)"},"type":"scatter","x":["2022-01-04T10:00:00+11:00","2022-01-04T11:00:00+11:00","2022-01-04T12:00:00+11:00","2022-01-04T13:00:00+11:00","2022-01-04T14:00:00+11:00","2022-01-04T15:00:00+11:00","2022-01-04T16:00:00+11:00","2022-01-05T10:00:00+11:00","2022-01-05T11:00:00+11:00","2022-01-05T12:00:00+11:00","2022-01-05T13:00:00+11:00","2022-01-05T14:00:00+11:00","2022-01-05T15:00:00+11:00","2022-01-05T16:00:00+11:00","2022-01-06T10:00:00+11:00","2022-01-06T11:00:00+11:00","2022-01-06T12:00:00+11:00","2022-01-06T13:00:00+11:00","2022-01-06T14:00:00+11:00","2022-01-06T15:00:00+11:00","2022-01-06T16:00:00+11:00","2022-01-07T10:00:00+11:00","2022-01-07T11:00:00+11:00","2022-01-07T12:00:00+11:00","2022-01-07T13:00:00+11:00","2022-01-07T14:00:00+11:00","2022-01-07T15:00:00+11:00","2022-01-07T16:00:00+11:00","2022-01-10T10:00:00+11:00","2022-01-10T11:00:00+11:00","2022-01-10T12:00:00+11:00","2022-01-10T13:00:00+11:00","2022-01-10T14:00:00+11:00","2022-01-10T15:00:00+11:00","2022-01-10T16:00:00+11:00","2022-01-11T10:00:00+11:00","2022-01-11T11:00:00+11:00","2022-01-11T12:00:00+11:00","2022-01-11T13:00:00+11:00","2022-01-11T14:00:00+11:00","2022-01-11T15:00:00+11:00","2022-01-11T16:00:00+11:00","2022-01-17T10:00:00+11:00","2022-01-17T11:00:00+11:00","2022-01-17T12:00:00+11:00","2022-01-17T13:00:00+11:00","2022-01-17T14:00:00+11:00","2022-01-17T15:00:00+11:00","2022-01-17T16:00:00+11:00","2022-01-18T10:00:00+11:00","2022-01-18T11:00:00+11:00","2022-01-18T12:00:00+11:00","2022-01-18T13:00:00+11:00","2022-01-18T14:00:00+11:00","2022-01-18T15:00:00+11:00","2022-01-18T16:00:00+11:00","2022-01-19T10:00:00+11:00","2022-01-19T11:00:00+11:00","2022-01-19T12:00:00+11:00","2022-01-19T13:00:00+11:00","2022-01-19T14:00:00+11:00","2022-01-19T15:00:00+11:00","2022-01-19T16:00:00+11:00","2022-01-20T10:00:00+11:00","2022-01-20T11:00:00+11:00","2022-01-20T12:00:00+11:00","2022-01-20T13:00:00+11:00","2022-01-20T14:00:00+11:00","2022-01-20T15:00:00+11:00","2022-01-20T16:00:00+11:00","2022-01-21T10:00:00+11:00","2022-01-21T11:00:00+11:00","2022-01-21T12:00:00+11:00","2022-01-21T13:00:00+11:00","2022-01-21T14:00:00+11:00","2022-01-21T15:00:00+11:00","2022-01-21T16:00:00+11:00","2022-01-25T15:00:00+11:00","2022-01-25T16:00:00+11:00","2022-01-27T10:00:00+11:00","2022-01-27T11:00:00+11:00","2022-01-27T12:00:00+11:00","2022-01-27T13:00:00+11:00","2022-01-27T14:00:00+11:00","2022-01-27T15:00:00+11:00","2022-01-27T16:00:00+11:00","2022-01-28T10:00:00+11:00","2022-01-28T11:00:00+11:00","2022-01-28T12:00:00+11:00","2022-01-28T13:00:00+11:00","2022-01-28T14:00:00+11:00","2022-01-28T15:00:00+11:00","2022-01-31T10:00:00+11:00","2022-01-31T11:00:00+11:00","2022-01-31T12:00:00+11:00","2022-01-31T13:00:00+11:00","2022-01-31T14:00:00+11:00","2022-01-31T15:00:00+11:00","2022-01-31T16:00:00+11:00","2022-02-01T10:00:00+11:00","2022-02-01T11:00:00+11:00","2022-02-01T12:00:00+11:00","2022-02-01T13:00:00+11:00","2022-02-01T14:00:00+11:00","2022-02-01T15:00:00+11:00","2022-02-01T16:00:00+11:00","2022-02-02T10:00:00+11:00","2022-02-02T11:00:00+11:00","2022-02-02T12:00:00+11:00","2022-02-02T13:00:00+11:00","2022-02-02T14:00:00+11:00","2022-02-02T15:00:00+11:00","2022-02-02T16:00:00+11:00","2022-02-03T10:00:00+11:00","2022-02-03T11:00:00+11:00","2022-02-03T12:00:00+11:00","2022-02-03T13:00:00+11:00","2022-02-03T14:00:00+11:00","2022-02-03T15:00:00+11:00","2022-02-03T16:00:00+11:00","2022-02-08T12:00:00+11:00","2022-02-08T13:00:00+11 ...

# %%
# plot_Ichimoku("Materials", material.sort_values(by=['CUM_RET'], ascending=False), 10)

# %%
# plot_Ichimoku("Real Estate", restate.sort_values(by=['CUM_RET'], ascending=False), 10)

# %%
# plot_Ichimoku("Energy", energy.sort_values(by=['CUM_RET'], ascending=False), 10)
